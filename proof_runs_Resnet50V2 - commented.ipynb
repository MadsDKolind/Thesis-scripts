# %% [markdown]
# # --

# %% [markdown]
# ## Setup

# %% [markdown]
# * IMPORT

# %%
import keras
import numpy as np
from numpy import ma
import json
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import  classification_report, confusion_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
import random

# %% [markdown]
# * Set random state

# %%
random_state = 42

# %% [markdown]
# ## Data

# %% [markdown]
# * LOAD DATA

# %%
# Load all data and labels
ccFieldsAll = np.load("C:/Users/mkoli/Syddansk Universitet/Morten Thyrring Stouenberg - Speciale2023/Data/AllNoAlt/ccLastImageNoCloudIndex0_6234.npy", allow_pickle=True)
labels = np.load("C:/Users/mkoli/Syddansk Universitet/Morten Thyrring Stouenberg - Speciale2023/Data/AllNoAlt/reLabelsAll.npy", allow_pickle=True)

# Cloud probability band subset
cloud_probability = ccFieldsAll[:len(labels),:,:,7]

# Subset data to true labels
ccFieldsAll = ccFieldsAll[:len(labels),:,:,[2,1,0]]

# %% [markdown]
# * Normalize color bands

# %%
# Initiate function to normalize color bands to fit the preprocessing functions for tensorflow applications transfer learning models
def normalize(band):
    band_min, band_max = (band.min(), band.max())
    return (((band-band_min)/((band_max - band_min)))*255)

# We use function for the visible bands - RGB
ccFieldsAll[:,:,:,0] = normalize(ccFieldsAll[:,:,:,0])
ccFieldsAll[:,:,:,1] = normalize(ccFieldsAll[:,:,:,1])
ccFieldsAll[:,:,:,2] = normalize(ccFieldsAll[:,:,:,2])

# %% [markdown]
# * Cloud masking

# %%
# We Set cloud tolerance, between 0-255
cloud_tolerance = 40
    
# We loop in the fields by the length of the dataset
for i in range(len(ccFieldsAll)):
    # we subset the image we are at in the loop
    image = ccFieldsAll[i,:,:,:]    
    # We create and apply a mask based on cloud probability over a certain value
    # We use np.logical because np.where did not work for me at the moment
    mask = np.logical_and(cloud_probability[i, :, :,] >= cloud_tolerance, cloud_probability[i, :, :] <= 256)
    # We set all masked pixels to zero, to black out cloud covered parts
    # I do not know why but it didn't work when i did not make a copy. It is just one of those times. 
    masked = image.copy()
    masked[mask] = 0
    # We are replacing the current image with the one with applied cloud mask, if no clouds then nothing is removed.
    ccFieldsAll[i] = masked

# %% [markdown]
# * DELETE EMPTY IMAGES AND RESIZE

# %%
# we want to delete the all black images, this is done by only appending images with visible RGB bands not all black.

# Initiate list for images that did not get blacked out as well as a list for labels
ccFieldsNoCloud = []
LabelsNoCloud = []

# as we are looping in the images we resize them at the same time
# so we set the size of the images
size = 128

# We loop in all the images
for i in range(len(ccFieldsAll)):
    # if the image is not all black
    if not np.all(ccFieldsAll[i] == 0):
        #we append the image and label
        ccFieldsNoCloud.append(tf.image.resize(ccFieldsAll[i], [size, size]))
        LabelsNoCloud.append(labels[i])

# We set the lists as arrays
ccFieldsNoCloud = np.array(ccFieldsNoCloud)
LabelsNoCloud   = np.array(LabelsNoCloud)

#And print the shapes to control the output and see how many fields are left. 
print(ccFieldsNoCloud.shape)
print(LabelsNoCloud.shape)
# Out:
# (6122, 128, 128, 3)
# (6122,)

# %% [markdown]
# * NEW DISTRIBUTION OF LABELS

# %%
#We investigate the new label distribution
print(f'Number of observations : {len(LabelsNoCloud)}')
# We count non zero indices and compute the percentage representation in the dataset. 
print(f'appearances of 0 in labels : {np.count_nonzero(LabelsNoCloud == 0)}({round(100*np.count_nonzero(LabelsNoCloud == 0)/len(LabelsNoCloud),2)}% of total)')
print(f'appearances of 1 in labels : {np.count_nonzero(LabelsNoCloud == 1)}({round(100*np.count_nonzero(LabelsNoCloud == 1)/len(LabelsNoCloud),2)}% of total)')
print(f'appearances of 2 in labels : {np.count_nonzero(LabelsNoCloud == 2)}({round(100*np.count_nonzero(LabelsNoCloud == 2)/len(LabelsNoCloud),2)}% of total)')
# Out:
# Number of observations : 6122
# appearances of 0 in labels : 999(16.32% of total)
# appearances of 1 in labels : 1325(21.64% of total)
# appearances of 2 in labels : 3798(62.04% of total)

# %% [markdown]
# ### CNN (RGB images)

# %%
# Data is split 80/20 for train and test
X_train, X_test, y_train, y_test = train_test_split(ccFieldsNoCloud, 
                                                    LabelsNoCloud, 
                                                    test_size=0.2, 
                                                    random_state=random_state)

# Train data is split 75/25, which corresponds to 20% of original 
# data as validation and 60% of original data as train
X_train, X_val, y_train, y_val = train_test_split(X_train, 
                                                  y_train, 
                                                  test_size=0.25, 
                                                  random_state=random_state) # 0.25 x 0.8 = 0.2

# Print the dataset shapes to inspect sizes
print(X_train.shape, y_train.shape) 
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (3672, 128, 128, 3) (3672,)
# (1225, 128, 128, 3) (1225,)
# (1225, 128, 128, 3) (1225,)

# %% [markdown]
# # Data augmentation

# %% [markdown]
# From: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
#Defining augmentaation method 
 
datagen = ImageDataGenerator(
    # Rotation range is set to 360 to enable images to get any rotational angle
    rotation_range      = 360,        
    # Zoom range is a conservative 0.2 to not get too big parts of the image out of bounds
    zoom_range          = 0.2,           
    # Brightness range is random between specified values to enable brightness adjustment due to sun or shadow from clouds
    brightness_range    = (0.8,1.2),    
    # Horisontal flip is enabled. I do not know if it is going to make a difference, but it is not going to hurt. 
    horizontal_flip     = True)

# %%
# We initiate lists for data and labels used for augmentation
data_for_augmentation = []
labels_for_augmentation = []

# We Loop Loop data and append fields to each class for single class data augmentation 
for i in range(len(y_train)):
  if y_train[i] == 0:
    data_for_augmentation.append(X_train[i])
    labels_for_augmentation.append(y_train[i])
  if y_train[i] == 1:
    data_for_augmentation.append(X_train[i])
    labels_for_augmentation.append(y_train[i])

# save as numpy arrays
data_for_augmentation    = np.asarray(data_for_augmentation)
labels_for_augmentation    = np.asarray(labels_for_augmentation)

# Check  array shape
print(f'data for augmentation : {data_for_augmentation.shape} labels for augmentation : {labels_for_augmentation.shape}')
# Out:
# data for augmentation : (1412, 128, 128, 3) labels for augmentation : (1412,)

# %%
# We set a specified number of images for augmentation per image in the dataset
num_samples_per_image = 7
# num_samples_per_image = 9
# num_samples_per_image = 11

# We reshaping data, i am not sure why, but stack overflow helped me get here.
aug_dataset            = data_for_augmentation.reshape(data_for_augmentation.shape[0], 
                                                      data_for_augmentation.shape[1], 
                                                      data_for_augmentation.shape[2], 
                                                      3)

# We initiate a list of labels for augmented data
labels_aug = []
# We create an empty list for the augmented images
augmented_images = []

# We loop in the length of the dataset
for i in range(len(aug_dataset)):
    # We loop in the desired amount of images augmented for each image
    for j in range(num_samples_per_image):
        # we subset the image
        img = data_for_augmentation[i]
        # we expand dimensions as described on the tensorflow website 
        # https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator 
        img = np.expand_dims(img, axis=0)
        # We use the datagen.flow to flow one image at the time into the augmenting imagedatagenerator
        # I am not entirely sure about the .next when using only one image but it works, in theory we do not need it but i do not want to remove something when it works. 
        augmented_img = datagen.flow(img, batch_size=1, shuffle=False).next()
        #as we have expanded the dimensiong we need to sqeeze it all back together for a functioning image again
        augmented_img = augmented_img.squeeze(axis=0)
        # We append the image and labels to our lists
        augmented_images.append(augmented_img)
        labels_aug.append(labels_for_augmentation[i])

#Turn it all into numpy arrays
labels_aug=np.asarray(labels_aug)
augmented_images=np.asarray(augmented_images)

# %%
# We concatenate the training data and the augmented data.
X_trainx = np.concatenate((X_trainx, augmented_images), axis=0)
y_train = np.concatenate((y_train, labels_aug), axis=0)

# %%
# We shuffle the data to ensure there is not only accepted fields in the start of the dataset
# we set a list of indexes that is randomly shuffled
idx = np.random.permutation(len(X_train))
# We use these indexes to set the images with corresponding labels
X_train,y_train = X_train[idx], y_train[idx]

# %%
# again we print the distribution to see if it changed - and it did!
print(f'Number of observations : {len(y_train)}')

print(f'appearances of 0 in labels : {np.count_nonzero(y_train == 0)}({round(100*np.count_nonzero(y_train == 0)/len(y_train),2)}% of total)')
print(f'appearances of 1 in labels : {np.count_nonzero(y_train == 1)}({round(100*np.count_nonzero(y_train == 1)/len(y_train),2)}% of total)')
print(f'appearances of 2 in labels : {np.count_nonzero(y_train == 2)}({round(100*np.count_nonzero(y_train == 2)/len(y_train),2)}% of total)')
# Out:
# Number of observations : 13556
# appearances of 0 in labels : 4832(35.64% of total)
# appearances of 1 in labels : 6464(47.68% of total)
# appearances of 2 in labels : 2260(16.67% of total)

# %% [markdown]
# # Accuracy metrics function

# %% [markdown]
# * Function for classification report and confusion matrix

# %%
# We define a function that visualize the results by a classification report and a confusion matrix.

def model_metrics(model, x_test, y_test):
    # Generate predictions on the test set using model and test data.
    y_pred = model.predict(X_test)
    # We use argmax function to gain the predicted class from the probabilities. 
    y_pred_classes = np.argmax(y_pred, axis=1)
    # We print classification report using true labels and predicted labels
    print(classification_report(y_test, y_pred_classes))
    # We Generate a confusion matrix
    cm = confusion_matrix(y_test, y_pred_classes)
    # We define define the class labels
    class_names = ['Failed (0)', 'Partially (1)', 'Accepted (2)']
    # We Plot the confusion matrix
    plt.figure(figsize=(8, 6))
    # show confusion matrix, cmap is the color scheme for matplotlib
    plt.imshow(cm, cmap=plt.cm.OrRd)
    # we set title and labels for plot
    plt.title(f'Confusion Matrix \n {cp_filepath}')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    # we set ticks
    plt.xticks(np.arange(len(class_names)), class_names, rotation=45)
    plt.yticks(np.arange(len(class_names)), class_names)
    plt.colorbar()
    # We add labels to the plot
    for k in range(len(class_names)):
        for h in range(len(class_names)):
            plt.text(h, k, cm[k, h], ha='center', va='center', color='black')
    plt.show()

# %% [markdown]
# # Training histories

# %%
histories = []
name = []

ft_histories = []
ft_name = []

# %% [markdown]
# # Best model runs for comparison

# %%
# Resnet50V2 model
X_train = tf.keras.applications.resnet_v2.preprocess_input(X_train, data_format=None)
X_test = tf.keras.applications.resnet_v2.preprocess_input(X_test, data_format=None)
X_val = tf.keras.applications.resnet_v2.preprocess_input(X_val, data_format=None)


####################################################################################################################
# All steps are the same as above, we change the model and top layers for specific model
learning_rate = [0.001]
batch_size = [16]
dropouts = [0.2]
model_name = "ResNet50V2" 
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)
####################################################################################################################
for i in learning_rate:
    for j in batch_size:
        for d in dropouts:
            ####################################################################################################################
            print(f'Running: \n learning rate:{i}, batch size: {j} with dropout: {d} for epochs: {epochs}')
            ####################################################################################################################
            base_model = keras.applications.ResNet50V2(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 
            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False
            ####################################################################################################################
            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(512, activation='relu'),  
                tf.keras.layers.Dropout(d),
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            ####################################################################################################################
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])
            ####################################################################################################################
            cp_filepath = '{} lr{} batch size{} dropout{}.h5'.format(model_name, i,j,d)
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            ####################################################################################################################
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            model = tf.keras.models.load_model(cp_filepath)
            #################################################################################################################### 
            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])
            cp_filepath = 'ft {} lr{} batch size{} dropout{}.h5'.format(model_name, i,j,d)
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')        
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')
            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)
            model = tf.keras.models.load_model(cp_filepath)
            model_metrics(model, X_test, y_test)
# Out:
# Running:
#  learning rate:0.001, batch size: 16 with dropout: 0.2 for epochs: 100
# Epoch 1/100
# 848/848 [==============================] - 23s 18ms/step - loss: 1.0814 - accuracy: 0.5115 - val_loss: 1.1414 - val_accuracy: 0.4776
# Epoch 2/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.8412 - accuracy: 0.5707 - val_loss: 1.2286 - val_accuracy: 0.4367
# Epoch 3/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.7948 - accuracy: 0.6019 - val_loss: 1.2373 - val_accuracy: 0.4498
# Epoch 4/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.7522 - accuracy: 0.6299 - val_loss: 1.1748 - val_accuracy: 0.4922
# Epoch 5/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.7093 - accuracy: 0.6554 - val_loss: 1.2138 - val_accuracy: 0.5249
# Epoch 6/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.6580 - accuracy: 0.6877 - val_loss: 1.1668 - val_accuracy: 0.5265
# Epoch 7/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.6133 - accuracy: 0.7095 - val_loss: 1.2421 - val_accuracy: 0.5012
# Epoch 8/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.5704 - accuracy: 0.7355 - val_loss: 1.2391 - val_accuracy: 0.5429
# Epoch 9/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.5331 - accuracy: 0.7572 - val_loss: 1.2297 - val_accuracy: 0.5616
# Epoch 10/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.4872 - accuracy: 0.7781 - val_loss: 1.4965 - val_accuracy: 0.4873
# Epoch 11/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.4566 - accuracy: 0.7937 - val_loss: 1.4321 - val_accuracy: 0.5200
# Epoch 12/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.4323 - accuracy: 0.8067 - val_loss: 1.5999 - val_accuracy: 0.4824
# Epoch 13/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.3958 - accuracy: 0.8272 - val_loss: 1.7173 - val_accuracy: 0.4694
# Epoch 14/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.3617 - accuracy: 0.8408 - val_loss: 1.6351 - val_accuracy: 0.5216
# Epoch 15/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.3543 - accuracy: 0.8464 - val_loss: 1.6216 - val_accuracy: 0.5020
# Epoch 16/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.3234 - accuracy: 0.8598 - val_loss: 1.7104 - val_accuracy: 0.5404
# Epoch 17/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.3248 - accuracy: 0.8578 - val_loss: 1.9194 - val_accuracy: 0.4784
# Epoch 18/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.2954 - accuracy: 0.8724 - val_loss: 2.0578 - val_accuracy: 0.5371
# Epoch 19/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.2866 - accuracy: 0.8786 - val_loss: 1.9918 - val_accuracy: 0.4988
# Epoch 20/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.2754 - accuracy: 0.8812 - val_loss: 1.9191 - val_accuracy: 0.5396
# Epoch 21/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.2582 - accuracy: 0.8886 - val_loss: 2.2413 - val_accuracy: 0.5069
# Epoch 22/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.2533 - accuracy: 0.8907 - val_loss: 2.0443 - val_accuracy: 0.5363
# Epoch 23/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.2502 - accuracy: 0.8948 - val_loss: 2.4167 - val_accuracy: 0.5053
# Epoch 24/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.2296 - accuracy: 0.9040 - val_loss: 2.3951 - val_accuracy: 0.5420
# Epoch 25/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.2345 - accuracy: 0.9037 - val_loss: 2.3461 - val_accuracy: 0.5184
# Epoch 26/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.2188 - accuracy: 0.9071 - val_loss: 2.3919 - val_accuracy: 0.5110
# Epoch 27/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.2196 - accuracy: 0.9070 - val_loss: 2.4500 - val_accuracy: 0.5380
# Epoch 28/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.2006 - accuracy: 0.9172 - val_loss: 2.2785 - val_accuracy: 0.5273
# Epoch 29/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1978 - accuracy: 0.9181 - val_loss: 2.7622 - val_accuracy: 0.5020
# Epoch 30/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1893 - accuracy: 0.9213 - val_loss: 2.3924 - val_accuracy: 0.5298
# Epoch 31/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1985 - accuracy: 0.9183 - val_loss: 2.5423 - val_accuracy: 0.4955
# Epoch 32/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1988 - accuracy: 0.9194 - val_loss: 2.5652 - val_accuracy: 0.5469
# Epoch 33/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1726 - accuracy: 0.9273 - val_loss: 2.6979 - val_accuracy: 0.5371
# Epoch 34/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1764 - accuracy: 0.9277 - val_loss: 2.7804 - val_accuracy: 0.5192
# Epoch 35/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1824 - accuracy: 0.9281 - val_loss: 2.8823 - val_accuracy: 0.5159
# Epoch 36/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1756 - accuracy: 0.9295 - val_loss: 2.6452 - val_accuracy: 0.5200
# Epoch 37/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1735 - accuracy: 0.9294 - val_loss: 2.6788 - val_accuracy: 0.5314
# Epoch 38/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1632 - accuracy: 0.9343 - val_loss: 2.9679 - val_accuracy: 0.4873
# Epoch 39/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1706 - accuracy: 0.9318 - val_loss: 3.1506 - val_accuracy: 0.5053
# Epoch 40/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1646 - accuracy: 0.9377 - val_loss: 2.8902 - val_accuracy: 0.5094
# Epoch 41/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1457 - accuracy: 0.9418 - val_loss: 2.9205 - val_accuracy: 0.4824
# Epoch 42/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1568 - accuracy: 0.9367 - val_loss: 3.1962 - val_accuracy: 0.4792
# Epoch 43/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1370 - accuracy: 0.9455 - val_loss: 3.2510 - val_accuracy: 0.5233
# Epoch 44/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1587 - accuracy: 0.9381 - val_loss: 2.8595 - val_accuracy: 0.5339
# Epoch 45/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1541 - accuracy: 0.9412 - val_loss: 2.9147 - val_accuracy: 0.5118
# Epoch 46/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1450 - accuracy: 0.9428 - val_loss: 2.9049 - val_accuracy: 0.5241
# Epoch 47/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1484 - accuracy: 0.9404 - val_loss: 3.1790 - val_accuracy: 0.5265
# Epoch 48/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1420 - accuracy: 0.9447 - val_loss: 3.1539 - val_accuracy: 0.5445
# Epoch 49/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1383 - accuracy: 0.9452 - val_loss: 3.3640 - val_accuracy: 0.5053
# Epoch 50/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1361 - accuracy: 0.9468 - val_loss: 3.0825 - val_accuracy: 0.5453
# Epoch 51/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1357 - accuracy: 0.9459 - val_loss: 3.4976 - val_accuracy: 0.5110
# Epoch 52/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1433 - accuracy: 0.9442 - val_loss: 3.3053 - val_accuracy: 0.5078
# Epoch 53/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1232 - accuracy: 0.9494 - val_loss: 3.2739 - val_accuracy: 0.5061
# Epoch 54/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1234 - accuracy: 0.9521 - val_loss: 3.5531 - val_accuracy: 0.5053
# Epoch 55/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1336 - accuracy: 0.9470 - val_loss: 3.3039 - val_accuracy: 0.4833
# Epoch 56/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1241 - accuracy: 0.9517 - val_loss: 3.1091 - val_accuracy: 0.5478
# Epoch 57/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1330 - accuracy: 0.9484 - val_loss: 3.6504 - val_accuracy: 0.4988
# Epoch 58/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1164 - accuracy: 0.9535 - val_loss: 3.5474 - val_accuracy: 0.5004
# Epoch 59/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1287 - accuracy: 0.9496 - val_loss: 3.5796 - val_accuracy: 0.5086
# Epoch 60/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1294 - accuracy: 0.9533 - val_loss: 3.6934 - val_accuracy: 0.5167
# Epoch 61/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1171 - accuracy: 0.9537 - val_loss: 3.3041 - val_accuracy: 0.5216
# Epoch 62/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1320 - accuracy: 0.9508 - val_loss: 3.5200 - val_accuracy: 0.5086
# Epoch 63/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1171 - accuracy: 0.9558 - val_loss: 3.5092 - val_accuracy: 0.4767
# Epoch 64/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1108 - accuracy: 0.9557 - val_loss: 3.3990 - val_accuracy: 0.5184
# Epoch 65/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.1216 - accuracy: 0.9528 - val_loss: 3.6551 - val_accuracy: 0.5045
# Epoch 66/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1172 - accuracy: 0.9555 - val_loss: 3.8891 - val_accuracy: 0.5118
# Epoch 67/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1046 - accuracy: 0.9568 - val_loss: 3.7556 - val_accuracy: 0.5437
# Epoch 68/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1047 - accuracy: 0.9605 - val_loss: 3.8820 - val_accuracy: 0.4996
# Epoch 69/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1136 - accuracy: 0.9574 - val_loss: 4.0693 - val_accuracy: 0.5078
# Epoch 70/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1233 - accuracy: 0.9549 - val_loss: 3.9114 - val_accuracy: 0.5184
# Epoch 71/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1097 - accuracy: 0.9585 - val_loss: 3.6366 - val_accuracy: 0.5518
# Epoch 72/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1104 - accuracy: 0.9593 - val_loss: 3.5802 - val_accuracy: 0.4914
# Epoch 73/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1049 - accuracy: 0.9587 - val_loss: 3.9225 - val_accuracy: 0.4857
# Epoch 74/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1065 - accuracy: 0.9603 - val_loss: 3.8758 - val_accuracy: 0.5020
# Epoch 75/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1027 - accuracy: 0.9596 - val_loss: 4.4937 - val_accuracy: 0.4580
# Epoch 76/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1057 - accuracy: 0.9605 - val_loss: 3.9763 - val_accuracy: 0.4939
# Epoch 77/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1059 - accuracy: 0.9599 - val_loss: 4.1764 - val_accuracy: 0.5102
# Epoch 78/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0999 - accuracy: 0.9626 - val_loss: 3.9721 - val_accuracy: 0.4955
# Epoch 79/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1137 - accuracy: 0.9593 - val_loss: 3.8448 - val_accuracy: 0.5069
# Epoch 80/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.0967 - accuracy: 0.9635 - val_loss: 4.5855 - val_accuracy: 0.4555
# Epoch 81/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0947 - accuracy: 0.9621 - val_loss: 4.2314 - val_accuracy: 0.5273
# Epoch 82/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.0995 - accuracy: 0.9634 - val_loss: 4.0658 - val_accuracy: 0.4882
# Epoch 83/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1040 - accuracy: 0.9599 - val_loss: 4.3257 - val_accuracy: 0.5224
# Epoch 84/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1001 - accuracy: 0.9639 - val_loss: 3.9788 - val_accuracy: 0.5045
# Epoch 85/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0964 - accuracy: 0.9644 - val_loss: 3.7234 - val_accuracy: 0.5143
# Epoch 86/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0947 - accuracy: 0.9618 - val_loss: 3.8079 - val_accuracy: 0.5249
# Epoch 87/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1083 - accuracy: 0.9615 - val_loss: 4.2482 - val_accuracy: 0.4939
# Epoch 88/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.0933 - accuracy: 0.9636 - val_loss: 4.2249 - val_accuracy: 0.4710
# Epoch 89/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.0902 - accuracy: 0.9666 - val_loss: 4.3565 - val_accuracy: 0.5029
# Epoch 90/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0949 - accuracy: 0.9632 - val_loss: 4.5833 - val_accuracy: 0.4833
# Epoch 91/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.1047 - accuracy: 0.9614 - val_loss: 4.0959 - val_accuracy: 0.4980
# Epoch 92/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0952 - accuracy: 0.9633 - val_loss: 4.4360 - val_accuracy: 0.4947
# Epoch 93/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0769 - accuracy: 0.9686 - val_loss: 4.2842 - val_accuracy: 0.5437
# Epoch 94/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.1045 - accuracy: 0.9633 - val_loss: 4.4654 - val_accuracy: 0.4751
# Epoch 95/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0977 - accuracy: 0.9667 - val_loss: 4.0876 - val_accuracy: 0.5118
# Epoch 96/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0820 - accuracy: 0.9680 - val_loss: 4.6936 - val_accuracy: 0.4857
# Epoch 97/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.0996 - accuracy: 0.9639 - val_loss: 4.9995 - val_accuracy: 0.4996
# Epoch 98/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0995 - accuracy: 0.9654 - val_loss: 3.8962 - val_accuracy: 0.5396
# Epoch 99/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0902 - accuracy: 0.9663 - val_loss: 4.3708 - val_accuracy: 0.5347
# Epoch 100/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.0805 - accuracy: 0.9691 - val_loss: 4.3070 - val_accuracy: 0.5029
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 4, 4, 2048)        23564800
#
#  global_max_pooling2d (Globa  (None, 2048)             0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 24,615,427
# Trainable params: 24,569,987
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/30
# 848/848 [==============================] - 44s 48ms/step - loss: 0.8655 - accuracy: 0.6139 - val_loss: 1.4900 - val_accuracy: 0.6278
# Epoch 2/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.7415 - accuracy: 0.6720 - val_loss: 1.3709 - val_accuracy: 0.2310
# Epoch 3/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.6815 - accuracy: 0.7009 - val_loss: 1.4874 - val_accuracy: 0.6294
# Epoch 4/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.6676 - accuracy: 0.7125 - val_loss: 0.9376 - val_accuracy: 0.6294
# Epoch 5/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.6483 - accuracy: 0.7186 - val_loss: 1.3370 - val_accuracy: 0.6294
# Epoch 6/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.6449 - accuracy: 0.7222 - val_loss: 1.0525 - val_accuracy: 0.6286
# Epoch 7/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.6421 - accuracy: 0.7224 - val_loss: 1.6532 - val_accuracy: 0.3061
# Epoch 8/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.6288 - accuracy: 0.7267 - val_loss: 1.0427 - val_accuracy: 0.4343
# Epoch 9/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.6194 - accuracy: 0.7348 - val_loss: 5.8967 - val_accuracy: 0.2180
# Epoch 10/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.5963 - accuracy: 0.7432 - val_loss: 0.9201 - val_accuracy: 0.6604
# Epoch 11/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.5875 - accuracy: 0.7418 - val_loss: 1.1717 - val_accuracy: 0.6278
# Epoch 12/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.5730 - accuracy: 0.7510 - val_loss: 2.4593 - val_accuracy: 0.2792
# Epoch 13/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.5651 - accuracy: 0.7541 - val_loss: 11.2104 - val_accuracy: 0.1641
# Epoch 14/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.5584 - accuracy: 0.7571 - val_loss: 7.3873 - val_accuracy: 0.2188
# Epoch 15/30
# 848/848 [==============================] - 40s 48ms/step - loss: 0.5418 - accuracy: 0.7624 - val_loss: 0.9778 - val_accuracy: 0.6171
# Epoch 16/30
# 848/848 [==============================] - 41s 48ms/step - loss: 0.5271 - accuracy: 0.7727 - val_loss: 0.8476 - val_accuracy: 0.6898
# Epoch 17/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.5164 - accuracy: 0.7744 - val_loss: 3.9628 - val_accuracy: 0.6294
# Epoch 18/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.4944 - accuracy: 0.7820 - val_loss: 8.5445 - val_accuracy: 0.1641
# Epoch 19/30
# 848/848 [==============================] - 40s 48ms/step - loss: 0.4812 - accuracy: 0.7891 - val_loss: 1.1354 - val_accuracy: 0.7110
# Epoch 20/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.4573 - accuracy: 0.8013 - val_loss: 1.8584 - val_accuracy: 0.6286
# Epoch 21/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.4296 - accuracy: 0.8143 - val_loss: 1.1601 - val_accuracy: 0.5796
# Epoch 22/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.3917 - accuracy: 0.8291 - val_loss: 1.5356 - val_accuracy: 0.3698
# Epoch 23/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.3576 - accuracy: 0.8478 - val_loss: 1.4841 - val_accuracy: 0.3412
# Epoch 24/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.3183 - accuracy: 0.8691 - val_loss: 3.8923 - val_accuracy: 0.1910
# Epoch 25/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.2771 - accuracy: 0.8874 - val_loss: 5.6280 - val_accuracy: 0.1984
# Epoch 26/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.2331 - accuracy: 0.9090 - val_loss: 1.5362 - val_accuracy: 0.6351
# Epoch 27/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.2081 - accuracy: 0.9214 - val_loss: 3.2669 - val_accuracy: 0.6514
# Epoch 28/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.1739 - accuracy: 0.9358 - val_loss: 2.4859 - val_accuracy: 0.3722
# Epoch 29/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.1476 - accuracy: 0.9456 - val_loss: 4.9612 - val_accuracy: 0.2376
# Epoch 30/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.1313 - accuracy: 0.9513 - val_loss: 8.4339 - val_accuracy: 0.2261
# 39/39 [==============================] - 2s 22ms/step
#               precision    recall  f1-score   support
#
#            0       0.56      0.80      0.66       208
#            1       0.00      0.00      0.00       250
#            2       0.78      0.94      0.85       767
#
#     accuracy                           0.72      1225
#    macro avg       0.45      0.58      0.50      1225
# weighted avg       0.58      0.72      0.64      1225

# %%
####################################################################################################################
# All steps are the same as above, we change the model and top layers for specific model
learning_rate = [0.001]
batch_size = [16]
dropouts = [0.2]
model_name = "ResNet50V2" 
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)
####################################################################################################################
for i in learning_rate:
    for j in batch_size:
        for d in dropouts:
            ####################################################################################################################
            print(f'Running: \n learning rate:{i}, batch size: {j} with dropout: {d} for epochs: {epochs}')
            ####################################################################################################################
            base_model = keras.applications.ResNet50V2(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 
            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False
            ####################################################################################################################
            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(512, activation='relu'),  
                tf.keras.layers.Dropout(d),
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            ####################################################################################################################
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])
            ####################################################################################################################
            cp_filepath = '{} lr{} batch size{} dropout{}.h5'.format(model_name, i,j,d)
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            ####################################################################################################################
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            model = tf.keras.models.load_model(cp_filepath)
            #################################################################################################################### 
            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])
            cp_filepath = 'ft {} lr{} batch size{} dropout{}.h5'.format(model_name, i,j,d)
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')        
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')
            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)
            model = tf.keras.models.load_model(cp_filepath)
            model_metrics(model, X_test, y_test)
# Out:
# Running:
#  learning rate:0.001, batch size: 16 with dropout: 0.2 for epochs: 100
# Epoch 1/100
# 848/848 [==============================] - 17s 18ms/step - loss: 1.0674 - accuracy: 0.4586 - val_loss: 1.4049 - val_accuracy: 0.2188
# Epoch 2/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0245 - accuracy: 0.4738 - val_loss: 1.3539 - val_accuracy: 0.2188
# Epoch 3/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0189 - accuracy: 0.4791 - val_loss: 1.5364 - val_accuracy: 0.1608
# Epoch 4/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0163 - accuracy: 0.4841 - val_loss: 1.4126 - val_accuracy: 0.2220
# Epoch 5/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0155 - accuracy: 0.4851 - val_loss: 1.2778 - val_accuracy: 0.2212
# Epoch 6/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0141 - accuracy: 0.4852 - val_loss: 1.4104 - val_accuracy: 0.2220
# Epoch 7/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0120 - accuracy: 0.4847 - val_loss: 1.4472 - val_accuracy: 0.2212
# Epoch 8/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0122 - accuracy: 0.4844 - val_loss: 1.3738 - val_accuracy: 0.2196
# Epoch 9/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0090 - accuracy: 0.4893 - val_loss: 1.4625 - val_accuracy: 0.2188
# Epoch 10/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0069 - accuracy: 0.4894 - val_loss: 1.3629 - val_accuracy: 0.2220
# Epoch 11/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0048 - accuracy: 0.4886 - val_loss: 1.4483 - val_accuracy: 0.2196
# Epoch 12/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0086 - accuracy: 0.4914 - val_loss: 1.3502 - val_accuracy: 0.2196
# Epoch 13/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0046 - accuracy: 0.4923 - val_loss: 1.3912 - val_accuracy: 0.2212
# Epoch 14/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0039 - accuracy: 0.4921 - val_loss: 1.3613 - val_accuracy: 0.2229
# Epoch 15/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0031 - accuracy: 0.4897 - val_loss: 1.4839 - val_accuracy: 0.2188
# Epoch 16/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0031 - accuracy: 0.4896 - val_loss: 1.4046 - val_accuracy: 0.2212
# Epoch 17/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0034 - accuracy: 0.4914 - val_loss: 1.5223 - val_accuracy: 0.2180
# Epoch 18/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0011 - accuracy: 0.4948 - val_loss: 1.4864 - val_accuracy: 0.2196
# Epoch 19/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0049 - accuracy: 0.4884 - val_loss: 1.4267 - val_accuracy: 0.2220
# Epoch 20/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0043 - accuracy: 0.4917 - val_loss: 1.5485 - val_accuracy: 0.2204
# Epoch 21/100
# 848/848 [==============================] - 14s 17ms/step - loss: 1.0028 - accuracy: 0.4931 - val_loss: 1.3850 - val_accuracy: 0.2237
# Epoch 22/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0020 - accuracy: 0.4949 - val_loss: 1.4468 - val_accuracy: 0.2204
# Epoch 23/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9996 - accuracy: 0.4964 - val_loss: 1.3417 - val_accuracy: 0.2212
# Epoch 24/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9990 - accuracy: 0.4915 - val_loss: 1.4645 - val_accuracy: 0.2237
# Epoch 25/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9969 - accuracy: 0.4966 - val_loss: 1.4054 - val_accuracy: 0.2237
# Epoch 26/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9951 - accuracy: 0.4972 - val_loss: 1.3829 - val_accuracy: 0.2196
# Epoch 27/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9960 - accuracy: 0.4948 - val_loss: 1.4111 - val_accuracy: 0.2253
# Epoch 28/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9960 - accuracy: 0.4967 - val_loss: 1.3471 - val_accuracy: 0.2237
# Epoch 29/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9941 - accuracy: 0.4951 - val_loss: 1.4460 - val_accuracy: 0.2245
# Epoch 30/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9924 - accuracy: 0.4950 - val_loss: 1.3762 - val_accuracy: 0.2229
# Epoch 31/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9933 - accuracy: 0.4958 - val_loss: 1.3577 - val_accuracy: 0.2212
# Epoch 32/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9922 - accuracy: 0.4941 - val_loss: 1.3321 - val_accuracy: 0.2245
# Epoch 33/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9928 - accuracy: 0.4987 - val_loss: 1.4279 - val_accuracy: 0.2188
# Epoch 34/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9914 - accuracy: 0.4948 - val_loss: 1.4843 - val_accuracy: 0.2245
# Epoch 35/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9935 - accuracy: 0.4959 - val_loss: 1.3453 - val_accuracy: 0.2261
# Epoch 36/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9915 - accuracy: 0.5000 - val_loss: 1.3317 - val_accuracy: 0.2220
# Epoch 37/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9914 - accuracy: 0.5011 - val_loss: 1.4220 - val_accuracy: 0.2237
# Epoch 38/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9890 - accuracy: 0.4979 - val_loss: 1.3963 - val_accuracy: 0.2237
# Epoch 39/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9904 - accuracy: 0.4984 - val_loss: 1.2995 - val_accuracy: 0.2204
# Epoch 40/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9898 - accuracy: 0.4996 - val_loss: 1.4554 - val_accuracy: 0.2212
# Epoch 41/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9911 - accuracy: 0.4951 - val_loss: 1.4033 - val_accuracy: 0.2220
# Epoch 42/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9889 - accuracy: 0.4971 - val_loss: 1.4943 - val_accuracy: 0.2204
# Epoch 43/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9881 - accuracy: 0.4993 - val_loss: 1.4243 - val_accuracy: 0.2220
# Epoch 44/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9899 - accuracy: 0.4977 - val_loss: 1.3334 - val_accuracy: 0.2212
# Epoch 45/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9871 - accuracy: 0.4987 - val_loss: 1.3198 - val_accuracy: 0.2220
# Epoch 46/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9855 - accuracy: 0.4999 - val_loss: 1.3755 - val_accuracy: 0.2196
# Epoch 47/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.9871 - accuracy: 0.4973 - val_loss: 1.4090 - val_accuracy: 0.2253
# Epoch 48/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.9846 - accuracy: 0.4980 - val_loss: 1.4424 - val_accuracy: 0.2229
# Epoch 49/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.9847 - accuracy: 0.4991 - val_loss: 1.4816 - val_accuracy: 0.2253
# Epoch 50/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9854 - accuracy: 0.4958 - val_loss: 1.3212 - val_accuracy: 0.2212
# Epoch 51/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9851 - accuracy: 0.4990 - val_loss: 1.3705 - val_accuracy: 0.2204
# Epoch 52/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9842 - accuracy: 0.4978 - val_loss: 1.3080 - val_accuracy: 0.2204
# Epoch 53/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9820 - accuracy: 0.5003 - val_loss: 1.3982 - val_accuracy: 0.2269
# Epoch 54/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9820 - accuracy: 0.5013 - val_loss: 1.3566 - val_accuracy: 0.2229
# Epoch 55/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9832 - accuracy: 0.5014 - val_loss: 1.4234 - val_accuracy: 0.2253
# Epoch 56/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9854 - accuracy: 0.4990 - val_loss: 1.3540 - val_accuracy: 0.2229
# Epoch 57/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9812 - accuracy: 0.5029 - val_loss: 1.3569 - val_accuracy: 0.2212
# Epoch 58/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9826 - accuracy: 0.5007 - val_loss: 1.3813 - val_accuracy: 0.2204
# Epoch 59/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9858 - accuracy: 0.4994 - val_loss: 1.3795 - val_accuracy: 0.2229
# Epoch 60/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9827 - accuracy: 0.5018 - val_loss: 1.4715 - val_accuracy: 0.2220
# Epoch 61/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9808 - accuracy: 0.4997 - val_loss: 1.4476 - val_accuracy: 0.2269
# Epoch 62/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9800 - accuracy: 0.5003 - val_loss: 1.2911 - val_accuracy: 0.2220
# Epoch 63/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9817 - accuracy: 0.5002 - val_loss: 1.3726 - val_accuracy: 0.2269
# Epoch 64/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9791 - accuracy: 0.5010 - val_loss: 1.3515 - val_accuracy: 0.2229
# Epoch 65/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9801 - accuracy: 0.4999 - val_loss: 1.4650 - val_accuracy: 0.2245
# Epoch 66/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9765 - accuracy: 0.5001 - val_loss: 1.3183 - val_accuracy: 0.2253
# Epoch 67/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9780 - accuracy: 0.5022 - val_loss: 1.3564 - val_accuracy: 0.2212
# Epoch 68/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9787 - accuracy: 0.4994 - val_loss: 1.5492 - val_accuracy: 0.2147
# Epoch 69/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9799 - accuracy: 0.4960 - val_loss: 1.4619 - val_accuracy: 0.2229
# Epoch 70/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9782 - accuracy: 0.5013 - val_loss: 1.2870 - val_accuracy: 0.2212
# Epoch 71/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9786 - accuracy: 0.5013 - val_loss: 1.4027 - val_accuracy: 0.2229
# Epoch 72/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9814 - accuracy: 0.5038 - val_loss: 1.3201 - val_accuracy: 0.2220
# Epoch 73/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9766 - accuracy: 0.5016 - val_loss: 1.4257 - val_accuracy: 0.2310
# Epoch 74/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9754 - accuracy: 0.4986 - val_loss: 1.2885 - val_accuracy: 0.2212
# Epoch 75/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9820 - accuracy: 0.5010 - val_loss: 1.3706 - val_accuracy: 0.2261
# Epoch 76/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9885 - accuracy: 0.4987 - val_loss: 1.3773 - val_accuracy: 0.2220
# Epoch 77/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9805 - accuracy: 0.4983 - val_loss: 1.3239 - val_accuracy: 0.2212
# Epoch 78/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9764 - accuracy: 0.5013 - val_loss: 1.3003 - val_accuracy: 0.2245
# Epoch 79/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9814 - accuracy: 0.5017 - val_loss: 1.4613 - val_accuracy: 0.2212
# Epoch 80/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9875 - accuracy: 0.4980 - val_loss: 1.4899 - val_accuracy: 0.2269
# Epoch 81/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9816 - accuracy: 0.5025 - val_loss: 1.3823 - val_accuracy: 0.2245
# Epoch 82/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9774 - accuracy: 0.5014 - val_loss: 1.4173 - val_accuracy: 0.2245
# Epoch 83/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9758 - accuracy: 0.5003 - val_loss: 1.3706 - val_accuracy: 0.2204
# Epoch 84/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9748 - accuracy: 0.5010 - val_loss: 1.4601 - val_accuracy: 0.2212
# Epoch 85/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9776 - accuracy: 0.5004 - val_loss: 1.4720 - val_accuracy: 0.2196
# Epoch 86/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9751 - accuracy: 0.5038 - val_loss: 1.3507 - val_accuracy: 0.2229
# Epoch 87/100
# 848/848 [==============================] - 13s 16ms/step - loss: 0.9721 - accuracy: 0.5038 - val_loss: 1.2947 - val_accuracy: 0.2229
# Epoch 88/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9729 - accuracy: 0.5060 - val_loss: 1.3184 - val_accuracy: 0.2220
# Epoch 89/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.9708 - accuracy: 0.5046 - val_loss: 1.4724 - val_accuracy: 0.2278
# Epoch 90/100
# 848/848 [==============================] - 14s 17ms/step - loss: 0.9736 - accuracy: 0.5030 - val_loss: 1.2447 - val_accuracy: 0.2204
# Epoch 91/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9760 - accuracy: 0.5046 - val_loss: 1.3712 - val_accuracy: 0.2212
# Epoch 92/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9711 - accuracy: 0.5022 - val_loss: 1.3070 - val_accuracy: 0.2220
# Epoch 93/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9716 - accuracy: 0.5015 - val_loss: 1.3931 - val_accuracy: 0.2196
# Epoch 94/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9736 - accuracy: 0.5000 - val_loss: 1.4094 - val_accuracy: 0.2261
# Epoch 95/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9727 - accuracy: 0.5044 - val_loss: 1.2966 - val_accuracy: 0.2229
# Epoch 96/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9745 - accuracy: 0.5014 - val_loss: 1.5098 - val_accuracy: 0.2229
# Epoch 97/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9720 - accuracy: 0.5015 - val_loss: 1.4051 - val_accuracy: 0.2253
# Epoch 98/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9764 - accuracy: 0.5040 - val_loss: 1.6296 - val_accuracy: 0.2261
# Epoch 99/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9721 - accuracy: 0.4996 - val_loss: 1.4361 - val_accuracy: 0.2229
# Epoch 100/100
# 848/848 [==============================] - 14s 16ms/step - loss: 0.9706 - accuracy: 0.5049 - val_loss: 1.3508 - val_accuracy: 0.2204
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 4, 4, 2048)        23564800
#
#  global_max_pooling2d_1 (Glo  (None, 2048)             0
#  balMaxPooling2D)
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 24,615,427
# Trainable params: 24,569,987
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/30
# 848/848 [==============================] - 44s 49ms/step - loss: 1.6774 - accuracy: 0.5774 - val_loss: 0.9546 - val_accuracy: 0.6294
# Epoch 2/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8453 - accuracy: 0.6064 - val_loss: 0.9695 - val_accuracy: 0.6294
# Epoch 3/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8335 - accuracy: 0.6149 - val_loss: 3.9065 - val_accuracy: 0.1543
# Epoch 4/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8345 - accuracy: 0.6132 - val_loss: 1.1446 - val_accuracy: 0.2180
# Epoch 5/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8298 - accuracy: 0.6107 - val_loss: 2.1115 - val_accuracy: 0.1527
# Epoch 6/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8305 - accuracy: 0.6115 - val_loss: 1.1200 - val_accuracy: 0.2180
# Epoch 7/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8295 - accuracy: 0.6194 - val_loss: 1.2320 - val_accuracy: 0.2180
# Epoch 8/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8161 - accuracy: 0.6241 - val_loss: 1.8671 - val_accuracy: 0.1527
# Epoch 9/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.9254 - accuracy: 0.5544 - val_loss: 24.4142 - val_accuracy: 0.1527
# Epoch 10/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8587 - accuracy: 0.5983 - val_loss: 12.9188 - val_accuracy: 0.1527
# Epoch 11/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8411 - accuracy: 0.6088 - val_loss: 35.7824 - val_accuracy: 0.1527
# Epoch 12/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8526 - accuracy: 0.6120 - val_loss: 16.7829 - val_accuracy: 0.1527
# Epoch 13/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8306 - accuracy: 0.6242 - val_loss: 1.0092 - val_accuracy: 0.6294
# Epoch 14/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8207 - accuracy: 0.6256 - val_loss: 43.4528 - val_accuracy: 0.1527
# Epoch 15/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8201 - accuracy: 0.6246 - val_loss: 1.0465 - val_accuracy: 0.6294
# Epoch 16/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8030 - accuracy: 0.6427 - val_loss: 40.6404 - val_accuracy: 0.1527
# Epoch 17/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8189 - accuracy: 0.6337 - val_loss: 4.4734 - val_accuracy: 0.1527
# Epoch 18/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8053 - accuracy: 0.6436 - val_loss: 37.0691 - val_accuracy: 0.1527
# Epoch 19/30
# 848/848 [==============================] - 40s 47ms/step - loss: 0.8015 - accuracy: 0.6535 - val_loss: 69.5854 - val_accuracy: 0.1527
# Epoch 20/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.7994 - accuracy: 0.6499 - val_loss: 5.2767 - val_accuracy: 0.1527
# Epoch 21/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.8359 - accuracy: 0.6264 - val_loss: 1.2498 - val_accuracy: 0.2180
# Epoch 22/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.8334 - accuracy: 0.6230 - val_loss: 1.2055 - val_accuracy: 0.2180
# Epoch 23/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.8152 - accuracy: 0.6361 - val_loss: 1.0496 - val_accuracy: 0.6294
# Epoch 24/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.8292 - accuracy: 0.6271 - val_loss: 1.2143 - val_accuracy: 0.2180
# Epoch 25/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.8027 - accuracy: 0.6470 - val_loss: 99.1052 - val_accuracy: 0.1527
# Epoch 26/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.7907 - accuracy: 0.6493 - val_loss: 1.5238 - val_accuracy: 0.6294
# Epoch 27/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.7645 - accuracy: 0.6669 - val_loss: 96.8232 - val_accuracy: 0.1527
# Epoch 28/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.7770 - accuracy: 0.6587 - val_loss: 1.3774 - val_accuracy: 0.1527
# Epoch 29/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.7853 - accuracy: 0.6385 - val_loss: 1.3276 - val_accuracy: 0.1527
# Epoch 30/30
# 848/848 [==============================] - 39s 46ms/step - loss: 0.7823 - accuracy: 0.6604 - val_loss: 1.4707 - val_accuracy: 0.6294
# 39/39 [==============================] - 1s 24ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       208
#            1       0.00      0.00      0.00       250
#            2       0.63      1.00      0.77       767
#
#     accuracy                           0.63      1225
#    macro avg       0.21      0.33      0.26      1225
# weighted avg       0.39      0.63      0.48      1225
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
####################################################################################################################
# All steps are the same as above, we change the model and top layers for specific model
learning_rate = [0.001]
batch_size = [16]
dropouts = [0.2]
model_name = "ResNet50V2" 
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)
####################################################################################################################
for i in learning_rate:
    for j in batch_size:
        for d in dropouts:
            ####################################################################################################################
            print(f'Running: \n learning rate:{i}, batch size: {j} with dropout: {d} for epochs: {epochs}')
            ####################################################################################################################
            base_model = keras.applications.ResNet50V2(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 
            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False
            ####################################################################################################################
            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(512, activation='relu'),  
                tf.keras.layers.Dropout(d),
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            ####################################################################################################################
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])
            ####################################################################################################################
            cp_filepath = '{} lr{} batch size{} dropout{}.h5'.format(model_name, i,j,d)
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            ####################################################################################################################
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            model = tf.keras.models.load_model(cp_filepath)
            #################################################################################################################### 
            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])
            cp_filepath = 'ft {} lr{} batch size{} dropout{}.h5'.format(model_name, i,j,d)
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')        
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')
            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)
            model = tf.keras.models.load_model(cp_filepath)
            model_metrics(model, X_test, y_test)
# Out:
# Running:
#  learning rate:0.001, batch size: 16 with dropout: 0.2 for epochs: 100
# Epoch 1/100
# 848/848 [==============================] - 16s 17ms/step - loss: 1.0619 - accuracy: 0.4576 - val_loss: 1.3194 - val_accuracy: 0.2180
# Epoch 2/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0263 - accuracy: 0.4768 - val_loss: 1.4640 - val_accuracy: 0.2180
# Epoch 3/100
# 848/848 [==============================] - 13s 15ms/step - loss: 1.0251 - accuracy: 0.4768 - val_loss: 1.5929 - val_accuracy: 0.2180
# Epoch 4/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0248 - accuracy: 0.4757 - val_loss: 1.3228 - val_accuracy: 0.2180
# Epoch 5/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0232 - accuracy: 0.4768 - val_loss: 1.3354 - val_accuracy: 0.2180
# Epoch 6/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0223 - accuracy: 0.4768 - val_loss: 1.3924 - val_accuracy: 0.2180
# Epoch 7/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0218 - accuracy: 0.4768 - val_loss: 1.3564 - val_accuracy: 0.2180
# Epoch 8/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4105 - val_accuracy: 0.2180
# Epoch 9/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0199 - accuracy: 0.4768 - val_loss: 1.4089 - val_accuracy: 0.2180
# Epoch 10/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0198 - accuracy: 0.4768 - val_loss: 1.4444 - val_accuracy: 0.2180
# Epoch 11/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4484 - val_accuracy: 0.2180
# Epoch 12/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4491 - val_accuracy: 0.2180
# Epoch 13/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4483 - val_accuracy: 0.2180
# Epoch 14/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4492 - val_accuracy: 0.2180
# Epoch 15/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4508 - val_accuracy: 0.2180
# Epoch 16/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4488 - val_accuracy: 0.2180
# Epoch 17/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4467 - val_accuracy: 0.2180
# Epoch 18/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4477 - val_accuracy: 0.2180
# Epoch 19/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4425 - val_accuracy: 0.2180
# Epoch 20/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4466 - val_accuracy: 0.2180
# Epoch 21/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4509 - val_accuracy: 0.2180
# Epoch 22/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4548 - val_accuracy: 0.2180
# Epoch 23/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4474 - val_accuracy: 0.2180
# Epoch 24/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4456 - val_accuracy: 0.2180
# Epoch 25/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4478 - val_accuracy: 0.2180
# Epoch 26/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4487 - val_accuracy: 0.2180
# Epoch 27/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4480 - val_accuracy: 0.2180
# Epoch 28/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4504 - val_accuracy: 0.2180
# Epoch 29/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4484 - val_accuracy: 0.2180
# Epoch 30/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4495 - val_accuracy: 0.2180
# Epoch 31/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4495 - val_accuracy: 0.2180
# Epoch 32/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4457 - val_accuracy: 0.2180
# Epoch 33/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4386 - val_accuracy: 0.2180
# Epoch 34/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4462 - val_accuracy: 0.2180
# Epoch 35/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4445 - val_accuracy: 0.2180
# Epoch 36/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4406 - val_accuracy: 0.2180
# Epoch 37/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4485 - val_accuracy: 0.2180
# Epoch 38/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4527 - val_accuracy: 0.2180
# Epoch 39/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4505 - val_accuracy: 0.2180
# Epoch 40/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4434 - val_accuracy: 0.2180
# Epoch 41/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4466 - val_accuracy: 0.2180
# Epoch 42/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4463 - val_accuracy: 0.2180
# Epoch 43/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4530 - val_accuracy: 0.2180
# Epoch 44/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4534 - val_accuracy: 0.2180
# Epoch 45/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4448 - val_accuracy: 0.2180
# Epoch 46/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4487 - val_accuracy: 0.2180
# Epoch 47/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4401 - val_accuracy: 0.2180
# Epoch 48/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4439 - val_accuracy: 0.2180
# Epoch 49/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4372 - val_accuracy: 0.2180
# Epoch 50/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4465 - val_accuracy: 0.2180
# Epoch 51/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4569 - val_accuracy: 0.2180
# Epoch 52/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4490 - val_accuracy: 0.2180
# Epoch 53/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4478 - val_accuracy: 0.2180
# Epoch 54/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4438 - val_accuracy: 0.2180
# Epoch 55/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4499 - val_accuracy: 0.2180
# Epoch 56/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4474 - val_accuracy: 0.2180
# Epoch 57/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4409 - val_accuracy: 0.2180
# Epoch 58/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4447 - val_accuracy: 0.2180
# Epoch 59/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4436 - val_accuracy: 0.2180
# Epoch 60/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4540 - val_accuracy: 0.2180
# Epoch 61/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4469 - val_accuracy: 0.2180
# Epoch 62/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4406 - val_accuracy: 0.2180
# Epoch 63/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4426 - val_accuracy: 0.2180
# Epoch 64/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4581 - val_accuracy: 0.2180
# Epoch 65/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4475 - val_accuracy: 0.2180
# Epoch 66/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4526 - val_accuracy: 0.2180
# Epoch 67/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4435 - val_accuracy: 0.2180
# Epoch 68/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4504 - val_accuracy: 0.2180
# Epoch 69/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0195 - accuracy: 0.4768 - val_loss: 1.4469 - val_accuracy: 0.2180
# Epoch 70/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4382 - val_accuracy: 0.2180
# Epoch 71/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4465 - val_accuracy: 0.2180
# Epoch 72/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4475 - val_accuracy: 0.2180
# Epoch 73/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4491 - val_accuracy: 0.2180
# Epoch 74/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4467 - val_accuracy: 0.2180
# Epoch 75/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4470 - val_accuracy: 0.2180
# Epoch 76/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4382 - val_accuracy: 0.2180
# Epoch 77/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4423 - val_accuracy: 0.2180
# Epoch 78/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4430 - val_accuracy: 0.2180
# Epoch 79/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4494 - val_accuracy: 0.2180
# Epoch 80/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4485 - val_accuracy: 0.2180
# Epoch 81/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4489 - val_accuracy: 0.2180
# Epoch 82/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4450 - val_accuracy: 0.2180
# Epoch 83/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4427 - val_accuracy: 0.2180
# Epoch 84/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4495 - val_accuracy: 0.2180
# Epoch 85/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4546 - val_accuracy: 0.2180
# Epoch 86/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4481 - val_accuracy: 0.2180
# Epoch 87/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4460 - val_accuracy: 0.2180
# Epoch 88/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4479 - val_accuracy: 0.2180
# Epoch 89/100
# 848/848 [==============================] - 14s 17ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4457 - val_accuracy: 0.2180
# Epoch 90/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4490 - val_accuracy: 0.2180
# Epoch 91/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4481 - val_accuracy: 0.2180
# Epoch 92/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4457 - val_accuracy: 0.2180
# Epoch 93/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4475 - val_accuracy: 0.2180
# Epoch 94/100
# 848/848 [==============================] - 14s 17ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4444 - val_accuracy: 0.2180
# Epoch 95/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4433 - val_accuracy: 0.2180
# Epoch 96/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4443 - val_accuracy: 0.2180
# Epoch 97/100
# 848/848 [==============================] - 14s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4455 - val_accuracy: 0.2180
# Epoch 98/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4461 - val_accuracy: 0.2180
# Epoch 99/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4527 - val_accuracy: 0.2180
# Epoch 100/100
# 848/848 [==============================] - 13s 16ms/step - loss: 1.0195 - accuracy: 0.4768 - val_loss: 1.4487 - val_accuracy: 0.2180
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 4, 4, 2048)        23564800
#
#  global_max_pooling2d_2 (Glo  (None, 2048)             0
#  balMaxPooling2D)
#
#  dense_4 (Dense)             (None, 512)               1049088
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 24,615,427
# Trainable params: 24,569,987
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/30
# 848/848 [==============================] - 43s 48ms/step - loss: 1.1188 - accuracy: 0.4647 - val_loss: 1.4395 - val_accuracy: 0.2180
# Epoch 2/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0264 - accuracy: 0.4734 - val_loss: 1.3922 - val_accuracy: 0.2180
# Epoch 3/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0268 - accuracy: 0.4740 - val_loss: 1.7168 - val_accuracy: 0.2180
# Epoch 4/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0230 - accuracy: 0.4761 - val_loss: 1.4158 - val_accuracy: 0.2180
# Epoch 5/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0234 - accuracy: 0.4761 - val_loss: 1.9568 - val_accuracy: 0.2180
# Epoch 6/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0257 - accuracy: 0.4760 - val_loss: 1.5230 - val_accuracy: 0.2180
# Epoch 7/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0231 - accuracy: 0.4762 - val_loss: 3.4245 - val_accuracy: 0.2180
# Epoch 8/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0235 - accuracy: 0.4766 - val_loss: 1.3887 - val_accuracy: 0.2180
# Epoch 9/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0209 - accuracy: 0.4768 - val_loss: 1.4091 - val_accuracy: 0.2180
# Epoch 10/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4260 - val_accuracy: 0.2180
# Epoch 11/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0241 - accuracy: 0.4750 - val_loss: 1.4362 - val_accuracy: 0.2180
# Epoch 12/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4414 - val_accuracy: 0.2180
# Epoch 13/30
# 848/848 [==============================] - 39s 46ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4479 - val_accuracy: 0.2180
# Epoch 14/30
# 848/848 [==============================] - 40s 47ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4459 - val_accuracy: 0.2180
# Epoch 15/30
# 848/848 [==============================] - 40s 47ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4481 - val_accuracy: 0.2180
# Epoch 16/30
# 848/848 [==============================] - 40s 47ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4488 - val_accuracy: 0.2180
# Epoch 17/30
# 848/848 [==============================] - 40s 47ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4571 - val_accuracy: 0.2180
# Epoch 18/30
# 848/848 [==============================] - 40s 48ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4521 - val_accuracy: 0.2180
# Epoch 19/30
# 848/848 [==============================] - 41s 48ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4524 - val_accuracy: 0.2180
# Epoch 20/30
# 848/848 [==============================] - 40s 47ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4505 - val_accuracy: 0.2180
# Epoch 21/30
# 848/848 [==============================] - 40s 47ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4498 - val_accuracy: 0.2180
# Epoch 22/30
# 848/848 [==============================] - 40s 48ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4463 - val_accuracy: 0.2180
# Epoch 23/30
# 848/848 [==============================] - 41s 48ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4431 - val_accuracy: 0.2180
# Epoch 24/30
# 848/848 [==============================] - 40s 47ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4421 - val_accuracy: 0.2180
# Epoch 25/30
# 848/848 [==============================] - 40s 48ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4513 - val_accuracy: 0.2180
# Epoch 26/30
# 848/848 [==============================] - 40s 48ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4485 - val_accuracy: 0.2180
# Epoch 27/30
# 848/848 [==============================] - 41s 48ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4436 - val_accuracy: 0.2180
# Epoch 28/30
# 848/848 [==============================] - 40s 47ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4498 - val_accuracy: 0.2180
# Epoch 29/30
# 848/848 [==============================] - 41s 48ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4448 - val_accuracy: 0.2180
# Epoch 30/30
# 848/848 [==============================] - 41s 48ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4453 - val_accuracy: 0.2180
# 39/39 [==============================] - 1s 27ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       208
#            1       0.20      1.00      0.34       250
#            2       0.00      0.00      0.00       767
#
#     accuracy                           0.20      1225
#    macro avg       0.07      0.33      0.11      1225
# weighted avg       0.04      0.20      0.07      1225
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Comparison of best model metrics

# %%
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
fig = plt.figure(figsize=[10, 10])
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)

ax = fig.add_subplot(spec2[0,0])
ax.plot(ft_histories[0].history['loss'], label='Run1')
ax.plot(ft_histories[1].history['loss'], label='Run2')
ax.plot(ft_histories[2].history['loss'], label='Run3')
plt.title("Training loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[0,1])
ax.plot(ft_histories[0].history['accuracy'], label='Run1')
ax.plot(ft_histories[1].history['accuracy'], label='Run2')
ax.plot(ft_histories[2].history['accuracy'], label='Run3')
plt.title("Training accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[1,0])
ax.plot(ft_histories[0].history['val_loss'], label='Run1')
ax.plot(ft_histories[1].history['val_loss'], label='Run2')
ax.plot(ft_histories[2].history['val_loss'], label='Run3')


plt.title("Validation loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0,4])
plt.legend()

ax = fig.add_subplot(spec2[1,1])
ax.plot(ft_histories[0].history['val_accuracy'], label='Run1')
ax.plot(ft_histories[1].history['val_accuracy'], label='Run2')
ax.plot(ft_histories[2].history['val_accuracy'], label='Run3')

plt.title("Validation accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

plt.savefig('fintuned_metrics.png')
plt.show()

# %%
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
fig = plt.figure(figsize=[10, 10])
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)

ax = fig.add_subplot(spec2[0,0])
ax.plot(histories[0].history['loss'], label='Run1')
ax.plot(histories[1].history['loss'], label='Run2')
ax.plot(histories[2].history['loss'], label='Run3')
plt.title("Training loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[0,1])
ax.plot(histories[0].history['accuracy'], label='Run1')
ax.plot(histories[1].history['accuracy'], label='Run2')
ax.plot(histories[2].history['accuracy'], label='Run3')
plt.title("Training accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[1,0])
ax.plot(histories[0].history['val_loss'], label='Run1')
ax.plot(histories[1].history['val_loss'], label='Run2')
ax.plot(histories[2].history['val_loss'], label='Run3')


plt.title("Validation loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0,4])
plt.legend()

ax = fig.add_subplot(spec2[1,1])
ax.plot(histories[0].history['val_accuracy'], label='Run1')
ax.plot(histories[1].history['val_accuracy'], label='Run2')
ax.plot(histories[2].history['val_accuracy'], label='Run3')

plt.title("Validation accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

plt.savefig('fintuned_metrics.png')
plt.show()
