# %% [markdown]
# # --

# %% [markdown]
# ## Setup

# %% [markdown]
# * IMPORT

# %%
import keras
import numpy as np
from numpy import ma
import json
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import  classification_report, confusion_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
import random

# %% [markdown]
# * set random state

# %%
random_state = 42

# %% [markdown]
# # Data

# %% [markdown]
# * LOAD DATA

# %%
# Load all data and labels
ccFieldsAll = np.load("C:/Users/mkoli/Syddansk Universitet/Morten Thyrring Stouenberg - Speciale2023/Data/AllNoAlt/ccLastImageNoCloudIndex0_6234.npy", allow_pickle=True)
labels = np.load("C:/Users/mkoli/Syddansk Universitet/Morten Thyrring Stouenberg - Speciale2023/Data/AllNoAlt/reLabelsAll.npy", allow_pickle=True)

# Cloud probability band subset
cloud_probability = ccFieldsAll[:len(labels),:,:,7]

# Subset data to true labels
ccFieldsAll = ccFieldsAll[:len(labels),:,:,[2,1,0]]

# %% [markdown]
# * Normalize color bands

# %%
# Initiate function to normalize color bands to fit the preprocessing functions for tensorflow applications transfer learning models
def normalize(band):
    band_min, band_max = (band.min(), band.max())
    return (((band-band_min)/((band_max - band_min)))*255)

# We use function for the visible bands - RGB
ccFieldsAll[:,:,:,0] = normalize(ccFieldsAll[:,:,:,0])
ccFieldsAll[:,:,:,1] = normalize(ccFieldsAll[:,:,:,1])
ccFieldsAll[:,:,:,2] = normalize(ccFieldsAll[:,:,:,2])

# %%
# We Set cloud tolerance, between 0-255
cloud_tolerance = 40
    
# We loop in the fields by the length of the dataset
for i in range(len(ccFieldsAll)):
    # we subset the image we are at in the loop
    image = ccFieldsAll[i,:,:,:]    
    # We create and apply a mask based on cloud probability over a certain value
    # We use np.logical because np.where did not work for me at the moment
    mask = np.logical_and(cloud_probability[i, :, :,] >= cloud_tolerance, cloud_probability[i, :, :] <= 256)
    # We set all masked pixels to zero, to black out cloud covered parts
    # I do not know why but it didn't work when i did not make a copy. It is just one of those times. 
    masked = image.copy()
    masked[mask] = 0
    # We are replacing the current image with the one with applied cloud mask, if no clouds then nothing is removed.
    ccFieldsAll[i] = masked

# %% [markdown]
# * DELETE EMPTY IMAGES AND RESIZE

# %%
# we want to delete the all black images, this is done by only appending images with visible RGB bands not all black.

# Initiate list for images that did not get blacked out as well as a list for labels
ccFieldsNoCloud = []
LabelsNoCloud = []

# as we are looping in the images we resize them at the same time
# so we set the size of the images
size = 128

# We loop in all the images
for i in range(len(ccFieldsAll)):
    # if the image is not all black
    if not np.all(ccFieldsAll[i] == 0):
        #we append the image and label
        ccFieldsNoCloud.append(tf.image.resize(ccFieldsAll[i], [size, size]))
        LabelsNoCloud.append(labels[i])

# We set the lists as arrays
ccFieldsNoCloud = np.array(ccFieldsNoCloud)
LabelsNoCloud   = np.array(LabelsNoCloud)

#And print the shapes to control the output and see how many fields are left. 
print(ccFieldsNoCloud.shape)
print(LabelsNoCloud.shape)
# Out:
# (6122, 128, 128, 3)
# (6122,)

# %% [markdown]
# * NEW DISTRIBUTION OF LABELS

# %%
#We investigate the new label distribution
print(f'Number of observations : {len(LabelsNoCloud)}')
# We count non zero indices and compute the percentage representation in the dataset. 
print(f'appearances of 0 in labels : {np.count_nonzero(LabelsNoCloud == 0)}({round(100*np.count_nonzero(LabelsNoCloud == 0)/len(LabelsNoCloud),2)}% of total)')
print(f'appearances of 1 in labels : {np.count_nonzero(LabelsNoCloud == 1)}({round(100*np.count_nonzero(LabelsNoCloud == 1)/len(LabelsNoCloud),2)}% of total)')
print(f'appearances of 2 in labels : {np.count_nonzero(LabelsNoCloud == 2)}({round(100*np.count_nonzero(LabelsNoCloud == 2)/len(LabelsNoCloud),2)}% of total)')
# Out:
# Number of observations : 6122
# appearances of 0 in labels : 999(16.32% of total)
# appearances of 1 in labels : 1325(21.64% of total)
# appearances of 2 in labels : 3798(62.04% of total)

# %% [markdown]
# ### CNN (RGB images)

# %%
# Data is split 80/20 for train and test
X_train, X_test, y_train, y_test = train_test_split(ccFieldsNoCloud, 
                                                    LabelsNoCloud, 
                                                    test_size=0.2, 
                                                    random_state=random_state)

# Train data is split 75/25, which corresponds to 20% of original 
# data as validation and 60% of original data as train
X_train, X_val, y_train, y_val = train_test_split(X_train, 
                                                  y_train, 
                                                  test_size=0.25, 
                                                  random_state=random_state) # 0.25 x 0.8 = 0.2

# Print the dataset shapes to inspect sizes
print(X_train.shape, y_train.shape) 
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (3672, 128, 128, 3) (3672,)
# (1225, 128, 128, 3) (1225,)
# (1225, 128, 128, 3) (1225,)

# %% [markdown]
# # Data augmentation

# %% [markdown]
# From: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
#Defining augmentaation method 
 
datagen = ImageDataGenerator(
    # Rotation range is set to 360 to enable images to get any rotational angle
    rotation_range      = 360,        
    # Zoom range is a conservative 0.2 to not get too big parts of the image out of bounds
    zoom_range          = 0.2,           
    # Brightness range is random between specified values to enable brightness adjustment due to sun or shadow from clouds
    brightness_range    = (0.8,1.2),    
    # Horisontal flip is enabled. I do not know if it is going to make a difference, but it is not going to hurt. 
    horizontal_flip     = True)

# %%
# We initiate lists for data and labels used for augmentation
data_for_augmentation = []
labels_for_augmentation = []

# We Loop Loop data and append fields to each class for single class data augmentation 
for i in range(len(y_train)):
  if y_train[i] == 0:
    data_for_augmentation.append(X_train[i])
    labels_for_augmentation.append(y_train[i])
  if y_train[i] == 1:
    data_for_augmentation.append(X_train[i])
    labels_for_augmentation.append(y_train[i])

# save as numpy arrays
data_for_augmentation    = np.asarray(data_for_augmentation)
labels_for_augmentation    = np.asarray(labels_for_augmentation)

# Check  array shape
print(f'data for augmentation : {data_for_augmentation.shape} labels for augmentation : {labels_for_augmentation.shape}')
# Out:
# data for augmentation : (1412, 128, 128, 3) labels for augmentation : (1412,)

# %%
# We set a specified number of images for augmentation per image in the dataset
num_samples_per_image = 7
# num_samples_per_image = 9
# num_samples_per_image = 11

# We reshaping data, i am not sure why, but stack overflow helped me get here.
aug_dataset            = data_for_augmentation.reshape(data_for_augmentation.shape[0], 
                                                      data_for_augmentation.shape[1], 
                                                      data_for_augmentation.shape[2], 
                                                      3)

# We initiate a list of labels for augmented data
labels_aug = []
# We create an empty list for the augmented images
augmented_images = []

# We loop in the length of the dataset
for i in range(len(aug_dataset)):
    # We loop in the desired amount of images augmented for each image
    for j in range(num_samples_per_image):
        # we subset the image
        img = data_for_augmentation[i]
        # we expand dimensions as described on the tensorflow website 
        # https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator 
        img = np.expand_dims(img, axis=0)
        # We use the datagen.flow to flow one image at the time into the augmenting imagedatagenerator
        # I am not entirely sure about the .next when using only one image but it works, in theory we do not need it but i do not want to remove something when it works. 
        augmented_img = datagen.flow(img, batch_size=1, shuffle=False).next()
        #as we have expanded the dimensiong we need to sqeeze it all back together for a functioning image again
        augmented_img = augmented_img.squeeze(axis=0)
        # We append the image and labels to our lists
        augmented_images.append(augmented_img)
        labels_aug.append(labels_for_augmentation[i])

#Turn it all into numpy arrays
labels_aug=np.asarray(labels_aug)
augmented_images=np.asarray(augmented_images)

# %%
# We concatenate the training data and the augmented data.
X_train = np.concatenate((X_train, augmented_images), axis=0)
y_train = np.concatenate((y_train, labels_aug), axis=0)

# %%
# We shuffle the data to ensure there is not only accepted fields in the start of the dataset
# we set a list of indexes that is randomly shuffled
idx = np.random.permutation(len(X_train))
# We use these indexes to set the images with corresponding labels
X_train,y_train = X_train[idx], y_train[idx]

# %%
# again we print the distribution to see if it changed - and it did!
print(f'Number of observations : {len(y_train)}')

print(f'appearances of 0 in labels : {np.count_nonzero(y_train == 0)}({round(100*np.count_nonzero(y_train == 0)/len(y_train),2)}% of total)')
print(f'appearances of 1 in labels : {np.count_nonzero(y_train == 1)}({round(100*np.count_nonzero(y_train == 1)/len(y_train),2)}% of total)')
print(f'appearances of 2 in labels : {np.count_nonzero(y_train == 2)}({round(100*np.count_nonzero(y_train == 2)/len(y_train),2)}% of total)')
# Out:
# Number of observations : 13556
# appearances of 0 in labels : 4832(35.64% of total)
# appearances of 1 in labels : 6464(47.68% of total)
# appearances of 2 in labels : 2260(16.67% of total)

# %% [markdown]
# # Accuracy metrics function

# %% [markdown]
# * Function for classification report and confusion matrix

# %%
# We define a function that visualize the results by a classification report and a confusion matrix.

def model_metrics(model, x_test, y_test):
    # Generate predictions on the test set using model and test data.
    y_pred = model.predict(X_test)
    # We use argmax function to gain the predicted class from the probabilities. 
    y_pred_classes = np.argmax(y_pred, axis=1)
    # We print classification report using true labels and predicted labels
    print(classification_report(y_test, y_pred_classes))
    # We Generate a confusion matrix
    cm = confusion_matrix(y_test, y_pred_classes)
    # We define define the class labels
    class_names = ['Failed (0)', 'Partially (1)', 'Accepted (2)']
    # We Plot the confusion matrix
    plt.figure(figsize=(8, 6))
    # show confusion matrix, cmap is the color scheme for matplotlib
    plt.imshow(cm, cmap=plt.cm.OrRd)
    # we set title and labels for plot
    plt.title(f'Confusion Matrix \n {cp_filepath}')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    # we set ticks
    plt.xticks(np.arange(len(class_names)), class_names, rotation=45)
    plt.yticks(np.arange(len(class_names)), class_names)
    plt.colorbar()
    # We add labels to the plot
    for k in range(len(class_names)):
        for h in range(len(class_names)):
            plt.text(h, k, cm[k, h], ha='center', va='center', color='black')
    plt.show()

# %% [markdown]
# # Training histories

# %%
histories = []
name = []

ft_histories = []
ft_name = []

# %% [markdown]
# # Best model runs for comparison

# %%
# VGG19 model
X_train = tf.keras.applications.vgg19.preprocess_input(X_trainx, data_format=None)
X_test = tf.keras.applications.vgg19.preprocess_input(X_testx, data_format=None)
X_val = tf.keras.applications.vgg19.preprocess_input(X_valx, data_format=None)
####################################################################################################################
#          We define our hyperparameters and model specifics. everything is in the same cell for convenience
learning_rate = [0.0001]
batch_size = [32]
model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)
####################################################################################################################
#           As this is the comparison only one model for each model
####################################################################################################################
#           We loop in our hyperparameters, this is only one as we are doing the best model run
for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')
            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 
            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 
            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False
            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            ####################################################################################################################
            #       We Compile our model
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])
            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.
            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)
            #We initiate a callback to save the best model
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            #       We append history and name of model to lists for training history comparison
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)
            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model, all the steps are almost identical to above
            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])
            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')  
                    
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')
            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])

            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            model_metrics(model, X_test, y_test)
# Out:
# Running:
#  learning rate:0.0001, batch size: 32 for epochs: 100
# Epoch 1/100
# 424/424 [==============================] - 29s 51ms/step - loss: 1.1873 - accuracy: 0.5430 - val_loss: 1.3446 - val_accuracy: 0.4310
# Epoch 2/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.7029 - accuracy: 0.6689 - val_loss: 1.0835 - val_accuracy: 0.5543
# Epoch 3/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.5366 - accuracy: 0.7591 - val_loss: 1.1549 - val_accuracy: 0.5518
# Epoch 4/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.3852 - accuracy: 0.8418 - val_loss: 1.2304 - val_accuracy: 0.5306
# Epoch 5/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.2489 - accuracy: 0.9090 - val_loss: 1.4863 - val_accuracy: 0.5282
# Epoch 6/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.1584 - accuracy: 0.9474 - val_loss: 1.5693 - val_accuracy: 0.5796
# Epoch 7/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0973 - accuracy: 0.9732 - val_loss: 1.6834 - val_accuracy: 0.5624
# Epoch 8/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0848 - accuracy: 0.9754 - val_loss: 1.8951 - val_accuracy: 0.5910
# Epoch 9/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.0687 - accuracy: 0.9802 - val_loss: 1.9165 - val_accuracy: 0.6065
# Epoch 10/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0571 - accuracy: 0.9835 - val_loss: 2.3959 - val_accuracy: 0.5616
# Epoch 11/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.0751 - accuracy: 0.9763 - val_loss: 2.3043 - val_accuracy: 0.6131
# Epoch 12/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0644 - accuracy: 0.9798 - val_loss: 2.2132 - val_accuracy: 0.5518
# Epoch 13/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0288 - accuracy: 0.9935 - val_loss: 2.6809 - val_accuracy: 0.5445
# Epoch 14/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0684 - accuracy: 0.9769 - val_loss: 2.2134 - val_accuracy: 0.5543
# Epoch 15/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0198 - accuracy: 0.9962 - val_loss: 2.6029 - val_accuracy: 0.5641
# Epoch 16/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0158 - accuracy: 0.9961 - val_loss: 2.9781 - val_accuracy: 0.5633
# Epoch 17/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0781 - accuracy: 0.9731 - val_loss: 2.7607 - val_accuracy: 0.5233
# Epoch 18/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0333 - accuracy: 0.9895 - val_loss: 3.0181 - val_accuracy: 0.5151
# Epoch 19/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0153 - accuracy: 0.9961 - val_loss: 2.9496 - val_accuracy: 0.5486
# Epoch 20/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0381 - accuracy: 0.9864 - val_loss: 3.0281 - val_accuracy: 0.5731
# Epoch 21/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0429 - accuracy: 0.9848 - val_loss: 2.9731 - val_accuracy: 0.5322
# Epoch 22/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0243 - accuracy: 0.9925 - val_loss: 3.3015 - val_accuracy: 0.5494
# Epoch 23/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0439 - accuracy: 0.9861 - val_loss: 2.9365 - val_accuracy: 0.5453
# Epoch 24/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0173 - accuracy: 0.9951 - val_loss: 3.2167 - val_accuracy: 0.5486
# Epoch 25/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0233 - accuracy: 0.9914 - val_loss: 3.3429 - val_accuracy: 0.5094
# Epoch 26/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0244 - accuracy: 0.9922 - val_loss: 3.3776 - val_accuracy: 0.5078
# Epoch 27/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 3.4674 - val_accuracy: 0.5657
# Epoch 28/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 3.8015 - val_accuracy: 0.5314
# Epoch 29/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 3.7489 - val_accuracy: 0.5641
# Epoch 30/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 3.7698 - val_accuracy: 0.5551
# Epoch 31/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 3.8169 - val_accuracy: 0.5616
# Epoch 32/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 3.8926 - val_accuracy: 0.5600
# Epoch 33/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 3.9701 - val_accuracy: 0.5624
# Epoch 34/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 4.0958 - val_accuracy: 0.5608
# Epoch 35/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0904 - accuracy: 0.9701 - val_loss: 2.9044 - val_accuracy: 0.5151
# Epoch 36/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0613 - accuracy: 0.9782 - val_loss: 3.2049 - val_accuracy: 0.5176
# Epoch 37/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0320 - accuracy: 0.9908 - val_loss: 3.2952 - val_accuracy: 0.5347
# Epoch 38/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 3.6975 - val_accuracy: 0.5118
# Epoch 39/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0120 - accuracy: 0.9967 - val_loss: 3.4815 - val_accuracy: 0.5829
# Epoch 40/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 3.6020 - val_accuracy: 0.5567
# Epoch 41/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0218 - accuracy: 0.9930 - val_loss: 3.7472 - val_accuracy: 0.5698
# Epoch 42/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0316 - accuracy: 0.9889 - val_loss: 3.4455 - val_accuracy: 0.5796
# Epoch 43/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 3.9328 - val_accuracy: 0.5265
# Epoch 44/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0258 - accuracy: 0.9919 - val_loss: 3.7964 - val_accuracy: 0.5249
# Epoch 45/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0162 - accuracy: 0.9962 - val_loss: 3.6559 - val_accuracy: 0.5567
# Epoch 46/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0150 - accuracy: 0.9954 - val_loss: 3.8515 - val_accuracy: 0.5698
# Epoch 47/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0244 - accuracy: 0.9921 - val_loss: 4.1672 - val_accuracy: 0.5282
# Epoch 48/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 3.6586 - val_accuracy: 0.5641
# Epoch 49/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 4.5068 - val_accuracy: 0.5061
# Epoch 50/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.0291 - accuracy: 0.9904 - val_loss: 3.6118 - val_accuracy: 0.5453
# Epoch 51/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 3.9634 - val_accuracy: 0.5763
# Epoch 52/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 4.1341 - val_accuracy: 0.5567
# Epoch 53/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 4.2088 - val_accuracy: 0.5665
# Epoch 54/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 4.2906 - val_accuracy: 0.5649
# Epoch 55/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 4.3215 - val_accuracy: 0.5657
# Epoch 56/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 4.3503 - val_accuracy: 0.5649
# Epoch 57/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 4.4662 - val_accuracy: 0.5657
# Epoch 58/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0315 - accuracy: 0.9919 - val_loss: 2.9786 - val_accuracy: 0.5347
# Epoch 59/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0748 - accuracy: 0.9729 - val_loss: 3.1729 - val_accuracy: 0.5576
# Epoch 60/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 4.0474 - val_accuracy: 0.5518
# Epoch 61/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0107 - accuracy: 0.9959 - val_loss: 4.1817 - val_accuracy: 0.5420
# Epoch 62/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0099 - accuracy: 0.9963 - val_loss: 4.0922 - val_accuracy: 0.5755
# Epoch 63/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 4.1711 - val_accuracy: 0.5192
# Epoch 64/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0168 - accuracy: 0.9947 - val_loss: 4.0812 - val_accuracy: 0.5469
# Epoch 65/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 4.2975 - val_accuracy: 0.5559
# Epoch 66/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 3.8914 - val_accuracy: 0.5535
# Epoch 67/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0149 - accuracy: 0.9954 - val_loss: 4.2491 - val_accuracy: 0.5673
# Epoch 68/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0292 - accuracy: 0.9911 - val_loss: 4.0752 - val_accuracy: 0.5592
# Epoch 69/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 4.3990 - val_accuracy: 0.5624
# Epoch 70/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 4.5724 - val_accuracy: 0.5682
# Epoch 71/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 4.7396 - val_accuracy: 0.5616
# Epoch 72/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 5.0126 - val_accuracy: 0.5616
# Epoch 73/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 5.2309 - val_accuracy: 0.5584
# Epoch 74/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 5.5181 - val_accuracy: 0.5641
# Epoch 75/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 5.7703 - val_accuracy: 0.5649
# Epoch 76/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 6.0126 - val_accuracy: 0.5624
# Epoch 77/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 5.9983 - val_accuracy: 0.5633
# Epoch 78/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 6.3424 - val_accuracy: 0.5576
# Epoch 79/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 6.5256 - val_accuracy: 0.5551
# Epoch 80/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0909 - accuracy: 0.9702 - val_loss: 4.1500 - val_accuracy: 0.5004
# Epoch 81/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0336 - accuracy: 0.9910 - val_loss: 3.7700 - val_accuracy: 0.5682
# Epoch 82/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 4.1501 - val_accuracy: 0.5535
# Epoch 83/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 4.7801 - val_accuracy: 0.5298
# Epoch 84/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 4.8632 - val_accuracy: 0.5469
# Epoch 85/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 5.4951 - val_accuracy: 0.5543
# Epoch 86/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 6.1131 - val_accuracy: 0.5543
# Epoch 87/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 6.4847 - val_accuracy: 0.5551
# Epoch 88/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 6.7527 - val_accuracy: 0.5559
# Epoch 89/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 6.8772 - val_accuracy: 0.5478
# Epoch 90/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 7.2817 - val_accuracy: 0.5616
# Epoch 91/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 7.6000 - val_accuracy: 0.5559
# Epoch 92/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0581 - accuracy: 0.9811 - val_loss: 3.6582 - val_accuracy: 0.5690
# Epoch 93/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0552 - accuracy: 0.9814 - val_loss: 4.5596 - val_accuracy: 0.5420
# Epoch 94/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 5.2509 - val_accuracy: 0.4678
# Epoch 95/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 5.3607 - val_accuracy: 0.5429
# Epoch 96/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0144 - accuracy: 0.9959 - val_loss: 5.0601 - val_accuracy: 0.5551
# Epoch 97/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 5.1890 - val_accuracy: 0.5837
# Epoch 98/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 4.3477 - val_accuracy: 0.5820
# Epoch 99/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 4.7483 - val_accuracy: 0.5771
# Epoch 100/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0201 - accuracy: 0.9950 - val_loss: 4.6704 - val_accuracy: 0.5902
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 424/424 [==============================] - 78s 169ms/step - loss: 0.7732 - accuracy: 0.6537 - val_loss: 0.7462 - val_accuracy: 0.6914
# Epoch 2/30
# 424/424 [==============================] - 69s 162ms/step - loss: 0.6009 - accuracy: 0.7400 - val_loss: 0.7516 - val_accuracy: 0.7135
# Epoch 3/30
# 424/424 [==============================] - 69s 162ms/step - loss: 0.5609 - accuracy: 0.7600 - val_loss: 0.6425 - val_accuracy: 0.7510
# Epoch 4/30
# 424/424 [==============================] - 69s 162ms/step - loss: 0.5192 - accuracy: 0.7755 - val_loss: 0.6300 - val_accuracy: 0.7616
# Epoch 5/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.5021 - accuracy: 0.7848 - val_loss: 0.6644 - val_accuracy: 0.7478
# Epoch 6/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.4724 - accuracy: 0.7948 - val_loss: 0.6813 - val_accuracy: 0.7510
# Epoch 7/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.4512 - accuracy: 0.8065 - val_loss: 0.7257 - val_accuracy: 0.7551
# Epoch 8/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.4078 - accuracy: 0.8246 - val_loss: 0.7408 - val_accuracy: 0.7502
# Epoch 9/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.3819 - accuracy: 0.8356 - val_loss: 0.6658 - val_accuracy: 0.7551
# Epoch 10/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.3404 - accuracy: 0.8560 - val_loss: 0.8873 - val_accuracy: 0.7437
# Epoch 11/30
# 424/424 [==============================] - 68s 159ms/step - loss: 0.2969 - accuracy: 0.8749 - val_loss: 1.1089 - val_accuracy: 0.6898
# Epoch 12/30
# 424/424 [==============================] - 68s 159ms/step - loss: 0.2501 - accuracy: 0.8972 - val_loss: 0.8783 - val_accuracy: 0.7224
# Epoch 13/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.2135 - accuracy: 0.9170 - val_loss: 1.1022 - val_accuracy: 0.7469
# Epoch 14/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.1733 - accuracy: 0.9329 - val_loss: 1.1180 - val_accuracy: 0.7412
# Epoch 15/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.1494 - accuracy: 0.9404 - val_loss: 1.1734 - val_accuracy: 0.7314
# Epoch 16/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.1256 - accuracy: 0.9527 - val_loss: 1.0470 - val_accuracy: 0.7192
# Epoch 17/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0939 - accuracy: 0.9655 - val_loss: 1.3954 - val_accuracy: 0.7298
# Epoch 18/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0938 - accuracy: 0.9661 - val_loss: 1.2474 - val_accuracy: 0.7600
# Epoch 19/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0695 - accuracy: 0.9732 - val_loss: 1.7015 - val_accuracy: 0.7371
# Epoch 20/30
# 424/424 [==============================] - 68s 159ms/step - loss: 0.0860 - accuracy: 0.9684 - val_loss: 1.3407 - val_accuracy: 0.7445
# Epoch 21/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.0621 - accuracy: 0.9784 - val_loss: 1.6138 - val_accuracy: 0.7355
# Epoch 22/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.0577 - accuracy: 0.9814 - val_loss: 1.5818 - val_accuracy: 0.7135
# Epoch 23/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.0652 - accuracy: 0.9771 - val_loss: 1.4305 - val_accuracy: 0.7347
# Epoch 24/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.0583 - accuracy: 0.9796 - val_loss: 1.7165 - val_accuracy: 0.6988
# Epoch 25/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.0642 - accuracy: 0.9800 - val_loss: 1.4524 - val_accuracy: 0.7412
# Epoch 26/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0659 - accuracy: 0.9777 - val_loss: 1.7766 - val_accuracy: 0.7306
# Epoch 27/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0498 - accuracy: 0.9835 - val_loss: 1.4003 - val_accuracy: 0.7200
# Epoch 28/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0496 - accuracy: 0.9821 - val_loss: 1.7662 - val_accuracy: 0.7069
# Epoch 29/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0349 - accuracy: 0.9886 - val_loss: 1.9761 - val_accuracy: 0.7167
# Epoch 30/30
# 424/424 [==============================] - 68s 159ms/step - loss: 0.0443 - accuracy: 0.9846 - val_loss: 1.6925 - val_accuracy: 0.7355
# 39/39 [==============================] - 2s 39ms/step
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.71       208
#            1       0.61      0.42      0.50       250
#            2       0.83      0.91      0.87       767
#
#     accuracy                           0.78      1225
#    macro avg       0.72      0.69      0.69      1225
# weighted avg       0.77      0.78      0.77      1225

# %%
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
fig = plt.figure(figsize=[10, 10])
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)

ax = fig.add_subplot(spec2[0,0])
ax.plot(ft_histories[0].history['loss'], label='Run1')
plt.title("Training loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[0,1])
ax.plot(ft_histories[0].history['accuracy'], label='Run1')
plt.title("Training accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[1,0])
ax.plot(ft_histories[0].history['val_loss'], label='Run1')


plt.title("Validation loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0,4])
plt.legend()

ax = fig.add_subplot(spec2[1,1])
ax.plot(ft_histories[0].history['val_accuracy'], label='Run1')

plt.title("Validation accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

plt.savefig('fintuned_metrics.png')
plt.show()

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
fig = plt.figure(figsize=[10, 10])
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)

ax = fig.add_subplot(spec2[0,0])
ax.plot(histories[0].history['loss'], label='Run1')
plt.title("Training loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[0,1])
ax.plot(histories[0].history['accuracy'], label='Run1')
plt.title("Training accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[1,0])
ax.plot(histories[0].history['val_loss'], label='Run1')


plt.title("Validation loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0,4])
plt.legend()

ax = fig.add_subplot(spec2[1,1])
ax.plot(histories[0].history['val_accuracy'], label='Run1')

plt.title("Validation accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

plt.savefig('fintuned_metrics.png')
plt.show()

# %%
####################################################################################################################
#          We define our hyperparameters and model specifics. everything is in the same cell for convenience
learning_rate = [0.0001]
batch_size = [32]
model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)
####################################################################################################################
#           As this is the comparison only one model for each model
####################################################################################################################
#           We loop in our hyperparameters, this is only one as we are doing the best model run
for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')
            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 
            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 
            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False
            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            ####################################################################################################################
            #       We Compile our model
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])
            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.
            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)
            #We initiate a callback to save the best model
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            #       We append history and name of model to lists for training history comparison
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)
            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model, all the steps are almost identical to above
            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])
            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')  
                    
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')
            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])

            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            model_metrics(model, X_test, y_test)
# Out:
# Running:
#  learning rate:0.0001, batch size: 32 for epochs: 100
# Epoch 1/100
# 424/424 [==============================] - 31s 51ms/step - loss: 1.2135 - accuracy: 0.5468 - val_loss: 1.1609 - val_accuracy: 0.5037
# Epoch 2/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.7031 - accuracy: 0.6658 - val_loss: 1.0650 - val_accuracy: 0.6196
# Epoch 3/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.5375 - accuracy: 0.7563 - val_loss: 1.2614 - val_accuracy: 0.5543
# Epoch 4/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.3855 - accuracy: 0.8365 - val_loss: 1.4569 - val_accuracy: 0.5257
# Epoch 5/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.2657 - accuracy: 0.8977 - val_loss: 1.4160 - val_accuracy: 0.5788
# Epoch 6/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.1622 - accuracy: 0.9488 - val_loss: 1.5552 - val_accuracy: 0.5829
# Epoch 7/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.1149 - accuracy: 0.9647 - val_loss: 1.7129 - val_accuracy: 0.5592
# Epoch 8/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0901 - accuracy: 0.9716 - val_loss: 1.8281 - val_accuracy: 0.5641
# Epoch 9/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0757 - accuracy: 0.9776 - val_loss: 2.0127 - val_accuracy: 0.5502
# Epoch 10/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0546 - accuracy: 0.9842 - val_loss: 2.0751 - val_accuracy: 0.5657
# Epoch 11/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0481 - accuracy: 0.9859 - val_loss: 2.5840 - val_accuracy: 0.5069
# Epoch 12/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0486 - accuracy: 0.9861 - val_loss: 2.3691 - val_accuracy: 0.5722
# Epoch 13/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0280 - accuracy: 0.9923 - val_loss: 2.5747 - val_accuracy: 0.5649
# Epoch 14/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0637 - accuracy: 0.9791 - val_loss: 2.7895 - val_accuracy: 0.5290
# Epoch 15/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0613 - accuracy: 0.9786 - val_loss: 2.4967 - val_accuracy: 0.5731
# Epoch 16/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0386 - accuracy: 0.9888 - val_loss: 2.6249 - val_accuracy: 0.5527
# Epoch 17/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0232 - accuracy: 0.9928 - val_loss: 2.8949 - val_accuracy: 0.5445
# Epoch 18/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0456 - accuracy: 0.9850 - val_loss: 2.6624 - val_accuracy: 0.5706
# Epoch 19/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0345 - accuracy: 0.9891 - val_loss: 2.9372 - val_accuracy: 0.5184
# Epoch 20/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0095 - accuracy: 0.9976 - val_loss: 3.1107 - val_accuracy: 0.5249
# Epoch 21/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 3.0644 - val_accuracy: 0.5747
# Epoch 22/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0565 - accuracy: 0.9798 - val_loss: 2.6982 - val_accuracy: 0.5820
# Epoch 23/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0485 - accuracy: 0.9838 - val_loss: 2.8394 - val_accuracy: 0.5322
# Epoch 24/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0162 - accuracy: 0.9956 - val_loss: 3.1591 - val_accuracy: 0.5576
# Epoch 25/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0212 - accuracy: 0.9928 - val_loss: 3.1088 - val_accuracy: 0.5584
# Epoch 26/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0321 - accuracy: 0.9892 - val_loss: 2.9724 - val_accuracy: 0.5796
# Epoch 27/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0296 - accuracy: 0.9906 - val_loss: 3.0073 - val_accuracy: 0.5894
# Epoch 28/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 3.3361 - val_accuracy: 0.5731
# Epoch 29/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0246 - accuracy: 0.9925 - val_loss: 3.3331 - val_accuracy: 0.5755
# Epoch 30/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0386 - accuracy: 0.9862 - val_loss: 2.9852 - val_accuracy: 0.5502
# Epoch 31/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 3.1177 - val_accuracy: 0.5829
# Epoch 32/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 3.2559 - val_accuracy: 0.5771
# Epoch 33/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 3.3568 - val_accuracy: 0.5747
# Epoch 34/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0020 - accuracy: 0.9989 - val_loss: 3.4218 - val_accuracy: 0.5682
# Epoch 35/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 3.4873 - val_accuracy: 0.5714
# Epoch 36/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 3.5713 - val_accuracy: 0.5722
# Epoch 37/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 3.6772 - val_accuracy: 0.5731
# Epoch 38/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.9477 - val_accuracy: 0.5690
# Epoch 39/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 4.5538 - val_accuracy: 0.5673
# Epoch 40/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.1083 - accuracy: 0.9643 - val_loss: 2.3948 - val_accuracy: 0.6122
# Epoch 41/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0542 - accuracy: 0.9813 - val_loss: 3.3178 - val_accuracy: 0.5216
# Epoch 42/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0262 - accuracy: 0.9913 - val_loss: 3.1839 - val_accuracy: 0.5665
# Epoch 43/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 3.4533 - val_accuracy: 0.5976
# Epoch 44/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 3.3369 - val_accuracy: 0.5518
# Epoch 45/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 3.6394 - val_accuracy: 0.5837
# Epoch 46/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 3.7093 - val_accuracy: 0.5551
# Epoch 47/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0391 - accuracy: 0.9864 - val_loss: 3.4026 - val_accuracy: 0.5812
# Epoch 48/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 3.7140 - val_accuracy: 0.5861
# Epoch 49/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 3.8417 - val_accuracy: 0.5567
# Epoch 50/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0310 - accuracy: 0.9891 - val_loss: 3.6022 - val_accuracy: 0.5641
# Epoch 51/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 3.7791 - val_accuracy: 0.5755
# Epoch 52/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 3.9775 - val_accuracy: 0.5624
# Epoch 53/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0202 - accuracy: 0.9942 - val_loss: 3.7657 - val_accuracy: 0.5502
# Epoch 54/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0196 - accuracy: 0.9941 - val_loss: 3.6700 - val_accuracy: 0.5641
# Epoch 55/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0153 - accuracy: 0.9961 - val_loss: 3.3353 - val_accuracy: 0.5796
# Epoch 56/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 3.8734 - val_accuracy: 0.5706
# Epoch 57/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 4.8527 - val_accuracy: 0.4931
# Epoch 58/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0348 - accuracy: 0.9890 - val_loss: 3.6509 - val_accuracy: 0.5690
# Epoch 59/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0214 - accuracy: 0.9924 - val_loss: 4.2009 - val_accuracy: 0.5445
# Epoch 60/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0211 - accuracy: 0.9925 - val_loss: 4.4433 - val_accuracy: 0.4988
# Epoch 61/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 4.0822 - val_accuracy: 0.5739
# Epoch 62/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 4.5036 - val_accuracy: 0.5576
# Epoch 63/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0019 - accuracy: 0.9991 - val_loss: 4.6050 - val_accuracy: 0.5731
# Epoch 64/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 4.7251 - val_accuracy: 0.5665
# Epoch 65/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 4.8474 - val_accuracy: 0.5624
# Epoch 66/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 4.8128 - val_accuracy: 0.5698
# Epoch 67/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 4.8448 - val_accuracy: 0.5771
# Epoch 68/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 5.1344 - val_accuracy: 0.5502
# Epoch 69/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0480 - accuracy: 0.9849 - val_loss: 3.3645 - val_accuracy: 0.5404
# Epoch 70/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0643 - accuracy: 0.9786 - val_loss: 3.8414 - val_accuracy: 0.5559
# Epoch 71/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 4.0861 - val_accuracy: 0.5665
# Epoch 72/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 4.3058 - val_accuracy: 0.5927
# Epoch 73/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 4.5963 - val_accuracy: 0.5265
# Epoch 74/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0330 - accuracy: 0.9900 - val_loss: 3.8732 - val_accuracy: 0.5682
# Epoch 75/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0157 - accuracy: 0.9958 - val_loss: 4.2470 - val_accuracy: 0.5812
# Epoch 76/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0107 - accuracy: 0.9959 - val_loss: 4.6028 - val_accuracy: 0.5576
# Epoch 77/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0237 - accuracy: 0.9931 - val_loss: 4.0357 - val_accuracy: 0.6041
# Epoch 78/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0134 - accuracy: 0.9956 - val_loss: 3.7870 - val_accuracy: 0.5731
# Epoch 79/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 4.3696 - val_accuracy: 0.5543
# Epoch 80/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0204 - accuracy: 0.9948 - val_loss: 4.2655 - val_accuracy: 0.5633
# Epoch 81/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 4.2752 - val_accuracy: 0.5567
# Epoch 82/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 4.5029 - val_accuracy: 0.5649
# Epoch 83/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 4.9060 - val_accuracy: 0.5306
# Epoch 84/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0342 - accuracy: 0.9894 - val_loss: 4.4540 - val_accuracy: 0.5869
# Epoch 85/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0152 - accuracy: 0.9941 - val_loss: 4.8112 - val_accuracy: 0.5682
# Epoch 86/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0124 - accuracy: 0.9966 - val_loss: 5.2890 - val_accuracy: 0.5641
# Epoch 87/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 4.3404 - val_accuracy: 0.5886
# Epoch 88/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0097 - accuracy: 0.9974 - val_loss: 5.2414 - val_accuracy: 0.5527
# Epoch 89/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0199 - accuracy: 0.9945 - val_loss: 4.5501 - val_accuracy: 0.5600
# Epoch 90/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 4.2243 - val_accuracy: 0.6073
# Epoch 91/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 5.3785 - val_accuracy: 0.5437
# Epoch 92/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 5.2802 - val_accuracy: 0.5747
# Epoch 93/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 5.8789 - val_accuracy: 0.5804
# Epoch 94/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 6.2571 - val_accuracy: 0.5763
# Epoch 95/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 6.2631 - val_accuracy: 0.5763
# Epoch 96/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 6.6800 - val_accuracy: 0.5731
# Epoch 97/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 6.8677 - val_accuracy: 0.5771
# Epoch 98/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 6.9503 - val_accuracy: 0.5747
# Epoch 99/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 7.2428 - val_accuracy: 0.5714
# Epoch 100/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 7.4665 - val_accuracy: 0.5722
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 424/424 [==============================] - 77s 166ms/step - loss: 1.0116 - accuracy: 0.4846 - val_loss: 0.7773 - val_accuracy: 0.7184
# Epoch 2/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.7184 - accuracy: 0.6934 - val_loss: 0.9724 - val_accuracy: 0.6090
# Epoch 3/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.6280 - accuracy: 0.7350 - val_loss: 0.8066 - val_accuracy: 0.7029
# Epoch 4/30
# 424/424 [==============================] - 68s 159ms/step - loss: 0.5954 - accuracy: 0.7522 - val_loss: 0.7292 - val_accuracy: 0.7363
# Epoch 5/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.5725 - accuracy: 0.7590 - val_loss: 0.7395 - val_accuracy: 0.7216
# Epoch 6/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.5505 - accuracy: 0.7701 - val_loss: 0.6962 - val_accuracy: 0.7167
# Epoch 7/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.5216 - accuracy: 0.7777 - val_loss: 0.6683 - val_accuracy: 0.7339
# Epoch 8/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.5055 - accuracy: 0.7856 - val_loss: 0.6613 - val_accuracy: 0.7592
# Epoch 9/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.4821 - accuracy: 0.7926 - val_loss: 0.6784 - val_accuracy: 0.7478
# Epoch 10/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.4543 - accuracy: 0.8016 - val_loss: 0.7110 - val_accuracy: 0.7494
# Epoch 11/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.4239 - accuracy: 0.8163 - val_loss: 0.7358 - val_accuracy: 0.7437
# Epoch 12/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.4121 - accuracy: 0.8230 - val_loss: 0.7052 - val_accuracy: 0.7453
# Epoch 13/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.3776 - accuracy: 0.8403 - val_loss: 0.7652 - val_accuracy: 0.7371
# Epoch 14/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.3394 - accuracy: 0.8548 - val_loss: 0.7987 - val_accuracy: 0.7690
# Epoch 15/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.2953 - accuracy: 0.8771 - val_loss: 0.8096 - val_accuracy: 0.7322
# Epoch 16/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.2537 - accuracy: 0.8945 - val_loss: 1.0157 - val_accuracy: 0.7371
# Epoch 17/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.2096 - accuracy: 0.9177 - val_loss: 1.0744 - val_accuracy: 0.7331
# Epoch 18/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.1839 - accuracy: 0.9281 - val_loss: 1.0485 - val_accuracy: 0.7159
# Epoch 19/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.1492 - accuracy: 0.9429 - val_loss: 1.2400 - val_accuracy: 0.7135
# Epoch 20/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.1237 - accuracy: 0.9531 - val_loss: 1.3402 - val_accuracy: 0.6767
# Epoch 21/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.1016 - accuracy: 0.9636 - val_loss: 1.3073 - val_accuracy: 0.7298
# Epoch 22/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.0838 - accuracy: 0.9716 - val_loss: 1.5220 - val_accuracy: 0.7306
# Epoch 23/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.0829 - accuracy: 0.9703 - val_loss: 1.2581 - val_accuracy: 0.7265
# Epoch 24/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.0815 - accuracy: 0.9696 - val_loss: 1.4414 - val_accuracy: 0.7429
# Epoch 25/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.0660 - accuracy: 0.9762 - val_loss: 1.5956 - val_accuracy: 0.7306
# Epoch 26/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.0650 - accuracy: 0.9772 - val_loss: 1.5693 - val_accuracy: 0.7249
# Epoch 27/30
# 424/424 [==============================] - 69s 162ms/step - loss: 0.0547 - accuracy: 0.9806 - val_loss: 2.0195 - val_accuracy: 0.6024
# Epoch 28/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.0519 - accuracy: 0.9813 - val_loss: 1.6003 - val_accuracy: 0.7192
# Epoch 29/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.0499 - accuracy: 0.9834 - val_loss: 1.5083 - val_accuracy: 0.7127
# Epoch 30/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.0531 - accuracy: 0.9806 - val_loss: 1.4155 - val_accuracy: 0.6612
# 39/39 [==============================] - 2s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.65      0.74      0.69       208
#            1       0.57      0.32      0.41       250
#            2       0.82      0.91      0.86       767
#
#     accuracy                           0.76      1225
#    macro avg       0.68      0.66      0.66      1225
# weighted avg       0.74      0.76      0.74      1225

# %%
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
fig = plt.figure(figsize=[10, 10])
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)

ax = fig.add_subplot(spec2[0,0])
ax.plot(ft_histories[0].history['loss'], label='Run1')
plt.title("Training loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[0,1])
ax.plot(ft_histories[0].history['accuracy'], label='Run1')
plt.title("Training accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[1,0])
ax.plot(ft_histories[0].history['val_loss'], label='Run1')


plt.title("Validation loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0,4])
plt.legend()

ax = fig.add_subplot(spec2[1,1])
ax.plot(ft_histories[0].history['val_accuracy'], label='Run1')

plt.title("Validation accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

plt.savefig('fintuned_metrics.png')
plt.show()

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
fig = plt.figure(figsize=[10, 10])
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)

ax = fig.add_subplot(spec2[0,0])
ax.plot(histories[0].history['loss'], label='Run1')
plt.title("Training loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[0,1])
ax.plot(histories[0].history['accuracy'], label='Run1')
plt.title("Training accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[1,0])
ax.plot(histories[0].history['val_loss'], label='Run1')


plt.title("Validation loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0,4])
plt.legend()

ax = fig.add_subplot(spec2[1,1])
ax.plot(histories[0].history['val_accuracy'], label='Run1')

plt.title("Validation accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

plt.savefig('fintuned_metrics.png')
plt.show()

# %%
####################################################################################################################
#          We define our hyperparameters and model specifics. everything is in the same cell for convenience
learning_rate = [0.0001]
batch_size = [32]
model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)
####################################################################################################################
#           As this is the comparison only one model for each model
####################################################################################################################
#           We loop in our hyperparameters, this is only one as we are doing the best model run
for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')
            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 
            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 
            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False
            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            ####################################################################################################################
            #       We Compile our model
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])
            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.
            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)
            #We initiate a callback to save the best model
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            #       We append history and name of model to lists for training history comparison
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)
            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model, all the steps are almost identical to above
            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])
            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)
            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')  
                    
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')
            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])

            ft_histories.append(history)
            ft_name.append(cp_filepath)
                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            model_metrics(model, X_test, y_test)
# Out:
# Running:
#  learning rate:0.0001, batch size: 32 for epochs: 100
# Epoch 1/100
# 424/424 [==============================] - 30s 51ms/step - loss: 1.2675 - accuracy: 0.5442 - val_loss: 1.0837 - val_accuracy: 0.5290
# Epoch 2/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.7086 - accuracy: 0.6651 - val_loss: 1.0987 - val_accuracy: 0.5559
# Epoch 3/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.5248 - accuracy: 0.7662 - val_loss: 1.1541 - val_accuracy: 0.5527
# Epoch 4/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.3727 - accuracy: 0.8455 - val_loss: 1.4131 - val_accuracy: 0.5118
# Epoch 5/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.2470 - accuracy: 0.9048 - val_loss: 1.4585 - val_accuracy: 0.5535
# Epoch 6/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.1529 - accuracy: 0.9512 - val_loss: 1.6077 - val_accuracy: 0.5469
# Epoch 7/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1103 - accuracy: 0.9668 - val_loss: 1.6582 - val_accuracy: 0.6122
# Epoch 8/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0903 - accuracy: 0.9740 - val_loss: 1.9975 - val_accuracy: 0.5053
# Epoch 9/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0597 - accuracy: 0.9838 - val_loss: 2.0112 - val_accuracy: 0.5306
# Epoch 10/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0380 - accuracy: 0.9920 - val_loss: 2.8271 - val_accuracy: 0.4857
# Epoch 11/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0843 - accuracy: 0.9720 - val_loss: 2.2864 - val_accuracy: 0.5135
# Epoch 12/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0493 - accuracy: 0.9862 - val_loss: 2.1358 - val_accuracy: 0.5731
# Epoch 13/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0153 - accuracy: 0.9973 - val_loss: 2.4911 - val_accuracy: 0.6016
# Epoch 14/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0346 - accuracy: 0.9904 - val_loss: 2.7495 - val_accuracy: 0.5910
# Epoch 15/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0895 - accuracy: 0.9692 - val_loss: 2.4216 - val_accuracy: 0.5314
# Epoch 16/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0381 - accuracy: 0.9889 - val_loss: 2.4507 - val_accuracy: 0.5984
# Epoch 17/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0173 - accuracy: 0.9954 - val_loss: 2.8022 - val_accuracy: 0.5747
# Epoch 18/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0504 - accuracy: 0.9831 - val_loss: 2.7352 - val_accuracy: 0.5608
# Epoch 19/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0295 - accuracy: 0.9913 - val_loss: 2.7983 - val_accuracy: 0.5747
# Epoch 20/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0504 - accuracy: 0.9827 - val_loss: 2.7091 - val_accuracy: 0.5331
# Epoch 21/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0305 - accuracy: 0.9909 - val_loss: 2.7332 - val_accuracy: 0.5992
# Epoch 22/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0254 - accuracy: 0.9928 - val_loss: 2.8285 - val_accuracy: 0.5722
# Epoch 23/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0273 - accuracy: 0.9915 - val_loss: 3.0172 - val_accuracy: 0.5690
# Epoch 24/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0379 - accuracy: 0.9870 - val_loss: 2.7924 - val_accuracy: 0.5690
# Epoch 25/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0081 - accuracy: 0.9982 - val_loss: 2.9493 - val_accuracy: 0.5763
# Epoch 26/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 3.2309 - val_accuracy: 0.5796
# Epoch 27/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 3.5414 - val_accuracy: 0.5763
# Epoch 28/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 3.8769 - val_accuracy: 0.5804
# Epoch 29/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 4.1363 - val_accuracy: 0.5837
# Epoch 30/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 4.3536 - val_accuracy: 0.5853
# Epoch 31/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.1012 - accuracy: 0.9656 - val_loss: 2.3169 - val_accuracy: 0.5388
# Epoch 32/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0435 - accuracy: 0.9855 - val_loss: 2.8155 - val_accuracy: 0.5518
# Epoch 33/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0225 - accuracy: 0.9934 - val_loss: 2.8778 - val_accuracy: 0.5616
# Epoch 34/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 3.2762 - val_accuracy: 0.6008
# Epoch 35/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0205 - accuracy: 0.9945 - val_loss: 3.4715 - val_accuracy: 0.5690
# Epoch 36/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0406 - accuracy: 0.9871 - val_loss: 3.0851 - val_accuracy: 0.5853
# Epoch 37/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0127 - accuracy: 0.9964 - val_loss: 3.2347 - val_accuracy: 0.5804
# Epoch 38/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 3.4777 - val_accuracy: 0.6090
# Epoch 39/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0195 - accuracy: 0.9940 - val_loss: 3.3566 - val_accuracy: 0.5771
# Epoch 40/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0263 - accuracy: 0.9919 - val_loss: 3.3463 - val_accuracy: 0.5829
# Epoch 41/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0191 - accuracy: 0.9937 - val_loss: 3.2482 - val_accuracy: 0.5861
# Epoch 42/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 3.4725 - val_accuracy: 0.5902
# Epoch 43/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 3.9227 - val_accuracy: 0.5469
# Epoch 44/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 4.0222 - val_accuracy: 0.5722
# Epoch 45/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0275 - accuracy: 0.9915 - val_loss: 3.0268 - val_accuracy: 0.5290
# Epoch 46/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0469 - accuracy: 0.9838 - val_loss: 3.2002 - val_accuracy: 0.5780
# Epoch 47/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 3.4976 - val_accuracy: 0.5820
# Epoch 48/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 3.6738 - val_accuracy: 0.5829
# Epoch 49/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 3.8135 - val_accuracy: 0.5608
# Epoch 50/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 3.8644 - val_accuracy: 0.5633
# Epoch 51/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 4.7197 - val_accuracy: 0.5682
# Epoch 52/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 5.2558 - val_accuracy: 0.5771
# Epoch 53/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 5.5547 - val_accuracy: 0.5649
# Epoch 54/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 5.7581 - val_accuracy: 0.5673
# Epoch 55/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 6.0021 - val_accuracy: 0.5747
# Epoch 56/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 6.0867 - val_accuracy: 0.5722
# Epoch 57/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 6.2235 - val_accuracy: 0.5739
# Epoch 58/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 6.3664 - val_accuracy: 0.5731
# Epoch 59/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0699 - accuracy: 0.9789 - val_loss: 2.7622 - val_accuracy: 0.5004
# Epoch 60/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0735 - accuracy: 0.9759 - val_loss: 3.7102 - val_accuracy: 0.5747
# Epoch 61/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0222 - accuracy: 0.9927 - val_loss: 3.3239 - val_accuracy: 0.5584
# Epoch 62/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0164 - accuracy: 0.9960 - val_loss: 3.4730 - val_accuracy: 0.5616
# Epoch 63/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0164 - accuracy: 0.9954 - val_loss: 3.4950 - val_accuracy: 0.5910
# Epoch 64/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0158 - accuracy: 0.9960 - val_loss: 3.7088 - val_accuracy: 0.5755
# Epoch 65/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 3.9274 - val_accuracy: 0.5576
# Epoch 66/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 4.2519 - val_accuracy: 0.5731
# Epoch 67/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 4.5133 - val_accuracy: 0.5682
# Epoch 68/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 4.7058 - val_accuracy: 0.5698
# Epoch 69/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 4.9523 - val_accuracy: 0.5747
# Epoch 70/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 5.1638 - val_accuracy: 0.5739
# Epoch 71/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 5.3264 - val_accuracy: 0.5763
# Epoch 72/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 5.5448 - val_accuracy: 0.5771
# Epoch 73/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 5.7014 - val_accuracy: 0.5747
# Epoch 74/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 5.7422 - val_accuracy: 0.5763
# Epoch 75/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 6.0852 - val_accuracy: 0.5739
# Epoch 76/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 6.2718 - val_accuracy: 0.5763
# Epoch 77/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0822 - accuracy: 0.9735 - val_loss: 3.1212 - val_accuracy: 0.5486
# Epoch 78/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0589 - accuracy: 0.9807 - val_loss: 3.7143 - val_accuracy: 0.5878
# Epoch 79/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0220 - accuracy: 0.9925 - val_loss: 4.2024 - val_accuracy: 0.5224
# Epoch 80/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 4.2050 - val_accuracy: 0.5869
# Epoch 81/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 3.9623 - val_accuracy: 0.6008
# Epoch 82/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0172 - accuracy: 0.9954 - val_loss: 4.0347 - val_accuracy: 0.5306
# Epoch 83/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 4.3581 - val_accuracy: 0.5486
# Epoch 84/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 4.1911 - val_accuracy: 0.5633
# Epoch 85/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 4.3917 - val_accuracy: 0.5722
# Epoch 86/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 4.5565 - val_accuracy: 0.5616
# Epoch 87/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 5.0471 - val_accuracy: 0.5714
# Epoch 88/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 5.8211 - val_accuracy: 0.5673
# Epoch 89/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 6.1909 - val_accuracy: 0.5706
# Epoch 90/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 6.4156 - val_accuracy: 0.5739
# Epoch 91/100
# 424/424 [==============================] - 18s 42ms/step - loss: 8.9286e-04 - accuracy: 0.9996 - val_loss: 6.9363 - val_accuracy: 0.5665
# Epoch 92/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 6.9950 - val_accuracy: 0.5698
# Epoch 93/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 7.3081 - val_accuracy: 0.5747
# Epoch 94/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 7.3897 - val_accuracy: 0.5722
# Epoch 95/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 7.7515 - val_accuracy: 0.5649
# Epoch 96/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0839 - accuracy: 0.9762 - val_loss: 3.4847 - val_accuracy: 0.5633
# Epoch 97/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0530 - accuracy: 0.9836 - val_loss: 3.8345 - val_accuracy: 0.6049
# Epoch 98/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0170 - accuracy: 0.9954 - val_loss: 4.0853 - val_accuracy: 0.5486
# Epoch 99/100
# 424/424 [==============================] - 18s 42ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 5.0442 - val_accuracy: 0.5665
# Epoch 100/100
# 424/424 [==============================] - 18s 42ms/step - loss: 9.7165e-04 - accuracy: 0.9997 - val_loss: 5.3287 - val_accuracy: 0.5673
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 424/424 [==============================] - 76s 164ms/step - loss: 0.9103 - accuracy: 0.5721 - val_loss: 0.7880 - val_accuracy: 0.6906
# Epoch 2/30
# 424/424 [==============================] - 67s 157ms/step - loss: 0.6433 - accuracy: 0.7281 - val_loss: 0.7157 - val_accuracy: 0.7249
# Epoch 3/30
# 424/424 [==============================] - 67s 157ms/step - loss: 0.5857 - accuracy: 0.7536 - val_loss: 0.6807 - val_accuracy: 0.7404
# Epoch 4/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.5502 - accuracy: 0.7631 - val_loss: 0.6945 - val_accuracy: 0.7404
# Epoch 5/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.5312 - accuracy: 0.7698 - val_loss: 0.6952 - val_accuracy: 0.7445
# Epoch 6/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.5114 - accuracy: 0.7750 - val_loss: 0.6817 - val_accuracy: 0.7486
# Epoch 7/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.4770 - accuracy: 0.7896 - val_loss: 0.6857 - val_accuracy: 0.7159
# Epoch 8/30
# 424/424 [==============================] - 68s 161ms/step - loss: 0.4620 - accuracy: 0.8022 - val_loss: 0.6327 - val_accuracy: 0.7633
# Epoch 9/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.4330 - accuracy: 0.8144 - val_loss: 0.6523 - val_accuracy: 0.7567
# Epoch 10/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.4145 - accuracy: 0.8247 - val_loss: 0.6848 - val_accuracy: 0.7527
# Epoch 11/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.3754 - accuracy: 0.8405 - val_loss: 0.7395 - val_accuracy: 0.7339
# Epoch 12/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.3329 - accuracy: 0.8639 - val_loss: 0.7571 - val_accuracy: 0.7404
# Epoch 13/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.2905 - accuracy: 0.8796 - val_loss: 0.7827 - val_accuracy: 0.7592
# Epoch 14/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.2543 - accuracy: 0.8989 - val_loss: 0.9101 - val_accuracy: 0.7404
# Epoch 15/30
# 424/424 [==============================] - 68s 159ms/step - loss: 0.2075 - accuracy: 0.9180 - val_loss: 0.9449 - val_accuracy: 0.7004
# Epoch 16/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.1792 - accuracy: 0.9304 - val_loss: 1.0825 - val_accuracy: 0.7314
# Epoch 17/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.1336 - accuracy: 0.9503 - val_loss: 1.0967 - val_accuracy: 0.7257
# Epoch 18/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.1116 - accuracy: 0.9582 - val_loss: 1.2865 - val_accuracy: 0.7282
# Epoch 19/30
# 424/424 [==============================] - 68s 160ms/step - loss: 0.1124 - accuracy: 0.9581 - val_loss: 1.2694 - val_accuracy: 0.7363
# Epoch 20/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.0818 - accuracy: 0.9702 - val_loss: 1.2730 - val_accuracy: 0.7331
# Epoch 21/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.0750 - accuracy: 0.9729 - val_loss: 1.2507 - val_accuracy: 0.7298
# Epoch 22/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0752 - accuracy: 0.9737 - val_loss: 1.3374 - val_accuracy: 0.6980
# Epoch 23/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.0603 - accuracy: 0.9792 - val_loss: 1.5375 - val_accuracy: 0.7290
# Epoch 24/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.0657 - accuracy: 0.9765 - val_loss: 1.4566 - val_accuracy: 0.7273
# Epoch 25/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0657 - accuracy: 0.9765 - val_loss: 1.4360 - val_accuracy: 0.7265
# Epoch 26/30
# 424/424 [==============================] - 68s 159ms/step - loss: 0.0529 - accuracy: 0.9816 - val_loss: 1.4147 - val_accuracy: 0.7184
# Epoch 27/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0617 - accuracy: 0.9788 - val_loss: 1.3554 - val_accuracy: 0.7118
# Epoch 28/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0466 - accuracy: 0.9831 - val_loss: 1.7560 - val_accuracy: 0.7298
# Epoch 29/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.0646 - accuracy: 0.9779 - val_loss: 1.4185 - val_accuracy: 0.7380
# Epoch 30/30
# 424/424 [==============================] - 67s 159ms/step - loss: 0.0385 - accuracy: 0.9883 - val_loss: 1.4826 - val_accuracy: 0.7086
# 39/39 [==============================] - 2s 38ms/step
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71       208
#            1       0.56      0.35      0.43       250
#            2       0.81      0.93      0.86       767
#
#     accuracy                           0.77      1225
#    macro avg       0.71      0.65      0.67      1225
# weighted avg       0.75      0.77      0.75      1225

# %%
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
fig = plt.figure(figsize=[10, 10])
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)

ax = fig.add_subplot(spec2[0,0])
ax.plot(ft_histories[0].history['loss'], label='Run1')
plt.title("Training loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[0,1])
ax.plot(ft_histories[0].history['accuracy'], label='Run3')
plt.title("Training accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[1,0])
ax.plot(ft_histories[0].history['val_loss'], label='Run3')


plt.title("Validation loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0,4])
plt.legend()

ax = fig.add_subplot(spec2[1,1])
ax.plot(ft_histories[0].history['val_accuracy'], label='Run3')

plt.title("Validation accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

plt.savefig('fintuned_metrics.png')
plt.show()

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
fig = plt.figure(figsize=[10, 10])
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)

ax = fig.add_subplot(spec2[0,0])
ax.plot(histories[0].history['loss'], label='Run3')
plt.title("Training loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[0,1])
ax.plot(histories[0].history['accuracy'], label='Run3')
plt.title("Training accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

ax = fig.add_subplot(spec2[1,0])
ax.plot(histories[0].history['val_loss'], label='Run3')


plt.title("Validation loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.0,4])
plt.legend()

ax = fig.add_subplot(spec2[1,1])
ax.plot(histories[0].history['val_accuracy'], label='Run3')

plt.title("Validation accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend()

plt.savefig('fintuned_metrics.png')
plt.show()
