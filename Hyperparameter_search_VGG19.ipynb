# %% [markdown]
# # --

# %% [markdown]
# ## Setup

# %% [markdown]
# * IMPORT

# %%
import keras
import numpy as np
from numpy import ma
import json
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import  classification_report, confusion_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
import random

# %% [markdown]
# * Set random state

# %%
random_state = 42

# %% [markdown]
# * CHECK FOR GPU

# %%
tf.config.list_physical_devices(
    device_type=None
)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Data

# %% [markdown]
# * LOAD DATA

# %%
# Load all data and labels
ccFieldsAll = np.load("C:/Users/mkoli/Syddansk Universitet/Morten Thyrring Stouenberg - Speciale2023/Data/AllNoAlt/ccLastImageNoCloudIndex0_6234.npy", allow_pickle=True)
labels = np.load("C:/Users/mkoli/Syddansk Universitet/Morten Thyrring Stouenberg - Speciale2023/Data/AllNoAlt/reLabelsAll.npy", allow_pickle=True)

# Cloud probability band subset
cloud_probability = ccFieldsAll[:len(labels),:,:,7]

# Subset data to true labels
ccFieldsAll = ccFieldsAll[:len(labels),:,:,[2,1,0]]

# %% [markdown]
# ## Normalize data to 0-255 range

# %%
def normalize(band):
    band_min, band_max = (band.min(), band.max())
    return (((band-band_min)/((band_max - band_min)))*255)

ccFieldsAll[:,:,:,0] = normalize(ccFieldsAll[:,:,:,0])
ccFieldsAll[:,:,:,1] = normalize(ccFieldsAll[:,:,:,1])
ccFieldsAll[:,:,:,2] = normalize(ccFieldsAll[:,:,:,2])

# %%
plt.imshow(ccFieldsAll[1])

# %% [markdown]
# Cloud masking

# %%
# We Set cloud tolerance, between 0-255
cloud_tolerance = 40
    
# We loop in the fields by the length of the dataset
for i in range(len(ccFieldsAll)):
    # we subset the image we are at in the loop
    image = ccFieldsAll[i,:,:,:]    
    # We create and apply a mask based on cloud probability over a certain value
    # We use np.logical because np.where did not work for me at the moment
    mask = np.logical_and(cloud_probability[i, :, :,] >= cloud_tolerance, cloud_probability[i, :, :] <= 256)
    # We set all masked pixels to zero, to black out cloud covered parts
    # I do not know why but it didn't work when i did not make a copy. It is just one of those times. 
    masked = image.copy()
    masked[mask] = 0
    # We are replacing the current image with the one with applied cloud mask, if no clouds then nothing is removed.
    ccFieldsAll[i] = masked

# %% [markdown]
# * DELETE EMPTY IMAGES, resize while were at it

# %%
# we want to delete the all black images, this is done by only appending images with visible RGB bands not all black.

# Initiate list for images that did not get blacked out as well as a list for labels
ccFieldsNoCloud = []
LabelsNoCloud = []

# as we are looping in the images we resize them at the same time
# so we set the size of the images
size = 128

# We loop in all the images
for i in range(len(ccFieldsAll)):
    # if the image is not all black
    if not np.all(ccFieldsAll[i] == 0):
        #we append the image and label
        ccFieldsNoCloud.append(tf.image.resize(ccFieldsAll[i], [size, size]))
        LabelsNoCloud.append(labels[i])

# We set the lists as arrays
ccFieldsNoCloud = np.array(ccFieldsNoCloud)
LabelsNoCloud   = np.array(LabelsNoCloud)

#And print the shapes to control the output and see how many fields are left. 
print(ccFieldsNoCloud.shape)
print(LabelsNoCloud.shape)
# Out:
# (6122, 128, 128, 3)
# (6122,)

# %% [markdown]
# * NEW DISTRIBUTION OF LABELS

# %%
print(f'Number of observations : {len(LabelsNoCloud)}')

print(f'appearances of 0 in labels : {np.count_nonzero(LabelsNoCloud == 0)}({round(100*np.count_nonzero(LabelsNoCloud == 0)/len(LabelsNoCloud),2)}% of total)')
print(f'appearances of 1 in labels : {np.count_nonzero(LabelsNoCloud == 1)}({round(100*np.count_nonzero(LabelsNoCloud == 1)/len(LabelsNoCloud),2)}% of total)')
print(f'appearances of 2 in labels : {np.count_nonzero(LabelsNoCloud == 2)}({round(100*np.count_nonzero(LabelsNoCloud == 2)/len(LabelsNoCloud),2)}% of total)')
# Out:
# Number of observations : 6122
# appearances of 0 in labels : 999(16.32% of total)
# appearances of 1 in labels : 1325(21.64% of total)
# appearances of 2 in labels : 3798(62.04% of total)

# %% [markdown]
# ### CNN (RGB images)

# %%
# Data is split 80/20 for train and test
X_train, X_test, y_train, y_test = train_test_split(ccFieldsNoCloud, 
                                                    LabelsNoCloud, 
                                                    test_size=0.2, 
                                                    random_state=random_state)

# Train data is split 75/25, which corresponds to 20% of original 
# data as validation and 60% of original data as train
X_train, X_val, y_train, y_val = train_test_split(X_train, 
                                                  y_train, 
                                                  test_size=0.25, 
                                                  random_state=random_state) # 0.25 x 0.8 = 0.2

# Print the dataset shapes to inspect sizes
print(X_train.shape, y_train.shape) 
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (3672, 128, 128, 3) (3672,)
# (1225, 128, 128, 3) (1225,)
# (1225, 128, 128, 3) (1225,)

# %% [markdown]
# # Data augmentation

# %%
#Defining augmentaation method 
 
datagen = ImageDataGenerator(
    # Rotation range is set to 360 to enable images to get any rotational angle
    rotation_range      = 360,        
    # Zoom range is a conservative 0.2 to not get too big parts of the image out of bounds
    zoom_range          = 0.2,           
    # Brightness range is random between specified values to enable brightness adjustment due to sun or shadow from clouds
    brightness_range    = (0.8,1.2),    
    # Horisontal flip is enabled. I do not know if it is going to make a difference, but it is not going to hurt. 
    horizontal_flip     = True)

# %%
# We initiate lists for data and labels used for augmentation
data_for_augmentation = []
labels_for_augmentation = []

# We Loop Loop data and append fields to each class for single class data augmentation 
for i in range(len(y_train)):
  if y_train[i] == 0:
    data_for_augmentation.append(X_train[i])
    labels_for_augmentation.append(y_train[i])
  if y_train[i] == 1:
    data_for_augmentation.append(X_train[i])
    labels_for_augmentation.append(y_train[i])

# save as numpy arrays
data_for_augmentation    = np.asarray(data_for_augmentation)
labels_for_augmentation    = np.asarray(labels_for_augmentation)

# Check  array shape
print(f'data for augmentation : {data_for_augmentation.shape} labels for augmentation : {labels_for_augmentation.shape}')
# Out:
# data for augmentation : (1412, 128, 128, 3) labels for augmentation : (1412,)

# %%
# We set a specified number of images for augmentation per image in the dataset
num_samples_per_image = 7
# num_samples_per_image = 9
# num_samples_per_image = 11

# We reshaping data, i am not sure why, but stack overflow helped me get here.
aug_dataset            = data_for_augmentation.reshape(data_for_augmentation.shape[0], 
                                                      data_for_augmentation.shape[1], 
                                                      data_for_augmentation.shape[2], 
                                                      3)

# We initiate a list of labels for augmented data
labels_aug = []
# We create an empty list for the augmented images
augmented_images = []

# We loop in the length of the dataset
for i in range(len(aug_dataset)):
    # We loop in the desired amount of images augmented for each image
    for j in range(num_samples_per_image):
        # we subset the image
        img = data_for_augmentation[i]
        # we expand dimensions as described on the tensorflow website 
        # https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator 
        img = np.expand_dims(img, axis=0)
        # We use the datagen.flow to flow one image at the time into the augmenting imagedatagenerator
        # I am not entirely sure about the .next when using only one image but it works, in theory we do not need it but i do not want to remove something when it works. 
        augmented_img = datagen.flow(img, batch_size=1, shuffle=False).next()
        #as we have expanded the dimensiong we need to sqeeze it all back together for a functioning image again
        augmented_img = augmented_img.squeeze(axis=0)
        # We append the image and labels to our lists
        augmented_images.append(augmented_img)
        labels_aug.append(labels_for_augmentation[i])

#Turn it all into numpy arrays
labels_aug=np.asarray(labels_aug)
augmented_images=np.asarray(augmented_images)

# %%
# We concatenate the data to make sure the training dataset is now the original train data and the augmented data
X_train = np.concatenate((X_train, augmented_images), axis=0)
y_train = np.concatenate((y_train, labels_aug), axis=0)

# %%
# We shuffle the data to ensure there is not only accepted fields in the start of the dataset
# we set a list of indexes that is randomly shuffled
idx = np.random.permutation(len(X_train))
# We use these indexes to set the images with corresponding labels
X_trainx,y_train = X_train[idx], y_train[idx]

# %%
print(f'Number of observations : {len(y_train)}')

print(f'appearances of 0 in labels : {np.count_nonzero(y_train == 0)}({round(100*np.count_nonzero(y_train == 0)/len(y_train),2)}% of total)')
print(f'appearances of 1 in labels : {np.count_nonzero(y_train == 1)}({round(100*np.count_nonzero(y_train == 1)/len(y_train),2)}% of total)')
print(f'appearances of 2 in labels : {np.count_nonzero(y_train == 2)}({round(100*np.count_nonzero(y_train == 2)/len(y_train),2)}% of total)')
# Out:
# Number of observations : 13556
# appearances of 0 in labels : 4832(35.64% of total)
# appearances of 1 in labels : 6464(47.68% of total)
# appearances of 2 in labels : 2260(16.67% of total)

# %% [markdown]
# # Deep Learning Models

# %%
X_train = tf.keras.applications.vgg19.preprocess_input(X_train, data_format=None)
X_test = tf.keras.applications.vgg19.preprocess_input(X_test, data_format=None)
X_val = tf.keras.applications.vgg19.preprocess_input(X_val, data_format=None)

# %% [markdown]
# # VGG19 - Hyperparametersearch

# %%
def His_metrics(history, cp_filepath):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()),1])
    plt.title(f'Training and Validation Loss {cp_filepath}')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0,1.0])
    plt.title(f'Training and Validation Loss {cp_filepath}')
    plt.xlabel('epoch')
    plt.show()

def Viz_metrics(X_test, y_test, model, cp_filepath):
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    print(classification_report(y_test, y_pred_classes))
    cm = confusion_matrix(y_test, y_pred_classes)
    class_names = ['Failed (0)', 'Partially (1)', 'Accepted (2)']
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, cmap=plt.cm.OrRd)
    plt.title(f'Confusion Matrix \n {cp_filepath}')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.xticks(np.arange(len(class_names)), class_names, rotation=45)
    plt.yticks(np.arange(len(class_names)), class_names)
    plt.colorbar()
    for k in range(len(class_names)):
        for h in range(len(class_names)):
            plt.text(h, k, cm[k, h], ha='center', va='center', color='black')

    plt.show()

# %%
histories = []
name = []

ft_histories = []
ft_name = []

# %% [markdown]
# ### lr=0.0001 bs=64 - done

# %%
####################################################################################################################
#          We define our hyperparameters. everything is in the same cell for convenience

learning_rate = [0.0001]
batch_size = [64]

####################################################################################################################
#           We define our model specific parameters

model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)

####################################################################################################################
#           We print the number of models and state the hyperparameter search

print(f'Running learning rate:{learning_rate} and batch size: {batch_size} for epochs: {epochs}')

####################################################################################################################
#           We loop in our hyperparameters

for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')

            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 

            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 

            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False

            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            #       The top model dense layers are arbitrarily chosen.

            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            
            ####################################################################################################################
            #       We Compile our model

            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.

            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')

            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)


            ####################################################################################################################
            #       Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            ####################################################################################################################
            #       save model with acc for later investigaion

            model.save('model{} acc{}  lr{} batch size{}.h5'.format(model_name,score[1], i,j,))
            ####################################################################################################################
            #       print visualization of training metrics           
            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)         

            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model

            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])


            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')


            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            # Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            model.save(' fintunedmodel{} acc{} lr{} batch size{}.h5'.format(model_name,score[1], i,j,))

            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)
# Out:
# Running learning rate:[0.0001] and batch size: [64] for epochs: 100
# Running:
#  learning rate:0.0001, batch size: 64 for epochs: 100
# Epoch 1/100
# 212/212 [==============================] - 30s 101ms/step - loss: 1.3611 - accuracy: 0.5360 - val_loss: 0.9823 - val_accuracy: 0.6057
# Epoch 2/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7090 - accuracy: 0.6662 - val_loss: 1.2031 - val_accuracy: 0.5086
# Epoch 3/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.5519 - accuracy: 0.7498 - val_loss: 1.0835 - val_accuracy: 0.5690
# Epoch 4/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.4172 - accuracy: 0.8232 - val_loss: 1.1230 - val_accuracy: 0.5829
# Epoch 5/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.2840 - accuracy: 0.8950 - val_loss: 1.2398 - val_accuracy: 0.5698
# Epoch 6/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.2067 - accuracy: 0.9292 - val_loss: 1.3730 - val_accuracy: 0.5592
# Epoch 7/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.1407 - accuracy: 0.9586 - val_loss: 1.7760 - val_accuracy: 0.4939
# Epoch 8/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0849 - accuracy: 0.9821 - val_loss: 1.6891 - val_accuracy: 0.5494
# Epoch 9/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0667 - accuracy: 0.9835 - val_loss: 1.9335 - val_accuracy: 0.5445
# Epoch 10/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0440 - accuracy: 0.9926 - val_loss: 1.9016 - val_accuracy: 0.5469
# Epoch 11/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0233 - accuracy: 0.9975 - val_loss: 1.9363 - val_accuracy: 0.5894
# Epoch 12/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0155 - accuracy: 0.9987 - val_loss: 2.0512 - val_accuracy: 0.5633
# Epoch 13/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0113 - accuracy: 0.9982 - val_loss: 2.2322 - val_accuracy: 0.5445
# Epoch 14/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0157 - accuracy: 0.9975 - val_loss: 2.1449 - val_accuracy: 0.5845
# Epoch 15/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0364 - accuracy: 0.9905 - val_loss: 2.3776 - val_accuracy: 0.5641
# Epoch 16/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.1605 - accuracy: 0.9414 - val_loss: 2.2365 - val_accuracy: 0.5273
# Epoch 17/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0492 - accuracy: 0.9880 - val_loss: 2.2508 - val_accuracy: 0.5241
# Epoch 18/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0189 - accuracy: 0.9964 - val_loss: 2.4299 - val_accuracy: 0.5576
# Epoch 19/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0128 - accuracy: 0.9971 - val_loss: 2.6040 - val_accuracy: 0.5845
# Epoch 20/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0152 - accuracy: 0.9962 - val_loss: 2.5952 - val_accuracy: 0.5494
# Epoch 21/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0134 - accuracy: 0.9972 - val_loss: 2.8275 - val_accuracy: 0.5257
# Epoch 22/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0924 - accuracy: 0.9670 - val_loss: 2.2274 - val_accuracy: 0.5584
# Epoch 23/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0276 - accuracy: 0.9931 - val_loss: 2.5400 - val_accuracy: 0.5682
# Epoch 24/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0084 - accuracy: 0.9987 - val_loss: 2.6516 - val_accuracy: 0.5624
# Epoch 25/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 2.7598 - val_accuracy: 0.5543
# Epoch 26/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 2.8256 - val_accuracy: 0.5673
# Epoch 27/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 2.8857 - val_accuracy: 0.5673
# Epoch 28/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0061 - accuracy: 0.9988 - val_loss: 2.9010 - val_accuracy: 0.5731
# Epoch 29/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 3.0000 - val_accuracy: 0.5747
# Epoch 30/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 3.0253 - val_accuracy: 0.5641
# Epoch 31/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 3.0508 - val_accuracy: 0.5763
# Epoch 32/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0038 - accuracy: 0.9993 - val_loss: 3.1074 - val_accuracy: 0.5608
# Epoch 33/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 3.1384 - val_accuracy: 0.5682
# Epoch 34/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 3.2282 - val_accuracy: 0.5731
# Epoch 35/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.1180 - accuracy: 0.9675 - val_loss: 1.8236 - val_accuracy: 0.5176
# Epoch 36/100
# 212/212 [==============================] - 17s 81ms/step - loss: 0.0934 - accuracy: 0.9670 - val_loss: 2.3335 - val_accuracy: 0.5731
# Epoch 37/100
# 212/212 [==============================] - 17s 81ms/step - loss: 0.0251 - accuracy: 0.9928 - val_loss: 2.6905 - val_accuracy: 0.5649
# Epoch 38/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0090 - accuracy: 0.9980 - val_loss: 2.9590 - val_accuracy: 0.5486
# Epoch 39/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 3.0251 - val_accuracy: 0.5706
# Epoch 40/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 3.3047 - val_accuracy: 0.5355
# Epoch 41/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0450 - accuracy: 0.9849 - val_loss: 2.7847 - val_accuracy: 0.5388
# Epoch 42/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0261 - accuracy: 0.9917 - val_loss: 2.8333 - val_accuracy: 0.6049
# Epoch 43/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0212 - accuracy: 0.9945 - val_loss: 3.0740 - val_accuracy: 0.5788
# Epoch 44/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 3.1249 - val_accuracy: 0.5665
# Epoch 45/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.0214 - accuracy: 0.9932 - val_loss: 3.0876 - val_accuracy: 0.5682
# Epoch 46/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 3.3513 - val_accuracy: 0.5576
# Epoch 47/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 3.4765 - val_accuracy: 0.5739
# Epoch 48/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.0146 - accuracy: 0.9951 - val_loss: 3.2881 - val_accuracy: 0.5543
# Epoch 49/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.0231 - accuracy: 0.9929 - val_loss: 3.5792 - val_accuracy: 0.5265
# Epoch 50/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.0329 - accuracy: 0.9891 - val_loss: 3.2675 - val_accuracy: 0.5600
# Epoch 51/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 3.3036 - val_accuracy: 0.5567
# Epoch 52/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 3.3974 - val_accuracy: 0.5624
# Epoch 53/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.4608 - val_accuracy: 0.5633
# Epoch 54/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 3.5186 - val_accuracy: 0.5665
# Epoch 55/100
# 212/212 [==============================] - 17s 81ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 3.5813 - val_accuracy: 0.5665
# Epoch 56/100
# 212/212 [==============================] - 17s 81ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 3.6265 - val_accuracy: 0.5665
# Epoch 57/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 3.6781 - val_accuracy: 0.5698
# Epoch 58/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 3.7801 - val_accuracy: 0.5641
# Epoch 59/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 3.7386 - val_accuracy: 0.5624
# Epoch 60/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 3.7778 - val_accuracy: 0.5714
# Epoch 61/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 3.8730 - val_accuracy: 0.5624
# Epoch 62/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.9035 - val_accuracy: 0.5673
# Epoch 63/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 3.9121 - val_accuracy: 0.5722
# Epoch 64/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 3.9946 - val_accuracy: 0.5682
# Epoch 65/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 4.0679 - val_accuracy: 0.5682
# Epoch 66/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 4.1038 - val_accuracy: 0.5706
# Epoch 67/100
# 212/212 [==============================] - 17s 81ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 4.1440 - val_accuracy: 0.5706
# Epoch 68/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 4.2047 - val_accuracy: 0.5698
# Epoch 69/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 4.2029 - val_accuracy: 0.5698
# Epoch 70/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 4.2705 - val_accuracy: 0.5641
# Epoch 71/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 4.3112 - val_accuracy: 0.5722
# Epoch 72/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 4.3925 - val_accuracy: 0.5649
# Epoch 73/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 4.2584 - val_accuracy: 0.5665
# Epoch 74/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.1614 - accuracy: 0.9442 - val_loss: 3.0190 - val_accuracy: 0.5673
# Epoch 75/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0316 - accuracy: 0.9893 - val_loss: 3.1436 - val_accuracy: 0.5616
# Epoch 76/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 3.7802 - val_accuracy: 0.5273
# Epoch 77/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 3.8238 - val_accuracy: 0.5665
# Epoch 78/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 4.0444 - val_accuracy: 0.5657
# Epoch 79/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 4.3826 - val_accuracy: 0.5616
# Epoch 80/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 4.6876 - val_accuracy: 0.5698
# Epoch 81/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 4.9525 - val_accuracy: 0.5690
# Epoch 82/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 5.1613 - val_accuracy: 0.5673
# Epoch 83/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 5.4005 - val_accuracy: 0.5682
# Epoch 84/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 5.4933 - val_accuracy: 0.5731
# Epoch 85/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 5.6473 - val_accuracy: 0.5731
# Epoch 86/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 5.8157 - val_accuracy: 0.5714
# Epoch 87/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 5.9965 - val_accuracy: 0.5616
# Epoch 88/100
# 212/212 [==============================] - 17s 81ms/step - loss: 0.1018 - accuracy: 0.9661 - val_loss: 3.1989 - val_accuracy: 0.5763
# Epoch 89/100
# 212/212 [==============================] - 17s 81ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 3.6730 - val_accuracy: 0.5641
# Epoch 90/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0162 - accuracy: 0.9947 - val_loss: 3.7676 - val_accuracy: 0.5616
# Epoch 91/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 3.9686 - val_accuracy: 0.5559
# Epoch 92/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0116 - accuracy: 0.9957 - val_loss: 4.0464 - val_accuracy: 0.5747
# Epoch 93/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 4.1086 - val_accuracy: 0.5837
# Epoch 94/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 4.2295 - val_accuracy: 0.5600
# Epoch 95/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 4.1504 - val_accuracy: 0.5445
# Epoch 96/100
# 212/212 [==============================] - 17s 81ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 4.0483 - val_accuracy: 0.6073
# Epoch 97/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 4.3630 - val_accuracy: 0.5380
# Epoch 98/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 4.3873 - val_accuracy: 0.5363
# Epoch 99/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 3.9423 - val_accuracy: 0.5853
# Epoch 100/100
# 212/212 [==============================] - 17s 80ms/step - loss: 0.0157 - accuracy: 0.9949 - val_loss: 4.1260 - val_accuracy: 0.5518
# Test loss: 3.803915023803711
# Test accuracy: 0.5893877744674683
# 39/39 [==============================] - 2s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.35      0.35      0.35       208
#            1       0.31      0.32      0.32       250
#            2       0.76      0.74      0.75       767
#
#     accuracy                           0.59      1225
#    macro avg       0.47      0.47      0.47      1225
# weighted avg       0.59      0.59      0.59      1225
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 212/212 [==============================] - 83s 342ms/step - loss: 0.9781 - accuracy: 0.6459 - val_loss: 0.9838 - val_accuracy: 0.5804
# Epoch 2/30
# 212/212 [==============================] - 65s 304ms/step - loss: 0.6475 - accuracy: 0.7240 - val_loss: 0.7036 - val_accuracy: 0.7151
# Epoch 3/30
# 212/212 [==============================] - 64s 301ms/step - loss: 0.5920 - accuracy: 0.7474 - val_loss: 0.8018 - val_accuracy: 0.6939
# Epoch 4/30
# 212/212 [==============================] - 64s 303ms/step - loss: 0.5649 - accuracy: 0.7624 - val_loss: 0.6364 - val_accuracy: 0.7576
# Epoch 5/30
# 212/212 [==============================] - 64s 304ms/step - loss: 0.5287 - accuracy: 0.7738 - val_loss: 0.6497 - val_accuracy: 0.7706
# Epoch 6/30
# 212/212 [==============================] - 64s 301ms/step - loss: 0.4990 - accuracy: 0.7844 - val_loss: 0.7349 - val_accuracy: 0.7453
# Epoch 7/30
# 212/212 [==============================] - 64s 301ms/step - loss: 0.4752 - accuracy: 0.7950 - val_loss: 0.7517 - val_accuracy: 0.7429
# Epoch 8/30
# 212/212 [==============================] - 64s 300ms/step - loss: 0.4417 - accuracy: 0.8103 - val_loss: 0.6582 - val_accuracy: 0.7616
# Epoch 9/30
# 212/212 [==============================] - 64s 300ms/step - loss: 0.4068 - accuracy: 0.8256 - val_loss: 0.7071 - val_accuracy: 0.7608
# Epoch 10/30
# 212/212 [==============================] - 64s 301ms/step - loss: 0.3773 - accuracy: 0.8368 - val_loss: 0.7740 - val_accuracy: 0.7592
# Epoch 11/30
# 212/212 [==============================] - 64s 300ms/step - loss: 0.3347 - accuracy: 0.8577 - val_loss: 0.7775 - val_accuracy: 0.7429
# Epoch 12/30
# 212/212 [==============================] - 64s 301ms/step - loss: 0.2902 - accuracy: 0.8801 - val_loss: 0.8502 - val_accuracy: 0.7355
# Epoch 13/30
# 212/212 [==============================] - 63s 299ms/step - loss: 0.2573 - accuracy: 0.8950 - val_loss: 0.9693 - val_accuracy: 0.7355
# Epoch 14/30
# 212/212 [==============================] - 64s 302ms/step - loss: 0.2410 - accuracy: 0.9024 - val_loss: 0.9291 - val_accuracy: 0.7282
# Epoch 15/30
# 212/212 [==============================] - 64s 301ms/step - loss: 0.1911 - accuracy: 0.9253 - val_loss: 0.9593 - val_accuracy: 0.7445
# Epoch 16/30
# 212/212 [==============================] - 64s 300ms/step - loss: 0.1582 - accuracy: 0.9375 - val_loss: 1.1413 - val_accuracy: 0.7347
# Epoch 17/30
# 212/212 [==============================] - 64s 301ms/step - loss: 0.1531 - accuracy: 0.9402 - val_loss: 1.0964 - val_accuracy: 0.7363
# Epoch 18/30
# 212/212 [==============================] - 65s 306ms/step - loss: 0.1209 - accuracy: 0.9554 - val_loss: 1.0798 - val_accuracy: 0.7722
# Epoch 19/30
# 212/212 [==============================] - 64s 302ms/step - loss: 0.1174 - accuracy: 0.9549 - val_loss: 1.2741 - val_accuracy: 0.7257
# Epoch 20/30
# 212/212 [==============================] - 64s 303ms/step - loss: 0.1066 - accuracy: 0.9585 - val_loss: 1.3085 - val_accuracy: 0.7404
# Epoch 21/30
# 212/212 [==============================] - 64s 302ms/step - loss: 0.1008 - accuracy: 0.9633 - val_loss: 1.4481 - val_accuracy: 0.7143
# Epoch 22/30
# 212/212 [==============================] - 64s 301ms/step - loss: 0.0870 - accuracy: 0.9689 - val_loss: 1.3500 - val_accuracy: 0.7102
# Epoch 23/30
# 212/212 [==============================] - 64s 300ms/step - loss: 0.0892 - accuracy: 0.9666 - val_loss: 1.4333 - val_accuracy: 0.7290
# Epoch 24/30
# 212/212 [==============================] - 64s 301ms/step - loss: 0.0786 - accuracy: 0.9712 - val_loss: 1.4393 - val_accuracy: 0.7412
# Epoch 25/30
# 212/212 [==============================] - 64s 300ms/step - loss: 0.0617 - accuracy: 0.9786 - val_loss: 1.3855 - val_accuracy: 0.7159
# Epoch 26/30
# 212/212 [==============================] - 64s 300ms/step - loss: 0.0736 - accuracy: 0.9726 - val_loss: 1.1986 - val_accuracy: 0.7200
# Epoch 27/30
# 212/212 [==============================] - 64s 301ms/step - loss: 0.0659 - accuracy: 0.9763 - val_loss: 1.3977 - val_accuracy: 0.7510
# Epoch 28/30
# 212/212 [==============================] - 64s 300ms/step - loss: 0.0604 - accuracy: 0.9784 - val_loss: 1.5173 - val_accuracy: 0.7608
# Epoch 29/30
# 212/212 [==============================] - 64s 300ms/step - loss: 0.0540 - accuracy: 0.9801 - val_loss: 1.6427 - val_accuracy: 0.7543
# Epoch 30/30
# 212/212 [==============================] - 64s 300ms/step - loss: 0.0528 - accuracy: 0.9813 - val_loss: 1.5664 - val_accuracy: 0.7143
# Test loss: 1.1000628471374512
# Test accuracy: 0.7559183835983276
# 39/39 [==============================] - 1s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.68      0.66      0.67       208
#            1       0.53      0.39      0.45       250
#            2       0.83      0.90      0.86       767
#
#     accuracy                           0.76      1225
#    macro avg       0.68      0.65      0.66      1225
# weighted avg       0.74      0.76      0.74      1225

# %% [markdown]
# ### lr=0,0001 bs=32 - done

# %%
####################################################################################################################
#          We define our hyperparameters. everything is in the same cell for convenience

learning_rate = [0.0001]
batch_size = [32]

####################################################################################################################
#           We define our model specific parameters

model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)

####################################################################################################################
#           We print the number of models and state the hyperparameter search

print(f'Running learning rate:{learning_rate} and batch size: {batch_size} for epochs: {epochs}')

####################################################################################################################
#           We loop in our hyperparameters

for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')

            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 

            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 

            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False

            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            #       The top model dense layers are arbitrarily chosen.

            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            
            ####################################################################################################################
            #       We Compile our model

            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.

            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')

            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)


            ####################################################################################################################
            #       Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            ####################################################################################################################
            #       save model with acc for later investigaion

            model.save('model{} acc{}  lr{} batch size{}.h5'.format(model_name,score[1], i,j,))
            ####################################################################################################################
            #       print visualization of training metrics           
            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)         

            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model

            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])


            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')


            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            # Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            model.save(' fintunedmodel{} acc{} lr{} batch size{}.h5'.format(model_name,score[1], i,j,))

            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)
# Out:
# Running learning rate:[0.0001] and batch size: [32] for epochs: 100
# Running:
#  learning rate:0.0001, batch size: 32 for epochs: 100
# Epoch 1/100
# 424/424 [==============================] - 29s 50ms/step - loss: 1.1859 - accuracy: 0.5390 - val_loss: 1.6160 - val_accuracy: 0.3559
# Epoch 2/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.7147 - accuracy: 0.6613 - val_loss: 1.1275 - val_accuracy: 0.5445
# Epoch 3/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.5419 - accuracy: 0.7540 - val_loss: 1.1276 - val_accuracy: 0.5518
# Epoch 4/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.3881 - accuracy: 0.8378 - val_loss: 1.3049 - val_accuracy: 0.5396
# Epoch 5/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.2551 - accuracy: 0.9036 - val_loss: 1.4764 - val_accuracy: 0.5200
# Epoch 6/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1550 - accuracy: 0.9490 - val_loss: 1.4509 - val_accuracy: 0.5943
# Epoch 7/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.1025 - accuracy: 0.9695 - val_loss: 1.9961 - val_accuracy: 0.4857
# Epoch 8/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.1000 - accuracy: 0.9692 - val_loss: 1.9161 - val_accuracy: 0.5657
# Epoch 9/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0722 - accuracy: 0.9799 - val_loss: 1.9388 - val_accuracy: 0.5535
# Epoch 10/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0641 - accuracy: 0.9811 - val_loss: 2.0661 - val_accuracy: 0.5559
# Epoch 11/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0575 - accuracy: 0.9823 - val_loss: 2.3806 - val_accuracy: 0.5110
# Epoch 12/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0512 - accuracy: 0.9847 - val_loss: 2.2505 - val_accuracy: 0.5845
# Epoch 13/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0293 - accuracy: 0.9921 - val_loss: 2.6521 - val_accuracy: 0.5298
# Epoch 14/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0473 - accuracy: 0.9847 - val_loss: 2.5218 - val_accuracy: 0.5584
# Epoch 15/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0694 - accuracy: 0.9759 - val_loss: 2.5906 - val_accuracy: 0.5192
# Epoch 16/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0341 - accuracy: 0.9892 - val_loss: 2.6090 - val_accuracy: 0.5486
# Epoch 17/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0291 - accuracy: 0.9910 - val_loss: 2.7054 - val_accuracy: 0.5355
# Epoch 18/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0276 - accuracy: 0.9914 - val_loss: 2.7916 - val_accuracy: 0.5682
# Epoch 19/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0437 - accuracy: 0.9845 - val_loss: 2.7046 - val_accuracy: 0.5829
# Epoch 20/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0385 - accuracy: 0.9871 - val_loss: 2.8407 - val_accuracy: 0.5143
# Epoch 21/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0301 - accuracy: 0.9897 - val_loss: 2.8050 - val_accuracy: 0.5706
# Epoch 22/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 3.1511 - val_accuracy: 0.5584
# Epoch 23/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 3.1165 - val_accuracy: 0.5796
# Epoch 24/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 3.2180 - val_accuracy: 0.5755
# Epoch 25/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 3.3131 - val_accuracy: 0.5739
# Epoch 26/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 3.3852 - val_accuracy: 0.5771
# Epoch 27/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 3.3678 - val_accuracy: 0.5763
# Epoch 28/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 3.5459 - val_accuracy: 0.5739
# Epoch 29/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 3.5523 - val_accuracy: 0.5763
# Epoch 30/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0820 - accuracy: 0.9748 - val_loss: 2.5615 - val_accuracy: 0.5624
# Epoch 31/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0994 - accuracy: 0.9631 - val_loss: 2.8566 - val_accuracy: 0.5192
# Epoch 32/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0269 - accuracy: 0.9918 - val_loss: 3.2742 - val_accuracy: 0.5559
# Epoch 33/100
# 424/424 [==============================] - 19s 45ms/step - loss: 0.0221 - accuracy: 0.9928 - val_loss: 3.1369 - val_accuracy: 0.6033
# Epoch 34/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0250 - accuracy: 0.9916 - val_loss: 3.0248 - val_accuracy: 0.5722
# Epoch 35/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 3.4599 - val_accuracy: 0.5429
# Epoch 36/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0308 - accuracy: 0.9908 - val_loss: 3.4230 - val_accuracy: 0.5233
# Epoch 37/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 3.4750 - val_accuracy: 0.5755
# Epoch 38/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0311 - accuracy: 0.9905 - val_loss: 3.6989 - val_accuracy: 0.4996
# Epoch 39/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0305 - accuracy: 0.9899 - val_loss: 3.4389 - val_accuracy: 0.5339
# Epoch 40/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 3.4121 - val_accuracy: 0.5714
# Epoch 41/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 3.8792 - val_accuracy: 0.5355
# Epoch 42/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0269 - accuracy: 0.9911 - val_loss: 3.4735 - val_accuracy: 0.5510
# Epoch 43/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0186 - accuracy: 0.9935 - val_loss: 3.6042 - val_accuracy: 0.5469
# Epoch 44/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 3.6942 - val_accuracy: 0.5641
# Epoch 45/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 3.3618 - val_accuracy: 0.5861
# Epoch 46/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 4.0001 - val_accuracy: 0.5518
# Epoch 47/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0205 - accuracy: 0.9937 - val_loss: 3.5905 - val_accuracy: 0.5763
# Epoch 48/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0293 - accuracy: 0.9892 - val_loss: 3.5224 - val_accuracy: 0.5804
# Epoch 49/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 3.7164 - val_accuracy: 0.5747
# Epoch 50/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 3.8824 - val_accuracy: 0.5796
# Epoch 51/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 4.0725 - val_accuracy: 0.5665
# Epoch 52/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 4.1287 - val_accuracy: 0.5714
# Epoch 53/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 4.2063 - val_accuracy: 0.5673
# Epoch 54/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 4.3925 - val_accuracy: 0.5771
# Epoch 55/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 4.7241 - val_accuracy: 0.5747
# Epoch 56/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 4.8490 - val_accuracy: 0.5763
# Epoch 57/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0699 - accuracy: 0.9774 - val_loss: 2.9002 - val_accuracy: 0.5494
# Epoch 58/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0415 - accuracy: 0.9858 - val_loss: 3.2688 - val_accuracy: 0.5927
# Epoch 59/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 3.9098 - val_accuracy: 0.5780
# Epoch 60/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0210 - accuracy: 0.9926 - val_loss: 3.8590 - val_accuracy: 0.5820
# Epoch 61/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 4.6683 - val_accuracy: 0.5233
# Epoch 62/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0167 - accuracy: 0.9953 - val_loss: 3.7664 - val_accuracy: 0.5894
# Epoch 63/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0173 - accuracy: 0.9936 - val_loss: 4.0379 - val_accuracy: 0.5845
# Epoch 64/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 4.3593 - val_accuracy: 0.5804
# Epoch 65/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 5.0068 - val_accuracy: 0.5820
# Epoch 66/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 5.5199 - val_accuracy: 0.5780
# Epoch 67/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 5.8313 - val_accuracy: 0.5731
# Epoch 68/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 5.9894 - val_accuracy: 0.5698
# Epoch 69/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 6.2242 - val_accuracy: 0.5788
# Epoch 70/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 6.3799 - val_accuracy: 0.5747
# Epoch 71/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 6.6829 - val_accuracy: 0.5698
# Epoch 72/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0862 - accuracy: 0.9729 - val_loss: 3.5911 - val_accuracy: 0.5567
# Epoch 73/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0269 - accuracy: 0.9914 - val_loss: 4.2859 - val_accuracy: 0.5624
# Epoch 74/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0279 - accuracy: 0.9909 - val_loss: 3.7426 - val_accuracy: 0.6041
# Epoch 75/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 4.3147 - val_accuracy: 0.5731
# Epoch 76/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 4.6014 - val_accuracy: 0.5804
# Epoch 77/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 4.4099 - val_accuracy: 0.5861
# Epoch 78/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0265 - accuracy: 0.9909 - val_loss: 4.3500 - val_accuracy: 0.5298
# Epoch 79/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0096 - accuracy: 0.9970 - val_loss: 4.9022 - val_accuracy: 0.5902
# Epoch 80/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 5.2640 - val_accuracy: 0.5747
# Epoch 81/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0399 - accuracy: 0.9886 - val_loss: 3.2831 - val_accuracy: 0.5665
# Epoch 82/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 4.6392 - val_accuracy: 0.5682
# Epoch 83/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 4.3253 - val_accuracy: 0.5886
# Epoch 84/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 4.5116 - val_accuracy: 0.5722
# Epoch 85/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 4.5498 - val_accuracy: 0.5967
# Epoch 86/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 5.2424 - val_accuracy: 0.5576
# Epoch 87/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0218 - accuracy: 0.9932 - val_loss: 4.4559 - val_accuracy: 0.5037
# Epoch 88/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0144 - accuracy: 0.9956 - val_loss: 4.7938 - val_accuracy: 0.5935
# Epoch 89/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 5.0015 - val_accuracy: 0.5404
# Epoch 90/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0157 - accuracy: 0.9947 - val_loss: 4.8353 - val_accuracy: 0.5763
# Epoch 91/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0247 - accuracy: 0.9932 - val_loss: 4.3551 - val_accuracy: 0.5706
# Epoch 92/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 4.9714 - val_accuracy: 0.5869
# Epoch 93/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0118 - accuracy: 0.9966 - val_loss: 4.9782 - val_accuracy: 0.5771
# Epoch 94/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 4.9308 - val_accuracy: 0.5780
# Epoch 95/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0247 - accuracy: 0.9925 - val_loss: 4.4460 - val_accuracy: 0.5518
# Epoch 96/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0209 - accuracy: 0.9923 - val_loss: 4.7830 - val_accuracy: 0.5445
# Epoch 97/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 5.6917 - val_accuracy: 0.5698
# Epoch 98/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 5.7453 - val_accuracy: 0.6155
# Epoch 99/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0118 - accuracy: 0.9952 - val_loss: 5.1003 - val_accuracy: 0.5739
# Epoch 100/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0136 - accuracy: 0.9963 - val_loss: 4.7062 - val_accuracy: 0.5714
# Test loss: 5.539676666259766
# Test accuracy: 0.5991836786270142
# 39/39 [==============================] - 1s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.38      0.41      0.39       208
#            1       0.30      0.26      0.28       250
#            2       0.75      0.76      0.76       767
#
#     accuracy                           0.60      1225
#    macro avg       0.47      0.48      0.47      1225
# weighted avg       0.59      0.60      0.60      1225
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 424/424 [==============================] - 76s 165ms/step - loss: 0.9087 - accuracy: 0.6116 - val_loss: 1.1655 - val_accuracy: 0.5151
# Epoch 2/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.6574 - accuracy: 0.7186 - val_loss: 0.7008 - val_accuracy: 0.7469
# Epoch 3/30
# 424/424 [==============================] - 66s 157ms/step - loss: 0.6086 - accuracy: 0.7413 - val_loss: 0.7288 - val_accuracy: 0.7339
# Epoch 4/30
# 424/424 [==============================] - 66s 157ms/step - loss: 0.5797 - accuracy: 0.7527 - val_loss: 0.7441 - val_accuracy: 0.7216
# Epoch 5/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.5496 - accuracy: 0.7662 - val_loss: 0.6617 - val_accuracy: 0.7616
# Epoch 6/30
# 424/424 [==============================] - 67s 158ms/step - loss: 0.5247 - accuracy: 0.7746 - val_loss: 0.6549 - val_accuracy: 0.7690
# Epoch 7/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.5084 - accuracy: 0.7794 - val_loss: 0.8410 - val_accuracy: 0.6947
# Epoch 8/30
# 424/424 [==============================] - 66s 157ms/step - loss: 0.4944 - accuracy: 0.7843 - val_loss: 0.6659 - val_accuracy: 0.7584
# Epoch 9/30
# 424/424 [==============================] - 66s 157ms/step - loss: 0.4711 - accuracy: 0.7977 - val_loss: 0.8047 - val_accuracy: 0.7233
# Epoch 10/30
# 424/424 [==============================] - 66s 157ms/step - loss: 0.4514 - accuracy: 0.8060 - val_loss: 0.7401 - val_accuracy: 0.7478
# Epoch 11/30
# 424/424 [==============================] - 66s 157ms/step - loss: 0.4203 - accuracy: 0.8186 - val_loss: 0.6626 - val_accuracy: 0.7592
# Epoch 12/30
# 424/424 [==============================] - 66s 157ms/step - loss: 0.4015 - accuracy: 0.8300 - val_loss: 0.7389 - val_accuracy: 0.7429
# Epoch 13/30
# 424/424 [==============================] - 66s 157ms/step - loss: 0.3650 - accuracy: 0.8429 - val_loss: 0.8015 - val_accuracy: 0.7543
# Epoch 14/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.3360 - accuracy: 0.8591 - val_loss: 0.8456 - val_accuracy: 0.7633
# Epoch 15/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.2875 - accuracy: 0.8817 - val_loss: 0.9261 - val_accuracy: 0.7437
# Epoch 16/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.2546 - accuracy: 0.8953 - val_loss: 0.8707 - val_accuracy: 0.7241
# Epoch 17/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.2145 - accuracy: 0.9147 - val_loss: 0.9936 - val_accuracy: 0.7412
# Epoch 18/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.1873 - accuracy: 0.9269 - val_loss: 1.0600 - val_accuracy: 0.7102
# Epoch 19/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.1511 - accuracy: 0.9414 - val_loss: 1.2112 - val_accuracy: 0.7200
# Epoch 20/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.1210 - accuracy: 0.9551 - val_loss: 1.2198 - val_accuracy: 0.7363
# Epoch 21/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.1228 - accuracy: 0.9522 - val_loss: 1.4380 - val_accuracy: 0.7420
# Epoch 22/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.0900 - accuracy: 0.9647 - val_loss: 1.4922 - val_accuracy: 0.7347
# Epoch 23/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.0942 - accuracy: 0.9649 - val_loss: 1.6325 - val_accuracy: 0.6890
# Epoch 24/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.0840 - accuracy: 0.9680 - val_loss: 1.4564 - val_accuracy: 0.7388
# Epoch 25/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.0753 - accuracy: 0.9736 - val_loss: 1.6846 - val_accuracy: 0.7241
# Epoch 26/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.0697 - accuracy: 0.9748 - val_loss: 1.7164 - val_accuracy: 0.7037
# Epoch 27/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.0662 - accuracy: 0.9774 - val_loss: 1.6245 - val_accuracy: 0.7331
# Epoch 28/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.0609 - accuracy: 0.9778 - val_loss: 1.4384 - val_accuracy: 0.7143
# Epoch 29/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.0589 - accuracy: 0.9791 - val_loss: 1.6793 - val_accuracy: 0.7233
# Epoch 30/30
# 424/424 [==============================] - 66s 156ms/step - loss: 0.0739 - accuracy: 0.9735 - val_loss: 1.5980 - val_accuracy: 0.6955
# Test loss: 0.6311252117156982
# Test accuracy: 0.7616326808929443
# 39/39 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.72      0.74      0.73       208
#            1       0.54      0.30      0.39       250
#            2       0.81      0.92      0.86       767
#
#     accuracy                           0.76      1225
#    macro avg       0.69      0.65      0.66      1225
# weighted avg       0.74      0.76      0.74      1225

# %% [markdown]
# ### lr=0.0001 bs=16 - done

# %%
####################################################################################################################
#          We define our hyperparameters. everything is in the same cell for convenience

learning_rate = [0.0001]
batch_size = [16]

####################################################################################################################
#           We define our model specific parameters

model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)

####################################################################################################################
#           We print the number of models and state the hyperparameter search

print(f'Running learning rate:{learning_rate} and batch size: {batch_size} for epochs: {epochs}')

####################################################################################################################
#           We loop in our hyperparameters

for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')

            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 

            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 

            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False

            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            #       The top model dense layers are arbitrarily chosen.

            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            
            ####################################################################################################################
            #       We Compile our model

            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.

            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')

            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)


            ####################################################################################################################
            #       Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            ####################################################################################################################
            #       save model with acc for later investigaion

            model.save('model{} acc{}  lr{} batch size{}.h5'.format(model_name,score[1], i,j,))
            ####################################################################################################################
            #       print visualization of training metrics           
            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)         

            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model

            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])


            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')


            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            # Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            model.save(' fintunedmodel{} acc{} lr{} batch size{}.h5'.format(model_name,score[1], i,j,))

            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)
# Out:
# Running learning rate:[0.0001] and batch size: [16] for epochs: 100
# Running:
#  learning rate:0.0001, batch size: 16 for epochs: 100
# Epoch 1/100
# 848/848 [==============================] - 32s 29ms/step - loss: 1.1440 - accuracy: 0.5427 - val_loss: 1.0774 - val_accuracy: 0.5233
# Epoch 2/100
# 848/848 [==============================] - 23s 27ms/step - loss: 0.7108 - accuracy: 0.6575 - val_loss: 1.0878 - val_accuracy: 0.5486
# Epoch 3/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.5458 - accuracy: 0.7534 - val_loss: 1.1899 - val_accuracy: 0.5012
# Epoch 4/100
# 848/848 [==============================] - 23s 27ms/step - loss: 0.3823 - accuracy: 0.8426 - val_loss: 1.3376 - val_accuracy: 0.5951
# Epoch 5/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.2483 - accuracy: 0.9023 - val_loss: 1.5435 - val_accuracy: 0.5657
# Epoch 6/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.1719 - accuracy: 0.9394 - val_loss: 1.7671 - val_accuracy: 0.5576
# Epoch 7/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.1157 - accuracy: 0.9608 - val_loss: 1.8119 - val_accuracy: 0.5878
# Epoch 8/100
# 848/848 [==============================] - 22s 27ms/step - loss: 0.0926 - accuracy: 0.9682 - val_loss: 2.2205 - val_accuracy: 0.5380
# Epoch 9/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0829 - accuracy: 0.9729 - val_loss: 2.1823 - val_accuracy: 0.5437
# Epoch 10/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0671 - accuracy: 0.9789 - val_loss: 2.2088 - val_accuracy: 0.5763
# Epoch 11/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0730 - accuracy: 0.9743 - val_loss: 2.5050 - val_accuracy: 0.5322
# Epoch 12/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0520 - accuracy: 0.9838 - val_loss: 2.4815 - val_accuracy: 0.5763
# Epoch 13/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0487 - accuracy: 0.9833 - val_loss: 2.6636 - val_accuracy: 0.5461
# Epoch 14/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0503 - accuracy: 0.9833 - val_loss: 2.9576 - val_accuracy: 0.5543
# Epoch 15/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0471 - accuracy: 0.9834 - val_loss: 3.0973 - val_accuracy: 0.5347
# Epoch 16/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0370 - accuracy: 0.9880 - val_loss: 2.9903 - val_accuracy: 0.5478
# Epoch 17/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0440 - accuracy: 0.9852 - val_loss: 2.7846 - val_accuracy: 0.5518
# Epoch 18/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0258 - accuracy: 0.9911 - val_loss: 3.2363 - val_accuracy: 0.5567
# Epoch 19/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0526 - accuracy: 0.9827 - val_loss: 2.7227 - val_accuracy: 0.5796
# Epoch 20/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0349 - accuracy: 0.9888 - val_loss: 2.9747 - val_accuracy: 0.5371
# Epoch 21/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0331 - accuracy: 0.9894 - val_loss: 3.0731 - val_accuracy: 0.5698
# Epoch 22/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0300 - accuracy: 0.9897 - val_loss: 3.4190 - val_accuracy: 0.5673
# Epoch 23/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0341 - accuracy: 0.9883 - val_loss: 3.9183 - val_accuracy: 0.4890
# Epoch 24/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0252 - accuracy: 0.9914 - val_loss: 4.0936 - val_accuracy: 0.5380
# Epoch 25/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0330 - accuracy: 0.9889 - val_loss: 3.8626 - val_accuracy: 0.5282
# Epoch 26/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0405 - accuracy: 0.9873 - val_loss: 3.3259 - val_accuracy: 0.5706
# Epoch 27/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 4.3211 - val_accuracy: 0.5094
# Epoch 28/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0378 - accuracy: 0.9883 - val_loss: 3.7035 - val_accuracy: 0.5649
# Epoch 29/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 3.8694 - val_accuracy: 0.5478
# Epoch 30/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0346 - accuracy: 0.9883 - val_loss: 4.0992 - val_accuracy: 0.5527
# Epoch 31/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 3.9998 - val_accuracy: 0.5829
# Epoch 32/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0274 - accuracy: 0.9913 - val_loss: 3.5499 - val_accuracy: 0.5673
# Epoch 33/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0374 - accuracy: 0.9889 - val_loss: 3.9988 - val_accuracy: 0.5314
# Epoch 34/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 4.2901 - val_accuracy: 0.5078
# Epoch 35/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0356 - accuracy: 0.9888 - val_loss: 4.9429 - val_accuracy: 0.5053
# Epoch 36/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0233 - accuracy: 0.9934 - val_loss: 4.5772 - val_accuracy: 0.5086
# Epoch 37/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0289 - accuracy: 0.9906 - val_loss: 4.0461 - val_accuracy: 0.5486
# Epoch 38/100
# 848/848 [==============================] - 23s 27ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 3.7424 - val_accuracy: 0.6041
# Epoch 39/100
# 848/848 [==============================] - 23s 27ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 4.1891 - val_accuracy: 0.5918
# Epoch 40/100
# 848/848 [==============================] - 23s 27ms/step - loss: 0.0245 - accuracy: 0.9928 - val_loss: 4.1328 - val_accuracy: 0.5535
# Epoch 41/100
# 848/848 [==============================] - 23s 27ms/step - loss: 0.0271 - accuracy: 0.9914 - val_loss: 4.6179 - val_accuracy: 0.5282
# Epoch 42/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0245 - accuracy: 0.9907 - val_loss: 4.5960 - val_accuracy: 0.5380
# Epoch 43/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0295 - accuracy: 0.9914 - val_loss: 4.0142 - val_accuracy: 0.5788
# Epoch 44/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 5.0358 - val_accuracy: 0.5208
# Epoch 45/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 4.8108 - val_accuracy: 0.5649
# Epoch 46/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0319 - accuracy: 0.9906 - val_loss: 4.6294 - val_accuracy: 0.5314
# Epoch 47/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0317 - accuracy: 0.9897 - val_loss: 4.8957 - val_accuracy: 0.5600
# Epoch 48/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0283 - accuracy: 0.9906 - val_loss: 4.5778 - val_accuracy: 0.5763
# Epoch 49/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 4.9861 - val_accuracy: 0.5159
# Epoch 50/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 4.8347 - val_accuracy: 0.5535
# Epoch 51/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 5.6795 - val_accuracy: 0.5151
# Epoch 52/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0388 - accuracy: 0.9880 - val_loss: 4.9224 - val_accuracy: 0.5755
# Epoch 53/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0244 - accuracy: 0.9934 - val_loss: 5.1375 - val_accuracy: 0.5543
# Epoch 54/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 5.2423 - val_accuracy: 0.5535
# Epoch 55/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0288 - accuracy: 0.9911 - val_loss: 5.1678 - val_accuracy: 0.5388
# Epoch 56/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0292 - accuracy: 0.9920 - val_loss: 4.8727 - val_accuracy: 0.5273
# Epoch 57/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 5.3449 - val_accuracy: 0.5608
# Epoch 58/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0298 - accuracy: 0.9921 - val_loss: 5.4195 - val_accuracy: 0.5429
# Epoch 59/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0176 - accuracy: 0.9948 - val_loss: 5.0299 - val_accuracy: 0.5616
# Epoch 60/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 5.2396 - val_accuracy: 0.5910
# Epoch 61/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0292 - accuracy: 0.9913 - val_loss: 4.8905 - val_accuracy: 0.5657
# Epoch 62/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 6.4383 - val_accuracy: 0.4873
# Epoch 63/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 5.2742 - val_accuracy: 0.5339
# Epoch 64/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0271 - accuracy: 0.9933 - val_loss: 5.0896 - val_accuracy: 0.5665
# Epoch 65/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0228 - accuracy: 0.9937 - val_loss: 5.3171 - val_accuracy: 0.5216
# Epoch 66/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0120 - accuracy: 0.9959 - val_loss: 5.0278 - val_accuracy: 0.5722
# Epoch 67/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 5.8063 - val_accuracy: 0.5869
# Epoch 68/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0294 - accuracy: 0.9909 - val_loss: 5.0156 - val_accuracy: 0.5739
# Epoch 69/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0288 - accuracy: 0.9929 - val_loss: 5.1415 - val_accuracy: 0.5510
# Epoch 70/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 6.3750 - val_accuracy: 0.5445
# Epoch 71/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0326 - accuracy: 0.9906 - val_loss: 5.2493 - val_accuracy: 0.5551
# Epoch 72/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0169 - accuracy: 0.9950 - val_loss: 5.2992 - val_accuracy: 0.5551
# Epoch 73/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0247 - accuracy: 0.9927 - val_loss: 5.5707 - val_accuracy: 0.5837
# Epoch 74/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0129 - accuracy: 0.9966 - val_loss: 6.0203 - val_accuracy: 0.5755
# Epoch 75/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0227 - accuracy: 0.9939 - val_loss: 5.6525 - val_accuracy: 0.5886
# Epoch 76/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0190 - accuracy: 0.9948 - val_loss: 5.2610 - val_accuracy: 0.5731
# Epoch 77/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0208 - accuracy: 0.9942 - val_loss: 6.2271 - val_accuracy: 0.5429
# Epoch 78/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0254 - accuracy: 0.9922 - val_loss: 5.4900 - val_accuracy: 0.5722
# Epoch 79/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0159 - accuracy: 0.9953 - val_loss: 5.7509 - val_accuracy: 0.5420
# Epoch 80/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0235 - accuracy: 0.9940 - val_loss: 5.5785 - val_accuracy: 0.5641
# Epoch 81/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0224 - accuracy: 0.9954 - val_loss: 5.2962 - val_accuracy: 0.5714
# Epoch 82/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0212 - accuracy: 0.9949 - val_loss: 5.3882 - val_accuracy: 0.5771
# Epoch 83/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0066 - accuracy: 0.9987 - val_loss: 5.7428 - val_accuracy: 0.5649
# Epoch 84/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 6.0526 - val_accuracy: 0.5706
# Epoch 85/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 6.4190 - val_accuracy: 0.5673
# Epoch 86/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0645 - accuracy: 0.9830 - val_loss: 6.2836 - val_accuracy: 0.5886
# Epoch 87/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0273 - accuracy: 0.9931 - val_loss: 5.9140 - val_accuracy: 0.5935
# Epoch 88/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 6.0633 - val_accuracy: 0.5959
# Epoch 89/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 6.2149 - val_accuracy: 0.5731
# Epoch 90/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 6.8271 - val_accuracy: 0.5747
# Epoch 91/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0504 - accuracy: 0.9882 - val_loss: 5.8717 - val_accuracy: 0.5935
# Epoch 92/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0300 - accuracy: 0.9924 - val_loss: 5.6018 - val_accuracy: 0.5927
# Epoch 93/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0157 - accuracy: 0.9964 - val_loss: 6.1946 - val_accuracy: 0.5510
# Epoch 94/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 6.1611 - val_accuracy: 0.5657
# Epoch 95/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 6.8958 - val_accuracy: 0.5265
# Epoch 96/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 7.4447 - val_accuracy: 0.5959
# Epoch 97/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0269 - accuracy: 0.9926 - val_loss: 7.4335 - val_accuracy: 0.5176
# Epoch 98/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0269 - accuracy: 0.9938 - val_loss: 5.8888 - val_accuracy: 0.5412
# Epoch 99/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0281 - accuracy: 0.9937 - val_loss: 6.4099 - val_accuracy: 0.5624
# Epoch 100/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.0212 - accuracy: 0.9945 - val_loss: 6.1652 - val_accuracy: 0.5633
# Test loss: 3.561795234680176
# Test accuracy: 0.5828571319580078
# 39/39 [==============================] - 1s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.40      0.34      0.37       208
#            1       0.26      0.26      0.26       250
#            2       0.73      0.75      0.74       767
#
#     accuracy                           0.58      1225
#    macro avg       0.46      0.45      0.46      1225
# weighted avg       0.58      0.58      0.58      1225
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 848/848 [==============================] - 79s 89ms/step - loss: 0.8664 - accuracy: 0.6029 - val_loss: 0.7555 - val_accuracy: 0.7273
# Epoch 2/30
# 848/848 [==============================] - 74s 87ms/step - loss: 0.6630 - accuracy: 0.7144 - val_loss: 0.7280 - val_accuracy: 0.7224
# Epoch 3/30
# 848/848 [==============================] - 74s 88ms/step - loss: 0.6165 - accuracy: 0.7358 - val_loss: 0.6793 - val_accuracy: 0.7404
# Epoch 4/30
# 848/848 [==============================] - 74s 87ms/step - loss: 0.5791 - accuracy: 0.7545 - val_loss: 0.7892 - val_accuracy: 0.6735
# Epoch 5/30
# 848/848 [==============================] - 74s 87ms/step - loss: 0.5534 - accuracy: 0.7599 - val_loss: 0.8498 - val_accuracy: 0.6898
# Epoch 6/30
# 848/848 [==============================] - 73s 87ms/step - loss: 0.5332 - accuracy: 0.7653 - val_loss: 0.6874 - val_accuracy: 0.7363
# Epoch 7/30
# 848/848 [==============================] - 73s 87ms/step - loss: 0.5197 - accuracy: 0.7733 - val_loss: 0.7306 - val_accuracy: 0.7314
# Epoch 8/30
# 848/848 [==============================] - 74s 87ms/step - loss: 0.5019 - accuracy: 0.7788 - val_loss: 0.6859 - val_accuracy: 0.7576
# Epoch 9/30
# 848/848 [==============================] - 73s 87ms/step - loss: 0.4769 - accuracy: 0.7954 - val_loss: 0.7454 - val_accuracy: 0.7347
# Epoch 10/30
# 848/848 [==============================] - 73s 86ms/step - loss: 0.4626 - accuracy: 0.8002 - val_loss: 0.7566 - val_accuracy: 0.7322
# Epoch 11/30
# 848/848 [==============================] - 73s 86ms/step - loss: 0.4339 - accuracy: 0.8103 - val_loss: 0.6644 - val_accuracy: 0.7567
# Epoch 12/30
# 848/848 [==============================] - 73s 86ms/step - loss: 0.3989 - accuracy: 0.8311 - val_loss: 0.7200 - val_accuracy: 0.7371
# Epoch 13/30
# 848/848 [==============================] - 73s 86ms/step - loss: 0.3743 - accuracy: 0.8413 - val_loss: 0.7476 - val_accuracy: 0.7461
# Epoch 14/30
# 848/848 [==============================] - 73s 86ms/step - loss: 0.3260 - accuracy: 0.8617 - val_loss: 0.8732 - val_accuracy: 0.7306
# Epoch 15/30
# 848/848 [==============================] - 73s 86ms/step - loss: 0.2866 - accuracy: 0.8820 - val_loss: 0.9447 - val_accuracy: 0.7371
# Epoch 16/30
# 848/848 [==============================] - 73s 86ms/step - loss: 0.2474 - accuracy: 0.9020 - val_loss: 0.8807 - val_accuracy: 0.7388
# Epoch 17/30
# 848/848 [==============================] - 73s 86ms/step - loss: 0.2017 - accuracy: 0.9203 - val_loss: 1.2002 - val_accuracy: 0.6800
# Epoch 18/30
# 848/848 [==============================] - 73s 86ms/step - loss: 0.1707 - accuracy: 0.9377 - val_loss: 1.2154 - val_accuracy: 0.7053
# Epoch 19/30
# 848/848 [==============================] - 73s 86ms/step - loss: 0.1533 - accuracy: 0.9430 - val_loss: 1.1347 - val_accuracy: 0.7355
# Epoch 20/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.1295 - accuracy: 0.9535 - val_loss: 1.1565 - val_accuracy: 0.7453
# Epoch 21/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.1112 - accuracy: 0.9604 - val_loss: 1.5153 - val_accuracy: 0.7437
# Epoch 22/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.1072 - accuracy: 0.9611 - val_loss: 1.6736 - val_accuracy: 0.7069
# Epoch 23/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.0935 - accuracy: 0.9675 - val_loss: 1.9364 - val_accuracy: 0.6506
# Epoch 24/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.0886 - accuracy: 0.9693 - val_loss: 1.4226 - val_accuracy: 0.7437
# Epoch 25/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.0800 - accuracy: 0.9709 - val_loss: 1.8449 - val_accuracy: 0.6947
# Epoch 26/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.0787 - accuracy: 0.9730 - val_loss: 1.3848 - val_accuracy: 0.6735
# Epoch 27/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.0787 - accuracy: 0.9743 - val_loss: 1.4881 - val_accuracy: 0.6669
# Epoch 28/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.0640 - accuracy: 0.9774 - val_loss: 1.7944 - val_accuracy: 0.7118
# Epoch 29/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.0892 - accuracy: 0.9701 - val_loss: 1.4843 - val_accuracy: 0.7224
# Epoch 30/30
# 848/848 [==============================] - 75s 88ms/step - loss: 0.0483 - accuracy: 0.9827 - val_loss: 1.5994 - val_accuracy: 0.7135
# Test loss: 0.6737121343612671
# Test accuracy: 0.7632653117179871
# 39/39 [==============================] - 1s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.74      0.68      0.71       208
#            1       0.52      0.50      0.51       250
#            2       0.84      0.87      0.86       767
#
#     accuracy                           0.76      1225
#    macro avg       0.70      0.68      0.69      1225
# weighted avg       0.76      0.76      0.76      1225

# %% [markdown]
# ### lr=0,001 bs=64 - done

# %%
####################################################################################################################
#          We define our hyperparameters. everything is in the same cell for convenience

learning_rate = [0.001]
batch_size = [64]

####################################################################################################################
#           We define our model specific parameters

model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)

####################################################################################################################
#           We print the number of models and state the hyperparameter search

print(f'Running learning rate:{learning_rate} and batch size: {batch_size} for epochs: {epochs}')

####################################################################################################################
#           We loop in our hyperparameters

for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')

            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 

            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 

            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False

            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            #       The top model dense layers are arbitrarily chosen.

            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            
            ####################################################################################################################
            #       We Compile our model

            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.

            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')

            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)


            ####################################################################################################################
            #       Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            ####################################################################################################################
            #       save model with acc for later investigaion

            model.save('model{} acc{}  lr{} batch size{}.h5'.format(model_name,score[1], i,j,))
            ####################################################################################################################
            #       print visualization of training metrics           
            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)         

            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model

            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])


            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')


            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            # Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            model.save(' fintunedmodel{} acc{} lr{} batch size{}.h5'.format(model_name,score[1], i,j,))

            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)
# Out:
# Running learning rate:[0.001] and batch size: [64] for epochs: 100
# Running:
#  learning rate:0.001, batch size: 64 for epochs: 100
# Epoch 1/100
# 212/212 [==============================] - 30s 99ms/step - loss: 1.9942 - accuracy: 0.5491 - val_loss: 0.8946 - val_accuracy: 0.6220
# Epoch 2/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.7276 - accuracy: 0.6414 - val_loss: 0.9719 - val_accuracy: 0.6131
# Epoch 3/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.6574 - accuracy: 0.6844 - val_loss: 1.0185 - val_accuracy: 0.6016
# Epoch 4/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.5865 - accuracy: 0.7211 - val_loss: 1.1704 - val_accuracy: 0.5624
# Epoch 5/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.5085 - accuracy: 0.7676 - val_loss: 1.3078 - val_accuracy: 0.5943
# Epoch 6/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.4458 - accuracy: 0.7970 - val_loss: 1.3866 - val_accuracy: 0.6155
# Epoch 7/100
# 212/212 [==============================] - 17s 78ms/step - loss: 0.3802 - accuracy: 0.8311 - val_loss: 1.9168 - val_accuracy: 0.5200
# Epoch 8/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.3276 - accuracy: 0.8553 - val_loss: 1.8394 - val_accuracy: 0.5053
# Epoch 9/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.2799 - accuracy: 0.8829 - val_loss: 2.3231 - val_accuracy: 0.4727
# Epoch 10/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.2303 - accuracy: 0.9035 - val_loss: 2.0840 - val_accuracy: 0.5747
# Epoch 11/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.2146 - accuracy: 0.9131 - val_loss: 2.5688 - val_accuracy: 0.5306
# Epoch 12/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.1664 - accuracy: 0.9349 - val_loss: 2.3551 - val_accuracy: 0.5600
# Epoch 13/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.1770 - accuracy: 0.9289 - val_loss: 2.7321 - val_accuracy: 0.5029
# Epoch 14/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.1472 - accuracy: 0.9433 - val_loss: 2.6020 - val_accuracy: 0.5918
# Epoch 15/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.1213 - accuracy: 0.9519 - val_loss: 3.2271 - val_accuracy: 0.5282
# Epoch 16/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.1387 - accuracy: 0.9505 - val_loss: 2.6883 - val_accuracy: 0.5706
# Epoch 17/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.1066 - accuracy: 0.9594 - val_loss: 3.4989 - val_accuracy: 0.5127
# Epoch 18/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.1019 - accuracy: 0.9633 - val_loss: 3.4028 - val_accuracy: 0.5127
# Epoch 19/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0882 - accuracy: 0.9677 - val_loss: 3.4806 - val_accuracy: 0.5192
# Epoch 20/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0594 - accuracy: 0.9796 - val_loss: 4.0272 - val_accuracy: 0.5641
# Epoch 21/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0963 - accuracy: 0.9677 - val_loss: 3.3929 - val_accuracy: 0.5861
# Epoch 22/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0890 - accuracy: 0.9684 - val_loss: 3.6401 - val_accuracy: 0.5363
# Epoch 23/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0770 - accuracy: 0.9733 - val_loss: 3.6243 - val_accuracy: 0.5690
# Epoch 24/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0730 - accuracy: 0.9748 - val_loss: 3.8927 - val_accuracy: 0.5273
# Epoch 25/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0680 - accuracy: 0.9781 - val_loss: 4.1771 - val_accuracy: 0.4718
# Epoch 26/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0657 - accuracy: 0.9768 - val_loss: 4.1899 - val_accuracy: 0.5420
# Epoch 27/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0609 - accuracy: 0.9795 - val_loss: 4.4343 - val_accuracy: 0.5331
# Epoch 28/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0927 - accuracy: 0.9718 - val_loss: 4.1085 - val_accuracy: 0.5429
# Epoch 29/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0564 - accuracy: 0.9803 - val_loss: 4.1944 - val_accuracy: 0.5812
# Epoch 30/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0488 - accuracy: 0.9844 - val_loss: 4.1943 - val_accuracy: 0.5543
# Epoch 31/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0630 - accuracy: 0.9793 - val_loss: 4.1382 - val_accuracy: 0.5584
# Epoch 32/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0452 - accuracy: 0.9847 - val_loss: 4.9502 - val_accuracy: 0.4914
# Epoch 33/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0665 - accuracy: 0.9780 - val_loss: 4.5548 - val_accuracy: 0.5673
# Epoch 34/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0497 - accuracy: 0.9820 - val_loss: 3.8245 - val_accuracy: 0.5576
# Epoch 35/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0536 - accuracy: 0.9824 - val_loss: 4.9429 - val_accuracy: 0.5322
# Epoch 36/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0450 - accuracy: 0.9854 - val_loss: 4.9698 - val_accuracy: 0.5355
# Epoch 37/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0482 - accuracy: 0.9843 - val_loss: 5.0555 - val_accuracy: 0.5527
# Epoch 38/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0514 - accuracy: 0.9842 - val_loss: 4.3594 - val_accuracy: 0.5722
# Epoch 39/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0579 - accuracy: 0.9819 - val_loss: 4.1323 - val_accuracy: 0.5592
# Epoch 40/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0651 - accuracy: 0.9824 - val_loss: 4.6939 - val_accuracy: 0.5420
# Epoch 41/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0449 - accuracy: 0.9855 - val_loss: 5.0204 - val_accuracy: 0.5567
# Epoch 42/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0313 - accuracy: 0.9899 - val_loss: 5.5662 - val_accuracy: 0.5069
# Epoch 43/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0470 - accuracy: 0.9855 - val_loss: 5.4049 - val_accuracy: 0.5298
# Epoch 44/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0680 - accuracy: 0.9778 - val_loss: 5.0730 - val_accuracy: 0.5616
# Epoch 45/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0588 - accuracy: 0.9798 - val_loss: 5.6122 - val_accuracy: 0.5633
# Epoch 46/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0553 - accuracy: 0.9836 - val_loss: 4.5100 - val_accuracy: 0.6082
# Epoch 47/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0594 - accuracy: 0.9810 - val_loss: 4.8241 - val_accuracy: 0.5616
# Epoch 48/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0290 - accuracy: 0.9909 - val_loss: 5.0801 - val_accuracy: 0.5624
# Epoch 49/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.0323 - accuracy: 0.9900 - val_loss: 5.0556 - val_accuracy: 0.5796
# Epoch 50/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.0421 - accuracy: 0.9877 - val_loss: 5.5681 - val_accuracy: 0.5469
# Epoch 51/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0381 - accuracy: 0.9874 - val_loss: 5.4990 - val_accuracy: 0.5502
# Epoch 52/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0319 - accuracy: 0.9904 - val_loss: 5.1049 - val_accuracy: 0.5690
# Epoch 53/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0382 - accuracy: 0.9878 - val_loss: 5.4295 - val_accuracy: 0.5722
# Epoch 54/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0574 - accuracy: 0.9841 - val_loss: 5.9564 - val_accuracy: 0.5135
# Epoch 55/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0848 - accuracy: 0.9771 - val_loss: 5.0190 - val_accuracy: 0.5494
# Epoch 56/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0441 - accuracy: 0.9858 - val_loss: 5.2585 - val_accuracy: 0.5527
# Epoch 57/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0326 - accuracy: 0.9921 - val_loss: 5.5180 - val_accuracy: 0.5265
# Epoch 58/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0310 - accuracy: 0.9903 - val_loss: 5.5121 - val_accuracy: 0.5812
# Epoch 59/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0535 - accuracy: 0.9843 - val_loss: 5.0343 - val_accuracy: 0.5649
# Epoch 60/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0463 - accuracy: 0.9851 - val_loss: 6.1566 - val_accuracy: 0.5788
# Epoch 61/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0409 - accuracy: 0.9883 - val_loss: 5.7177 - val_accuracy: 0.5273
# Epoch 62/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0331 - accuracy: 0.9880 - val_loss: 5.6514 - val_accuracy: 0.5829
# Epoch 63/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0094 - accuracy: 0.9972 - val_loss: 6.1700 - val_accuracy: 0.5641
# Epoch 64/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0489 - accuracy: 0.9858 - val_loss: 6.3250 - val_accuracy: 0.5184
# Epoch 65/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0554 - accuracy: 0.9841 - val_loss: 6.9275 - val_accuracy: 0.5527
# Epoch 66/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0572 - accuracy: 0.9862 - val_loss: 5.8950 - val_accuracy: 0.5739
# Epoch 67/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0543 - accuracy: 0.9869 - val_loss: 6.3586 - val_accuracy: 0.5396
# Epoch 68/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0251 - accuracy: 0.9932 - val_loss: 6.2778 - val_accuracy: 0.5567
# Epoch 69/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0504 - accuracy: 0.9869 - val_loss: 6.1097 - val_accuracy: 0.5371
# Epoch 70/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 5.8646 - val_accuracy: 0.5739
# Epoch 71/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 6.3115 - val_accuracy: 0.5453
# Epoch 72/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0259 - accuracy: 0.9926 - val_loss: 6.6021 - val_accuracy: 0.5380
# Epoch 73/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0182 - accuracy: 0.9954 - val_loss: 6.8864 - val_accuracy: 0.5763
# Epoch 74/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0611 - accuracy: 0.9840 - val_loss: 5.6279 - val_accuracy: 0.5559
# Epoch 75/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0706 - accuracy: 0.9811 - val_loss: 6.4353 - val_accuracy: 0.5608
# Epoch 76/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0544 - accuracy: 0.9864 - val_loss: 8.5766 - val_accuracy: 0.4433
# Epoch 77/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0422 - accuracy: 0.9886 - val_loss: 6.8095 - val_accuracy: 0.5731
# Epoch 78/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0305 - accuracy: 0.9925 - val_loss: 6.7750 - val_accuracy: 0.5698
# Epoch 79/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0649 - accuracy: 0.9847 - val_loss: 6.3728 - val_accuracy: 0.5510
# Epoch 80/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0440 - accuracy: 0.9885 - val_loss: 7.8940 - val_accuracy: 0.5722
# Epoch 81/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0343 - accuracy: 0.9899 - val_loss: 7.5752 - val_accuracy: 0.5518
# Epoch 82/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0499 - accuracy: 0.9879 - val_loss: 6.8337 - val_accuracy: 0.5771
# Epoch 83/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0252 - accuracy: 0.9926 - val_loss: 7.4024 - val_accuracy: 0.5437
# Epoch 84/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0261 - accuracy: 0.9918 - val_loss: 7.8005 - val_accuracy: 0.5494
# Epoch 85/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0257 - accuracy: 0.9931 - val_loss: 7.6000 - val_accuracy: 0.5747
# Epoch 86/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0251 - accuracy: 0.9931 - val_loss: 7.5495 - val_accuracy: 0.5812
# Epoch 87/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0321 - accuracy: 0.9929 - val_loss: 7.8259 - val_accuracy: 0.5624
# Epoch 88/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0304 - accuracy: 0.9929 - val_loss: 7.4805 - val_accuracy: 0.5820
# Epoch 89/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0466 - accuracy: 0.9866 - val_loss: 7.7139 - val_accuracy: 0.5576
# Epoch 90/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0325 - accuracy: 0.9913 - val_loss: 7.0492 - val_accuracy: 0.5682
# Epoch 91/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0539 - accuracy: 0.9866 - val_loss: 7.5137 - val_accuracy: 0.5592
# Epoch 92/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0251 - accuracy: 0.9925 - val_loss: 8.1624 - val_accuracy: 0.5510
# Epoch 93/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0472 - accuracy: 0.9895 - val_loss: 8.8399 - val_accuracy: 0.5469
# Epoch 94/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0547 - accuracy: 0.9873 - val_loss: 7.7620 - val_accuracy: 0.5902
# Epoch 95/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0340 - accuracy: 0.9910 - val_loss: 7.3820 - val_accuracy: 0.5861
# Epoch 96/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0175 - accuracy: 0.9950 - val_loss: 8.1098 - val_accuracy: 0.5673
# Epoch 97/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0447 - accuracy: 0.9884 - val_loss: 8.7889 - val_accuracy: 0.5380
# Epoch 98/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0464 - accuracy: 0.9887 - val_loss: 8.1125 - val_accuracy: 0.5649
# Epoch 99/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0233 - accuracy: 0.9934 - val_loss: 7.4280 - val_accuracy: 0.5600
# Epoch 100/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.0103 - accuracy: 0.9961 - val_loss: 7.9342 - val_accuracy: 0.5690
# Test loss: 0.8927522301673889
# Test accuracy: 0.6122449040412903
# 39/39 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.38      0.40      0.39       208
#            1       0.25      0.12      0.16       250
#            2       0.72      0.83      0.77       767
#
#     accuracy                           0.61      1225
#    macro avg       0.45      0.45      0.44      1225
# weighted avg       0.57      0.61      0.58      1225
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 212/212 [==============================] - 80s 329ms/step - loss: 4.2252 - accuracy: 0.4675 - val_loss: 1.3237 - val_accuracy: 0.2180
# Epoch 2/30
# 212/212 [==============================] - 62s 291ms/step - loss: 1.0220 - accuracy: 0.4768 - val_loss: 1.4838 - val_accuracy: 0.2180
# Epoch 3/30
# 212/212 [==============================] - 62s 291ms/step - loss: 1.0221 - accuracy: 0.4768 - val_loss: 1.4893 - val_accuracy: 0.2180
# Epoch 4/30
# 212/212 [==============================] - 62s 291ms/step - loss: 1.0207 - accuracy: 0.4768 - val_loss: 1.3626 - val_accuracy: 0.2180
# Epoch 5/30
# 212/212 [==============================] - 62s 291ms/step - loss: 1.0690 - accuracy: 0.4706 - val_loss: 1.3872 - val_accuracy: 0.2180
# Epoch 6/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.2445 - accuracy: 0.4655 - val_loss: 1.4177 - val_accuracy: 0.2180
# Epoch 7/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0261 - accuracy: 0.4745 - val_loss: 1.5457 - val_accuracy: 0.2180
# Epoch 8/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0213 - accuracy: 0.4768 - val_loss: 1.5160 - val_accuracy: 0.2180
# Epoch 9/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4065 - val_accuracy: 0.2180
# Epoch 10/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0210 - accuracy: 0.4768 - val_loss: 1.4323 - val_accuracy: 0.2180
# Epoch 11/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.3453 - val_accuracy: 0.2180
# Epoch 12/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4135 - val_accuracy: 0.2180
# Epoch 13/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.5219 - val_accuracy: 0.2180
# Epoch 14/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0207 - accuracy: 0.4768 - val_loss: 1.3701 - val_accuracy: 0.2180
# Epoch 15/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4548 - val_accuracy: 0.2180
# Epoch 16/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0199 - accuracy: 0.4768 - val_loss: 1.3948 - val_accuracy: 0.2180
# Epoch 17/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4513 - val_accuracy: 0.2180
# Epoch 18/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0199 - accuracy: 0.4768 - val_loss: 1.4409 - val_accuracy: 0.2180
# Epoch 19/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4825 - val_accuracy: 0.2180
# Epoch 20/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0207 - accuracy: 0.4768 - val_loss: 1.4247 - val_accuracy: 0.2180
# Epoch 21/30
# 212/212 [==============================] - 61s 289ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4688 - val_accuracy: 0.2180
# Epoch 22/30
# 212/212 [==============================] - 62s 294ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4465 - val_accuracy: 0.2180
# Epoch 23/30
# 212/212 [==============================] - 63s 295ms/step - loss: 1.0199 - accuracy: 0.4768 - val_loss: 1.4492 - val_accuracy: 0.2180
# Epoch 24/30
# 212/212 [==============================] - 62s 295ms/step - loss: 1.0201 - accuracy: 0.4760 - val_loss: 1.4556 - val_accuracy: 0.2180
# Epoch 25/30
# 212/212 [==============================] - 62s 294ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4478 - val_accuracy: 0.2180
# Epoch 26/30
# 212/212 [==============================] - 63s 297ms/step - loss: 1.0199 - accuracy: 0.4768 - val_loss: 1.4523 - val_accuracy: 0.2180
# Epoch 27/30
# 212/212 [==============================] - 63s 297ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4084 - val_accuracy: 0.2180
# Epoch 28/30
# 212/212 [==============================] - 62s 295ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4377 - val_accuracy: 0.2180
# Epoch 29/30
# 212/212 [==============================] - 63s 295ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4485 - val_accuracy: 0.2180
# Epoch 30/30
# 212/212 [==============================] - 63s 295ms/step - loss: 1.0198 - accuracy: 0.4768 - val_loss: 1.4650 - val_accuracy: 0.2180
# Test loss: 1.3253722190856934
# Test accuracy: 0.20408163964748383
# 39/39 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       208
#            1       0.20      1.00      0.34       250
#            2       0.00      0.00      0.00       767
#
#     accuracy                           0.20      1225
#    macro avg       0.07      0.33      0.11      1225
# weighted avg       0.04      0.20      0.07      1225
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### lr 0,001 bs=32 - done

# %%
####################################################################################################################
#          We define our hyperparameters. everything is in the same cell for convenience

learning_rate = [0.001]
batch_size = [32]

####################################################################################################################
#           We define our model specific parameters

model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)

####################################################################################################################
#           We print the number of models and state the hyperparameter search

print(f'Running learning rate:{learning_rate} and batch size: {batch_size} for epochs: {epochs}')

####################################################################################################################
#           We loop in our hyperparameters

for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')

            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 

            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 

            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False

            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            #       The top model dense layers are arbitrarily chosen.

            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            
            ####################################################################################################################
            #       We Compile our model

            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.

            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')

            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)


            ####################################################################################################################
            #       Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            ####################################################################################################################
            #       save model with acc for later investigaion

            model.save('model{} acc{}  lr{} batch size{}.h5'.format(model_name,score[1], i,j,))
            ####################################################################################################################
            #       print visualization of training metrics           
            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)         

            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model

            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])


            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')


            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            # Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            model.save(' fintunedmodel{} acc{} lr{} batch size{}.h5'.format(model_name,score[1], i,j,))

            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)
# Out:
# Running learning rate:[0.001] and batch size: [32] for epochs: 100
# Running:
#  learning rate:0.001, batch size: 32 for epochs: 100
# Epoch 1/100
# 424/424 [==============================] - 29s 50ms/step - loss: 1.6414 - accuracy: 0.5506 - val_loss: 0.9380 - val_accuracy: 0.5771
# Epoch 2/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.7625 - accuracy: 0.6205 - val_loss: 1.0108 - val_accuracy: 0.5592
# Epoch 3/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.7147 - accuracy: 0.6429 - val_loss: 0.9371 - val_accuracy: 0.6294
# Epoch 4/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.6637 - accuracy: 0.6680 - val_loss: 1.2423 - val_accuracy: 0.5045
# Epoch 5/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.6170 - accuracy: 0.7006 - val_loss: 1.1623 - val_accuracy: 0.5812
# Epoch 6/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.5582 - accuracy: 0.7312 - val_loss: 1.1050 - val_accuracy: 0.6220
# Epoch 7/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.5050 - accuracy: 0.7593 - val_loss: 1.3043 - val_accuracy: 0.6024
# Epoch 8/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.4444 - accuracy: 0.7965 - val_loss: 1.5912 - val_accuracy: 0.5576
# Epoch 9/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.3790 - accuracy: 0.8308 - val_loss: 2.0007 - val_accuracy: 0.5927
# Epoch 10/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.3548 - accuracy: 0.8474 - val_loss: 1.8404 - val_accuracy: 0.5812
# Epoch 11/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.2994 - accuracy: 0.8723 - val_loss: 1.9517 - val_accuracy: 0.5290
# Epoch 12/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.2534 - accuracy: 0.8939 - val_loss: 2.5068 - val_accuracy: 0.5510
# Epoch 13/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.2295 - accuracy: 0.9062 - val_loss: 2.8136 - val_accuracy: 0.5290
# Epoch 14/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1927 - accuracy: 0.9230 - val_loss: 2.9334 - val_accuracy: 0.5339
# Epoch 15/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1847 - accuracy: 0.9256 - val_loss: 2.6175 - val_accuracy: 0.5731
# Epoch 16/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1594 - accuracy: 0.9405 - val_loss: 2.8261 - val_accuracy: 0.5812
# Epoch 17/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1338 - accuracy: 0.9486 - val_loss: 3.1047 - val_accuracy: 0.5241
# Epoch 18/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1585 - accuracy: 0.9405 - val_loss: 3.4243 - val_accuracy: 0.5249
# Epoch 19/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1289 - accuracy: 0.9540 - val_loss: 3.7678 - val_accuracy: 0.5233
# Epoch 20/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1074 - accuracy: 0.9594 - val_loss: 3.5314 - val_accuracy: 0.5918
# Epoch 21/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1268 - accuracy: 0.9571 - val_loss: 3.6749 - val_accuracy: 0.5543
# Epoch 22/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.1154 - accuracy: 0.9630 - val_loss: 3.9048 - val_accuracy: 0.5869
# Epoch 23/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0963 - accuracy: 0.9665 - val_loss: 3.9174 - val_accuracy: 0.5469
# Epoch 24/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0781 - accuracy: 0.9731 - val_loss: 4.2865 - val_accuracy: 0.5600
# Epoch 25/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0947 - accuracy: 0.9671 - val_loss: 4.5283 - val_accuracy: 0.5461
# Epoch 26/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0902 - accuracy: 0.9703 - val_loss: 4.5142 - val_accuracy: 0.5355
# Epoch 27/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0984 - accuracy: 0.9667 - val_loss: 4.7754 - val_accuracy: 0.5094
# Epoch 28/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0827 - accuracy: 0.9726 - val_loss: 4.5842 - val_accuracy: 0.5535
# Epoch 29/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0695 - accuracy: 0.9773 - val_loss: 5.5053 - val_accuracy: 0.5159
# Epoch 30/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0785 - accuracy: 0.9737 - val_loss: 4.7974 - val_accuracy: 0.5576
# Epoch 31/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0677 - accuracy: 0.9783 - val_loss: 5.2213 - val_accuracy: 0.5192
# Epoch 32/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0930 - accuracy: 0.9681 - val_loss: 4.7187 - val_accuracy: 0.5673
# Epoch 33/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0520 - accuracy: 0.9827 - val_loss: 5.5334 - val_accuracy: 0.5518
# Epoch 34/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0647 - accuracy: 0.9798 - val_loss: 5.5739 - val_accuracy: 0.5690
# Epoch 35/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0917 - accuracy: 0.9719 - val_loss: 5.0368 - val_accuracy: 0.5110
# Epoch 36/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0712 - accuracy: 0.9778 - val_loss: 4.7378 - val_accuracy: 0.5502
# Epoch 37/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0768 - accuracy: 0.9757 - val_loss: 5.3268 - val_accuracy: 0.5469
# Epoch 38/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0526 - accuracy: 0.9838 - val_loss: 5.0481 - val_accuracy: 0.5371
# Epoch 39/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0756 - accuracy: 0.9772 - val_loss: 5.8087 - val_accuracy: 0.5233
# Epoch 40/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0802 - accuracy: 0.9777 - val_loss: 5.5032 - val_accuracy: 0.5445
# Epoch 41/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0553 - accuracy: 0.9830 - val_loss: 5.8536 - val_accuracy: 0.5518
# Epoch 42/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0694 - accuracy: 0.9785 - val_loss: 5.6910 - val_accuracy: 0.5412
# Epoch 43/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0697 - accuracy: 0.9791 - val_loss: 5.6845 - val_accuracy: 0.5273
# Epoch 44/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0646 - accuracy: 0.9816 - val_loss: 6.3681 - val_accuracy: 0.5273
# Epoch 45/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0707 - accuracy: 0.9806 - val_loss: 5.7950 - val_accuracy: 0.5445
# Epoch 46/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0590 - accuracy: 0.9832 - val_loss: 5.9949 - val_accuracy: 0.5665
# Epoch 47/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0795 - accuracy: 0.9778 - val_loss: 5.6256 - val_accuracy: 0.5543
# Epoch 48/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0521 - accuracy: 0.9846 - val_loss: 6.2410 - val_accuracy: 0.5543
# Epoch 49/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0610 - accuracy: 0.9825 - val_loss: 6.3712 - val_accuracy: 0.5208
# Epoch 50/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0751 - accuracy: 0.9805 - val_loss: 6.3890 - val_accuracy: 0.5796
# Epoch 51/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0651 - accuracy: 0.9812 - val_loss: 5.9998 - val_accuracy: 0.5216
# Epoch 52/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0344 - accuracy: 0.9889 - val_loss: 7.0600 - val_accuracy: 0.5518
# Epoch 53/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0229 - accuracy: 0.9924 - val_loss: 6.9332 - val_accuracy: 0.5510
# Epoch 54/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0218 - accuracy: 0.9927 - val_loss: 8.0870 - val_accuracy: 0.5559
# Epoch 55/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.1373 - accuracy: 0.9653 - val_loss: 5.5840 - val_accuracy: 0.5486
# Epoch 56/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0594 - accuracy: 0.9832 - val_loss: 6.4042 - val_accuracy: 0.5339
# Epoch 57/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0570 - accuracy: 0.9827 - val_loss: 6.5964 - val_accuracy: 0.5527
# Epoch 58/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0465 - accuracy: 0.9866 - val_loss: 6.7207 - val_accuracy: 0.5714
# Epoch 59/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0466 - accuracy: 0.9862 - val_loss: 6.0135 - val_accuracy: 0.5633
# Epoch 60/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0646 - accuracy: 0.9831 - val_loss: 6.1047 - val_accuracy: 0.5665
# Epoch 61/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0606 - accuracy: 0.9833 - val_loss: 6.8317 - val_accuracy: 0.5576
# Epoch 62/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0298 - accuracy: 0.9897 - val_loss: 8.2525 - val_accuracy: 0.5576
# Epoch 63/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0661 - accuracy: 0.9833 - val_loss: 7.0140 - val_accuracy: 0.5412
# Epoch 64/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0607 - accuracy: 0.9833 - val_loss: 6.8447 - val_accuracy: 0.5657
# Epoch 65/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0451 - accuracy: 0.9878 - val_loss: 7.5089 - val_accuracy: 0.5567
# Epoch 66/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0645 - accuracy: 0.9824 - val_loss: 7.5605 - val_accuracy: 0.5845
# Epoch 67/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0406 - accuracy: 0.9886 - val_loss: 9.2996 - val_accuracy: 0.5698
# Epoch 68/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0721 - accuracy: 0.9838 - val_loss: 7.5107 - val_accuracy: 0.5355
# Epoch 69/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0507 - accuracy: 0.9876 - val_loss: 7.1489 - val_accuracy: 0.5567
# Epoch 70/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0373 - accuracy: 0.9909 - val_loss: 8.2142 - val_accuracy: 0.5192
# Epoch 71/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0663 - accuracy: 0.9824 - val_loss: 7.7221 - val_accuracy: 0.5363
# Epoch 72/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0518 - accuracy: 0.9858 - val_loss: 7.8620 - val_accuracy: 0.5796
# Epoch 73/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0329 - accuracy: 0.9907 - val_loss: 8.3615 - val_accuracy: 0.5543
# Epoch 74/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0804 - accuracy: 0.9810 - val_loss: 8.5937 - val_accuracy: 0.5224
# Epoch 75/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0771 - accuracy: 0.9810 - val_loss: 7.3430 - val_accuracy: 0.5445
# Epoch 76/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0358 - accuracy: 0.9916 - val_loss: 8.1897 - val_accuracy: 0.5714
# Epoch 77/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0392 - accuracy: 0.9897 - val_loss: 8.0941 - val_accuracy: 0.5478
# Epoch 78/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0816 - accuracy: 0.9838 - val_loss: 6.8030 - val_accuracy: 0.5510
# Epoch 79/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0432 - accuracy: 0.9898 - val_loss: 7.3808 - val_accuracy: 0.5469
# Epoch 80/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0328 - accuracy: 0.9904 - val_loss: 8.9689 - val_accuracy: 0.5673
# Epoch 81/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0576 - accuracy: 0.9855 - val_loss: 8.4249 - val_accuracy: 0.5143
# Epoch 82/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0613 - accuracy: 0.9866 - val_loss: 8.3006 - val_accuracy: 0.5339
# Epoch 83/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0638 - accuracy: 0.9847 - val_loss: 7.3784 - val_accuracy: 0.5665
# Epoch 84/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0316 - accuracy: 0.9923 - val_loss: 8.9890 - val_accuracy: 0.5453
# Epoch 85/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0477 - accuracy: 0.9893 - val_loss: 8.1146 - val_accuracy: 0.5567
# Epoch 86/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0655 - accuracy: 0.9848 - val_loss: 8.3112 - val_accuracy: 0.5910
# Epoch 87/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0756 - accuracy: 0.9842 - val_loss: 9.4312 - val_accuracy: 0.5102
# Epoch 88/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0810 - accuracy: 0.9827 - val_loss: 8.1151 - val_accuracy: 0.5502
# Epoch 89/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0166 - accuracy: 0.9953 - val_loss: 9.4215 - val_accuracy: 0.5429
# Epoch 90/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0186 - accuracy: 0.9945 - val_loss: 10.2114 - val_accuracy: 0.5494
# Epoch 91/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0204 - accuracy: 0.9948 - val_loss: 9.9921 - val_accuracy: 0.5657
# Epoch 92/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.0678 - accuracy: 0.9861 - val_loss: 8.7416 - val_accuracy: 0.5771
# Epoch 93/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0401 - accuracy: 0.9892 - val_loss: 8.8890 - val_accuracy: 0.5510
# Epoch 94/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0787 - accuracy: 0.9838 - val_loss: 10.7960 - val_accuracy: 0.4980
# Epoch 95/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0393 - accuracy: 0.9906 - val_loss: 10.8342 - val_accuracy: 0.5535
# Epoch 96/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0324 - accuracy: 0.9914 - val_loss: 8.8328 - val_accuracy: 0.5845
# Epoch 97/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0331 - accuracy: 0.9911 - val_loss: 10.9691 - val_accuracy: 0.5363
# Epoch 98/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0793 - accuracy: 0.9845 - val_loss: 9.6317 - val_accuracy: 0.5559
# Epoch 99/100
# 424/424 [==============================] - 18s 44ms/step - loss: 0.0765 - accuracy: 0.9831 - val_loss: 10.4538 - val_accuracy: 0.5616
# Epoch 100/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.0462 - accuracy: 0.9886 - val_loss: 10.0019 - val_accuracy: 0.5086
# Test loss: 0.9661286473274231
# Test accuracy: 0.6220408082008362
# 39/39 [==============================] - 1s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.44      0.40      0.42       208
#            1       0.30      0.22      0.26       250
#            2       0.73      0.81      0.77       767
#
#     accuracy                           0.62      1225
#    macro avg       0.49      0.48      0.48      1225
# weighted avg       0.59      0.62      0.61      1225
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 424/424 [==============================] - 78s 170ms/step - loss: 2.2435 - accuracy: 0.4725 - val_loss: 1.5367 - val_accuracy: 0.2180
# Epoch 2/30
# 424/424 [==============================] - 68s 161ms/step - loss: 1.0222 - accuracy: 0.4768 - val_loss: 1.4336 - val_accuracy: 0.2180
# Epoch 3/30
# 424/424 [==============================] - 67s 159ms/step - loss: 1.1656 - accuracy: 0.4733 - val_loss: 1.4063 - val_accuracy: 0.2180
# Epoch 4/30
# 424/424 [==============================] - 67s 159ms/step - loss: 1.0212 - accuracy: 0.4768 - val_loss: 1.4843 - val_accuracy: 0.2180
# Epoch 5/30
# 424/424 [==============================] - 67s 159ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.5315 - val_accuracy: 0.2180
# Epoch 6/30
# 424/424 [==============================] - 67s 159ms/step - loss: 1.0264 - accuracy: 0.4771 - val_loss: 1.3357 - val_accuracy: 0.2180
# Epoch 7/30
# 424/424 [==============================] - 68s 160ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.5468 - val_accuracy: 0.2180
# Epoch 8/30
# 424/424 [==============================] - 67s 159ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4089 - val_accuracy: 0.2180
# Epoch 9/30
# 424/424 [==============================] - 67s 159ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4760 - val_accuracy: 0.2180
# Epoch 10/30
# 424/424 [==============================] - 67s 158ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.5092 - val_accuracy: 0.2180
# Epoch 11/30
# 424/424 [==============================] - 67s 159ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4418 - val_accuracy: 0.2180
# Epoch 12/30
# 424/424 [==============================] - 67s 158ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.5038 - val_accuracy: 0.2180
# Epoch 13/30
# 424/424 [==============================] - 67s 158ms/step - loss: 1.0199 - accuracy: 0.4768 - val_loss: 1.5454 - val_accuracy: 0.2180
# Epoch 14/30
# 424/424 [==============================] - 67s 158ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.5044 - val_accuracy: 0.2180
# Epoch 15/30
# 424/424 [==============================] - 67s 158ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.5298 - val_accuracy: 0.2180
# Epoch 16/30
# 424/424 [==============================] - 67s 158ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4709 - val_accuracy: 0.2180
# Epoch 17/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0207 - accuracy: 0.4768 - val_loss: 1.4532 - val_accuracy: 0.2180
# Epoch 18/30
# 424/424 [==============================] - 67s 158ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.3333 - val_accuracy: 0.2180
# Epoch 19/30
# 424/424 [==============================] - 67s 158ms/step - loss: 1.0215 - accuracy: 0.4766 - val_loss: 1.3380 - val_accuracy: 0.2180
# Epoch 20/30
# 424/424 [==============================] - 67s 159ms/step - loss: 1.0207 - accuracy: 0.4768 - val_loss: 1.4877 - val_accuracy: 0.2180
# Epoch 21/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.2749 - accuracy: 0.4742 - val_loss: 1.3701 - val_accuracy: 0.2180
# Epoch 22/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0238 - accuracy: 0.4760 - val_loss: 1.4271 - val_accuracy: 0.2180
# Epoch 23/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.2978 - accuracy: 0.4734 - val_loss: 1.4840 - val_accuracy: 0.2180
# Epoch 24/30
# 424/424 [==============================] - 66s 157ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4625 - val_accuracy: 0.2180
# Epoch 25/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4630 - val_accuracy: 0.2180
# Epoch 26/30
# 424/424 [==============================] - 66s 155ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4386 - val_accuracy: 0.2180
# Epoch 27/30
# 424/424 [==============================] - 66s 155ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4607 - val_accuracy: 0.2180
# Epoch 28/30
# 424/424 [==============================] - 66s 155ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.5083 - val_accuracy: 0.2180
# Epoch 29/30
# 424/424 [==============================] - 66s 155ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4492 - val_accuracy: 0.2180
# Epoch 30/30
# 424/424 [==============================] - 66s 155ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4731 - val_accuracy: 0.2180
# Test loss: 1.5380971431732178
# Test accuracy: 0.20408163964748383
# 39/39 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       208
#            1       0.20      1.00      0.34       250
#            2       0.00      0.00      0.00       767
#
#     accuracy                           0.20      1225
#    macro avg       0.07      0.33      0.11      1225
# weighted avg       0.04      0.20      0.07      1225
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### lr=0,001 bs=16 - done

# %%
####################################################################################################################
#          We define our hyperparameters. everything is in the same cell for convenience

learning_rate = [0.001]
batch_size = [16]
dropouts = [0.5]

####################################################################################################################
#           We define our model specific parameters

model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)

####################################################################################################################
#           We print the number of models and state the hyperparameter search

print(f'Running {len(learning_rate)*len(batch_size)*len(dropouts)} possible models with learning rates:{learning_rate} and batch sizes: {batch_size} with dropouts: {dropouts} for epochs: {epochs}')

####################################################################################################################
#           We loop in our hyperparameters

for i in learning_rate:
    for j in batch_size:
        for d in dropouts:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} with dropout: {d} for epochs: {epochs}')

            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 

            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 

            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False

            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            #       The top model dense layers are arbitrarily chosen.

            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(512, activation='relu'),  
                tf.keras.layers.Dropout(d),
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            
            ####################################################################################################################
            #       We Compile our model

            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.

            cp_filepath = '{} lr{} batch size{} dropout{}.h5'.format(model_name, i,j,d)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')

            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)


            ####################################################################################################################
            #       Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            ####################################################################################################################
            #       save model with acc for later investigaion

            model.save('model{} acc{}  lr{} batch size{} dropout{}.h5'.format(model_name,score[1], i,j,d))
            ####################################################################################################################
            #       print visualization of training metrics           
            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)         

            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model

            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])


            cp_filepath = 'ft {} lr{} batch size{} dropout{}.h5'.format(model_name, i,j,d)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')


            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            # Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            model.save(' fintunedmodel{} acc{} lr{} batch size{} dropout{}.h5'.format(model_name,score[1], i,j,d))

            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)
# Out:
# Running 1 possible models with learning rates:[0.001] and batch sizes: [16] with dropouts: [0.5] for epochs: 100
# Running:
#  learning rate:0.001, batch size: 16 with dropout: 0.5 for epochs: 100
# Epoch 1/100
# 848/848 [==============================] - 29s 26ms/step - loss: 1.3736 - accuracy: 0.5084 - val_loss: 1.1145 - val_accuracy: 0.5086
# Epoch 2/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.8326 - accuracy: 0.5690 - val_loss: 0.9796 - val_accuracy: 0.5567
# Epoch 3/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.8065 - accuracy: 0.5826 - val_loss: 1.0594 - val_accuracy: 0.5241
# Epoch 4/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.7947 - accuracy: 0.5904 - val_loss: 1.1750 - val_accuracy: 0.4816
# Epoch 5/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.7764 - accuracy: 0.6126 - val_loss: 1.0360 - val_accuracy: 0.5731
# Epoch 6/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.7592 - accuracy: 0.6236 - val_loss: 1.1385 - val_accuracy: 0.5176
# Epoch 7/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.7425 - accuracy: 0.6256 - val_loss: 1.0299 - val_accuracy: 0.5731
# Epoch 8/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.7337 - accuracy: 0.6348 - val_loss: 1.2941 - val_accuracy: 0.4914
# Epoch 9/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.7203 - accuracy: 0.6399 - val_loss: 1.0624 - val_accuracy: 0.5829
# Epoch 10/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.7086 - accuracy: 0.6491 - val_loss: 1.2047 - val_accuracy: 0.5176
# Epoch 11/100
# 848/848 [==============================] - 21s 24ms/step - loss: 0.6873 - accuracy: 0.6663 - val_loss: 1.1489 - val_accuracy: 0.6082
# Epoch 12/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.6731 - accuracy: 0.6725 - val_loss: 1.2026 - val_accuracy: 0.5282
# Epoch 13/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.6644 - accuracy: 0.6738 - val_loss: 1.1726 - val_accuracy: 0.5747
# Epoch 14/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.6549 - accuracy: 0.6775 - val_loss: 1.1988 - val_accuracy: 0.5518
# Epoch 15/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.6449 - accuracy: 0.6857 - val_loss: 1.1352 - val_accuracy: 0.5673
# Epoch 16/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.6313 - accuracy: 0.6995 - val_loss: 1.3784 - val_accuracy: 0.5045
# Epoch 17/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.6221 - accuracy: 0.6975 - val_loss: 1.2822 - val_accuracy: 0.5584
# Epoch 18/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.6063 - accuracy: 0.7071 - val_loss: 1.3590 - val_accuracy: 0.5192
# Epoch 19/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5906 - accuracy: 0.7161 - val_loss: 1.2625 - val_accuracy: 0.5861
# Epoch 20/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5984 - accuracy: 0.7163 - val_loss: 1.3651 - val_accuracy: 0.5331
# Epoch 21/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5708 - accuracy: 0.7258 - val_loss: 1.3649 - val_accuracy: 0.5633
# Epoch 22/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5705 - accuracy: 0.7243 - val_loss: 1.4423 - val_accuracy: 0.5551
# Epoch 23/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5649 - accuracy: 0.7363 - val_loss: 1.4542 - val_accuracy: 0.5176
# Epoch 24/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5418 - accuracy: 0.7406 - val_loss: 1.3682 - val_accuracy: 0.5633
# Epoch 25/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5443 - accuracy: 0.7464 - val_loss: 1.3983 - val_accuracy: 0.5502
# Epoch 26/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5356 - accuracy: 0.7510 - val_loss: 1.4785 - val_accuracy: 0.5224
# Epoch 27/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5255 - accuracy: 0.7544 - val_loss: 1.5867 - val_accuracy: 0.5682
# Epoch 28/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5197 - accuracy: 0.7561 - val_loss: 1.5162 - val_accuracy: 0.5584
# Epoch 29/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5072 - accuracy: 0.7630 - val_loss: 1.5061 - val_accuracy: 0.5241
# Epoch 30/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4980 - accuracy: 0.7724 - val_loss: 1.6266 - val_accuracy: 0.5429
# Epoch 31/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5022 - accuracy: 0.7718 - val_loss: 1.7929 - val_accuracy: 0.5151
# Epoch 32/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.5001 - accuracy: 0.7713 - val_loss: 1.7015 - val_accuracy: 0.5290
# Epoch 33/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4868 - accuracy: 0.7717 - val_loss: 1.8843 - val_accuracy: 0.5110
# Epoch 34/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4818 - accuracy: 0.7795 - val_loss: 1.7998 - val_accuracy: 0.5045
# Epoch 35/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4835 - accuracy: 0.7772 - val_loss: 1.7423 - val_accuracy: 0.5249
# Epoch 36/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4828 - accuracy: 0.7795 - val_loss: 1.7632 - val_accuracy: 0.5257
# Epoch 37/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4622 - accuracy: 0.7827 - val_loss: 1.9776 - val_accuracy: 0.5298
# Epoch 38/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4589 - accuracy: 0.7912 - val_loss: 2.0534 - val_accuracy: 0.5527
# Epoch 39/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4484 - accuracy: 0.7951 - val_loss: 2.1643 - val_accuracy: 0.5127
# Epoch 40/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4485 - accuracy: 0.7938 - val_loss: 1.9486 - val_accuracy: 0.5502
# Epoch 41/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4558 - accuracy: 0.7919 - val_loss: 1.9530 - val_accuracy: 0.5665
# Epoch 42/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4523 - accuracy: 0.7895 - val_loss: 2.0504 - val_accuracy: 0.5657
# Epoch 43/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4357 - accuracy: 0.8058 - val_loss: 2.0560 - val_accuracy: 0.5412
# Epoch 44/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4367 - accuracy: 0.8050 - val_loss: 2.1395 - val_accuracy: 0.5298
# Epoch 45/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4245 - accuracy: 0.8072 - val_loss: 2.0169 - val_accuracy: 0.5420
# Epoch 46/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4250 - accuracy: 0.8085 - val_loss: 2.1129 - val_accuracy: 0.5290
# Epoch 47/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4186 - accuracy: 0.8105 - val_loss: 2.1469 - val_accuracy: 0.5224
# Epoch 48/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4267 - accuracy: 0.8081 - val_loss: 2.0328 - val_accuracy: 0.5404
# Epoch 49/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4145 - accuracy: 0.8173 - val_loss: 2.1583 - val_accuracy: 0.5535
# Epoch 50/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3984 - accuracy: 0.8186 - val_loss: 2.2420 - val_accuracy: 0.5282
# Epoch 51/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4148 - accuracy: 0.8107 - val_loss: 2.1171 - val_accuracy: 0.5633
# Epoch 52/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3953 - accuracy: 0.8242 - val_loss: 2.2380 - val_accuracy: 0.5135
# Epoch 53/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4103 - accuracy: 0.8178 - val_loss: 2.2274 - val_accuracy: 0.5045
# Epoch 54/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.4012 - accuracy: 0.8192 - val_loss: 2.4792 - val_accuracy: 0.5478
# Epoch 55/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3878 - accuracy: 0.8302 - val_loss: 2.4867 - val_accuracy: 0.5078
# Epoch 56/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3903 - accuracy: 0.8241 - val_loss: 2.5176 - val_accuracy: 0.5322
# Epoch 57/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3855 - accuracy: 0.8294 - val_loss: 2.4438 - val_accuracy: 0.5461
# Epoch 58/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3847 - accuracy: 0.8328 - val_loss: 2.4854 - val_accuracy: 0.5143
# Epoch 59/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3827 - accuracy: 0.8294 - val_loss: 2.7196 - val_accuracy: 0.5412
# Epoch 60/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3982 - accuracy: 0.8249 - val_loss: 2.5390 - val_accuracy: 0.5339
# Epoch 61/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3705 - accuracy: 0.8359 - val_loss: 2.7593 - val_accuracy: 0.5135
# Epoch 62/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3822 - accuracy: 0.8316 - val_loss: 2.5360 - val_accuracy: 0.5331
# Epoch 63/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3846 - accuracy: 0.8323 - val_loss: 2.6732 - val_accuracy: 0.5665
# Epoch 64/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3597 - accuracy: 0.8390 - val_loss: 2.6308 - val_accuracy: 0.5322
# Epoch 65/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3616 - accuracy: 0.8396 - val_loss: 2.8110 - val_accuracy: 0.5282
# Epoch 66/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3671 - accuracy: 0.8384 - val_loss: 2.7551 - val_accuracy: 0.5518
# Epoch 67/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3740 - accuracy: 0.8372 - val_loss: 2.6653 - val_accuracy: 0.5306
# Epoch 68/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3679 - accuracy: 0.8382 - val_loss: 2.7504 - val_accuracy: 0.5404
# Epoch 69/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3697 - accuracy: 0.8399 - val_loss: 2.8722 - val_accuracy: 0.5306
# Epoch 70/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3625 - accuracy: 0.8436 - val_loss: 2.6300 - val_accuracy: 0.5665
# Epoch 71/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3589 - accuracy: 0.8433 - val_loss: 2.7929 - val_accuracy: 0.5200
# Epoch 72/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3611 - accuracy: 0.8438 - val_loss: 2.8908 - val_accuracy: 0.5486
# Epoch 73/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3496 - accuracy: 0.8492 - val_loss: 2.8994 - val_accuracy: 0.5331
# Epoch 74/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3557 - accuracy: 0.8464 - val_loss: 2.8575 - val_accuracy: 0.5478
# Epoch 75/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3476 - accuracy: 0.8488 - val_loss: 2.9542 - val_accuracy: 0.5273
# Epoch 76/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3493 - accuracy: 0.8492 - val_loss: 2.9144 - val_accuracy: 0.5159
# Epoch 77/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3374 - accuracy: 0.8534 - val_loss: 3.1190 - val_accuracy: 0.5469
# Epoch 78/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3519 - accuracy: 0.8458 - val_loss: 3.2097 - val_accuracy: 0.5339
# Epoch 79/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3523 - accuracy: 0.8452 - val_loss: 3.0543 - val_accuracy: 0.5420
# Epoch 80/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3433 - accuracy: 0.8540 - val_loss: 3.0589 - val_accuracy: 0.5567
# Epoch 81/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3439 - accuracy: 0.8472 - val_loss: 3.2108 - val_accuracy: 0.5257
# Epoch 82/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3353 - accuracy: 0.8504 - val_loss: 3.0346 - val_accuracy: 0.5478
# Epoch 83/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3232 - accuracy: 0.8599 - val_loss: 3.1954 - val_accuracy: 0.5249
# Epoch 84/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3330 - accuracy: 0.8543 - val_loss: 3.3139 - val_accuracy: 0.5306
# Epoch 85/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3305 - accuracy: 0.8601 - val_loss: 3.0097 - val_accuracy: 0.5486
# Epoch 86/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3290 - accuracy: 0.8578 - val_loss: 3.1718 - val_accuracy: 0.5355
# Epoch 87/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3226 - accuracy: 0.8620 - val_loss: 3.1847 - val_accuracy: 0.5567
# Epoch 88/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3377 - accuracy: 0.8552 - val_loss: 2.9367 - val_accuracy: 0.5412
# Epoch 89/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3241 - accuracy: 0.8627 - val_loss: 3.1668 - val_accuracy: 0.5420
# Epoch 90/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3263 - accuracy: 0.8590 - val_loss: 3.4652 - val_accuracy: 0.5445
# Epoch 91/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3343 - accuracy: 0.8601 - val_loss: 3.1691 - val_accuracy: 0.5567
# Epoch 92/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3182 - accuracy: 0.8630 - val_loss: 3.2781 - val_accuracy: 0.5363
# Epoch 93/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3183 - accuracy: 0.8632 - val_loss: 3.2892 - val_accuracy: 0.5469
# Epoch 94/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3278 - accuracy: 0.8620 - val_loss: 3.1315 - val_accuracy: 0.5502
# Epoch 95/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3267 - accuracy: 0.8587 - val_loss: 3.1897 - val_accuracy: 0.5192
# Epoch 96/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3111 - accuracy: 0.8694 - val_loss: 3.0713 - val_accuracy: 0.5404
# Epoch 97/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3217 - accuracy: 0.8646 - val_loss: 3.4449 - val_accuracy: 0.5322
# Epoch 98/100
# 848/848 [==============================] - 20s 23ms/step - loss: 0.3240 - accuracy: 0.8666 - val_loss: 3.2390 - val_accuracy: 0.5241
# Epoch 99/100
# 848/848 [==============================] - 21s 24ms/step - loss: 0.3142 - accuracy: 0.8676 - val_loss: 3.2485 - val_accuracy: 0.5396
# Epoch 100/100
# 848/848 [==============================] - 20s 24ms/step - loss: 0.3159 - accuracy: 0.8649 - val_loss: 3.3726 - val_accuracy: 0.5445
# Test loss: 1.1082837581634521
# Test accuracy: 0.6089795827865601
# 39/39 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.45      0.36      0.40       208
#            1       0.31      0.38      0.34       250
#            2       0.77      0.75      0.76       767
#
#     accuracy                           0.61      1225
#    macro avg       0.51      0.50      0.50      1225
# weighted avg       0.62      0.61      0.61      1225
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 20,288,579
# Trainable params: 20,288,579
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 848/848 [==============================] - 79s 88ms/step - loss: 3.3348 - accuracy: 0.4738 - val_loss: 1.3555 - val_accuracy: 0.2180
# Epoch 2/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0245 - accuracy: 0.4768 - val_loss: 1.4118 - val_accuracy: 0.2180
# Epoch 3/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4393 - val_accuracy: 0.2180
# Epoch 4/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4366 - val_accuracy: 0.2180
# Epoch 5/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4540 - val_accuracy: 0.2180
# Epoch 6/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4412 - val_accuracy: 0.2180
# Epoch 7/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4432 - val_accuracy: 0.2180
# Epoch 8/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4400 - val_accuracy: 0.2180
# Epoch 9/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4388 - val_accuracy: 0.2180
# Epoch 10/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4438 - val_accuracy: 0.2180
# Epoch 11/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4564 - val_accuracy: 0.2180
# Epoch 12/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4459 - val_accuracy: 0.2180
# Epoch 13/30
# 848/848 [==============================] - 73s 86ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4490 - val_accuracy: 0.2180
# Epoch 14/30
# 848/848 [==============================] - 72s 85ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4443 - val_accuracy: 0.2180
# Epoch 15/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4489 - val_accuracy: 0.2180
# Epoch 16/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4513 - val_accuracy: 0.2180
# Epoch 17/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4503 - val_accuracy: 0.2180
# Epoch 18/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4592 - val_accuracy: 0.2180
# Epoch 19/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4453 - val_accuracy: 0.2180
# Epoch 20/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4479 - val_accuracy: 0.2180
# Epoch 21/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4490 - val_accuracy: 0.2180
# Epoch 22/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4486 - val_accuracy: 0.2180
# Epoch 23/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4453 - val_accuracy: 0.2180
# Epoch 24/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4485 - val_accuracy: 0.2180
# Epoch 25/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4502 - val_accuracy: 0.2180
# Epoch 26/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4484 - val_accuracy: 0.2180
# Epoch 27/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4472 - val_accuracy: 0.2180
# Epoch 28/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4440 - val_accuracy: 0.2180
# Epoch 29/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0196 - accuracy: 0.4768 - val_loss: 1.4419 - val_accuracy: 0.2180
# Epoch 30/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0197 - accuracy: 0.4768 - val_loss: 1.4439 - val_accuracy: 0.2180
# Test loss: 1.3573551177978516
# Test accuracy: 0.20408163964748383
# 39/39 [==============================] - 1s 34ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       208
#            1       0.20      1.00      0.34       250
#            2       0.00      0.00      0.00       767
#
#     accuracy                           0.20      1225
#    macro avg       0.07      0.33      0.11      1225
# weighted avg       0.04      0.20      0.07      1225
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### lr 0.01 bs 64 - done

# %%
####################################################################################################################
#          We define our hyperparameters. everything is in the same cell for convenience

learning_rate = [0.01]
batch_size = [64]

####################################################################################################################
#           We define our model specific parameters

model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)

####################################################################################################################
#           We print the number of models and state the hyperparameter search

print(f'Running learning rate:{learning_rate} and batch size: {batch_size} for epochs: {epochs}')

####################################################################################################################
#           We loop in our hyperparameters

for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')

            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 

            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 

            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False

            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            #       The top model dense layers are arbitrarily chosen.

            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            
            ####################################################################################################################
            #       We Compile our model

            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.

            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')

            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)


            ####################################################################################################################
            #       Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            ####################################################################################################################
            #       save model with acc for later investigaion

            model.save('model{} acc{}  lr{} batch size{}.h5'.format(model_name,score[1], i,j,))
            ####################################################################################################################
            #       print visualization of training metrics           
            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)         

            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model

            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])


            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')


            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            # Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            model.save(' fintunedmodel{} acc{} lr{} batch size{}.h5'.format(model_name,score[1], i,j,))

            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)
# Out:
# Running learning rate:[0.01] and batch size: [64] for epochs: 100
# Running:
#  learning rate:0.01, batch size: 64 for epochs: 100
# Epoch 1/100
# 212/212 [==============================] - 31s 100ms/step - loss: 30.2305 - accuracy: 0.5095 - val_loss: 0.9677 - val_accuracy: 0.5747
# Epoch 2/100
# 212/212 [==============================] - 17s 81ms/step - loss: 0.8280 - accuracy: 0.5704 - val_loss: 0.8839 - val_accuracy: 0.6163
# Epoch 3/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7854 - accuracy: 0.5955 - val_loss: 0.9063 - val_accuracy: 0.6082
# Epoch 4/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7654 - accuracy: 0.6108 - val_loss: 1.1229 - val_accuracy: 0.5649
# Epoch 5/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7533 - accuracy: 0.6166 - val_loss: 0.9802 - val_accuracy: 0.5812
# Epoch 6/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7473 - accuracy: 0.6258 - val_loss: 0.9493 - val_accuracy: 0.5910
# Epoch 7/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7364 - accuracy: 0.6250 - val_loss: 1.0074 - val_accuracy: 0.5869
# Epoch 8/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7360 - accuracy: 0.6309 - val_loss: 1.1244 - val_accuracy: 0.5469
# Epoch 9/100
# 212/212 [==============================] - 17s 81ms/step - loss: 0.7301 - accuracy: 0.6284 - val_loss: 0.9992 - val_accuracy: 0.6261
# Epoch 10/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7143 - accuracy: 0.6442 - val_loss: 1.0706 - val_accuracy: 0.5616
# Epoch 11/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7094 - accuracy: 0.6393 - val_loss: 1.0022 - val_accuracy: 0.5853
# Epoch 12/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7056 - accuracy: 0.6391 - val_loss: 0.9915 - val_accuracy: 0.5812
# Epoch 13/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7116 - accuracy: 0.6456 - val_loss: 1.0963 - val_accuracy: 0.5453
# Epoch 14/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6968 - accuracy: 0.6467 - val_loss: 1.1070 - val_accuracy: 0.5861
# Epoch 15/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6994 - accuracy: 0.6495 - val_loss: 1.1209 - val_accuracy: 0.5200
# Epoch 16/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.7002 - accuracy: 0.6456 - val_loss: 1.3697 - val_accuracy: 0.4865
# Epoch 17/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6921 - accuracy: 0.6526 - val_loss: 1.1397 - val_accuracy: 0.5608
# Epoch 18/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6878 - accuracy: 0.6557 - val_loss: 1.1368 - val_accuracy: 0.5567
# Epoch 19/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6851 - accuracy: 0.6578 - val_loss: 1.1738 - val_accuracy: 0.5339
# Epoch 20/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6868 - accuracy: 0.6536 - val_loss: 1.2597 - val_accuracy: 0.5771
# Epoch 21/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6866 - accuracy: 0.6547 - val_loss: 1.2286 - val_accuracy: 0.5363
# Epoch 22/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6747 - accuracy: 0.6593 - val_loss: 1.2765 - val_accuracy: 0.5380
# Epoch 23/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6786 - accuracy: 0.6627 - val_loss: 1.2285 - val_accuracy: 0.5763
# Epoch 24/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6766 - accuracy: 0.6596 - val_loss: 1.2611 - val_accuracy: 0.5543
# Epoch 25/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6712 - accuracy: 0.6641 - val_loss: 1.1602 - val_accuracy: 0.5249
# Epoch 26/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6666 - accuracy: 0.6648 - val_loss: 1.1293 - val_accuracy: 0.5967
# Epoch 27/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6678 - accuracy: 0.6575 - val_loss: 1.1699 - val_accuracy: 0.5535
# Epoch 28/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6682 - accuracy: 0.6668 - val_loss: 1.2417 - val_accuracy: 0.5510
# Epoch 29/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6661 - accuracy: 0.6714 - val_loss: 1.3199 - val_accuracy: 0.5527
# Epoch 30/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6672 - accuracy: 0.6666 - val_loss: 1.1512 - val_accuracy: 0.5869
# Epoch 31/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6618 - accuracy: 0.6656 - val_loss: 1.2664 - val_accuracy: 0.5714
# Epoch 32/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6626 - accuracy: 0.6652 - val_loss: 1.1938 - val_accuracy: 0.5567
# Epoch 33/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6524 - accuracy: 0.6694 - val_loss: 1.2067 - val_accuracy: 0.5755
# Epoch 34/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6534 - accuracy: 0.6694 - val_loss: 1.2372 - val_accuracy: 0.5322
# Epoch 35/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6499 - accuracy: 0.6708 - val_loss: 1.5012 - val_accuracy: 0.5306
# Epoch 36/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6566 - accuracy: 0.6705 - val_loss: 1.2177 - val_accuracy: 0.5453
# Epoch 37/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6469 - accuracy: 0.6708 - val_loss: 1.2245 - val_accuracy: 0.5927
# Epoch 38/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6476 - accuracy: 0.6745 - val_loss: 1.4654 - val_accuracy: 0.5135
# Epoch 39/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6453 - accuracy: 0.6761 - val_loss: 1.3988 - val_accuracy: 0.4890
# Epoch 40/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6486 - accuracy: 0.6767 - val_loss: 1.3404 - val_accuracy: 0.5567
# Epoch 41/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6409 - accuracy: 0.6759 - val_loss: 1.3011 - val_accuracy: 0.4947
# Epoch 42/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6444 - accuracy: 0.6747 - val_loss: 1.1788 - val_accuracy: 0.5665
# Epoch 43/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6441 - accuracy: 0.6768 - val_loss: 1.3912 - val_accuracy: 0.5224
# Epoch 44/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6372 - accuracy: 0.6784 - val_loss: 1.2461 - val_accuracy: 0.5388
# Epoch 45/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6426 - accuracy: 0.6776 - val_loss: 1.2092 - val_accuracy: 0.5616
# Epoch 46/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6423 - accuracy: 0.6781 - val_loss: 1.2315 - val_accuracy: 0.5608
# Epoch 47/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6314 - accuracy: 0.6822 - val_loss: 1.4065 - val_accuracy: 0.5331
# Epoch 48/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6407 - accuracy: 0.6838 - val_loss: 1.1495 - val_accuracy: 0.5984
# Epoch 49/100
# 212/212 [==============================] - 17s 79ms/step - loss: 0.6330 - accuracy: 0.6779 - val_loss: 1.3024 - val_accuracy: 0.5380
# Epoch 50/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6336 - accuracy: 0.6753 - val_loss: 1.4812 - val_accuracy: 0.5608
# Epoch 51/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6243 - accuracy: 0.6823 - val_loss: 1.2942 - val_accuracy: 0.5461
# Epoch 52/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6350 - accuracy: 0.6770 - val_loss: 1.3955 - val_accuracy: 0.6041
# Epoch 53/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6383 - accuracy: 0.6793 - val_loss: 1.3517 - val_accuracy: 0.5780
# Epoch 54/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6286 - accuracy: 0.6814 - val_loss: 1.4977 - val_accuracy: 0.5780
# Epoch 55/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6264 - accuracy: 0.6841 - val_loss: 1.4016 - val_accuracy: 0.5820
# Epoch 56/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6364 - accuracy: 0.6807 - val_loss: 1.4857 - val_accuracy: 0.5584
# Epoch 57/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6325 - accuracy: 0.6820 - val_loss: 1.3340 - val_accuracy: 0.5706
# Epoch 58/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6273 - accuracy: 0.6794 - val_loss: 1.3385 - val_accuracy: 0.5918
# Epoch 59/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6305 - accuracy: 0.6823 - val_loss: 1.5771 - val_accuracy: 0.5576
# Epoch 60/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6302 - accuracy: 0.6825 - val_loss: 1.4841 - val_accuracy: 0.5739
# Epoch 61/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6253 - accuracy: 0.6821 - val_loss: 1.5905 - val_accuracy: 0.5714
# Epoch 62/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6283 - accuracy: 0.6825 - val_loss: 1.3342 - val_accuracy: 0.5984
# Epoch 63/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6238 - accuracy: 0.6809 - val_loss: 1.4178 - val_accuracy: 0.4955
# Epoch 64/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6187 - accuracy: 0.6874 - val_loss: 1.3632 - val_accuracy: 0.5788
# Epoch 65/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6173 - accuracy: 0.6882 - val_loss: 1.5050 - val_accuracy: 0.5518
# Epoch 66/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6361 - accuracy: 0.6779 - val_loss: 1.6536 - val_accuracy: 0.5894
# Epoch 67/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6340 - accuracy: 0.6787 - val_loss: 1.5375 - val_accuracy: 0.5641
# Epoch 68/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6213 - accuracy: 0.6855 - val_loss: 1.5610 - val_accuracy: 0.5657
# Epoch 69/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6169 - accuracy: 0.6910 - val_loss: 1.5827 - val_accuracy: 0.5518
# Epoch 70/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6187 - accuracy: 0.6840 - val_loss: 1.6324 - val_accuracy: 0.5714
# Epoch 71/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6143 - accuracy: 0.6933 - val_loss: 1.4266 - val_accuracy: 0.5796
# Epoch 72/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6178 - accuracy: 0.6883 - val_loss: 1.5334 - val_accuracy: 0.5902
# Epoch 73/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6191 - accuracy: 0.6874 - val_loss: 1.4508 - val_accuracy: 0.5527
# Epoch 74/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6263 - accuracy: 0.6835 - val_loss: 1.4973 - val_accuracy: 0.5886
# Epoch 75/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6113 - accuracy: 0.6882 - val_loss: 1.5558 - val_accuracy: 0.5404
# Epoch 76/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6111 - accuracy: 0.6897 - val_loss: 1.4306 - val_accuracy: 0.5731
# Epoch 77/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6223 - accuracy: 0.6838 - val_loss: 1.3955 - val_accuracy: 0.5682
# Epoch 78/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6170 - accuracy: 0.6865 - val_loss: 1.7965 - val_accuracy: 0.5233
# Epoch 79/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6073 - accuracy: 0.6899 - val_loss: 1.8113 - val_accuracy: 0.5869
# Epoch 80/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6122 - accuracy: 0.6919 - val_loss: 1.5213 - val_accuracy: 0.5682
# Epoch 81/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6118 - accuracy: 0.6900 - val_loss: 1.6929 - val_accuracy: 0.5616
# Epoch 82/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6080 - accuracy: 0.6892 - val_loss: 1.8550 - val_accuracy: 0.5502
# Epoch 83/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6086 - accuracy: 0.6903 - val_loss: 1.6496 - val_accuracy: 0.5535
# Epoch 84/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6062 - accuracy: 0.6871 - val_loss: 1.4304 - val_accuracy: 0.5796
# Epoch 85/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6099 - accuracy: 0.6922 - val_loss: 1.5859 - val_accuracy: 0.5657
# Epoch 86/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6144 - accuracy: 0.6888 - val_loss: 1.4903 - val_accuracy: 0.5102
# Epoch 87/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6071 - accuracy: 0.6920 - val_loss: 1.6797 - val_accuracy: 0.5576
# Epoch 88/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6031 - accuracy: 0.6916 - val_loss: 1.5245 - val_accuracy: 0.5861
# Epoch 89/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6053 - accuracy: 0.6958 - val_loss: 1.7050 - val_accuracy: 0.5567
# Epoch 90/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6092 - accuracy: 0.6861 - val_loss: 1.6765 - val_accuracy: 0.5731
# Epoch 91/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.5988 - accuracy: 0.6964 - val_loss: 1.5930 - val_accuracy: 0.5935
# Epoch 92/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6223 - accuracy: 0.6833 - val_loss: 1.4784 - val_accuracy: 0.5624
# Epoch 93/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6162 - accuracy: 0.6842 - val_loss: 1.5141 - val_accuracy: 0.5200
# Epoch 94/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6077 - accuracy: 0.6880 - val_loss: 1.7986 - val_accuracy: 0.5657
# Epoch 95/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6133 - accuracy: 0.6867 - val_loss: 2.4883 - val_accuracy: 0.5592
# Epoch 96/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6167 - accuracy: 0.6875 - val_loss: 1.7606 - val_accuracy: 0.5690
# Epoch 97/100
# 212/212 [==============================] - 16s 78ms/step - loss: 0.6109 - accuracy: 0.6903 - val_loss: 1.6722 - val_accuracy: 0.5404
# Epoch 98/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6107 - accuracy: 0.6916 - val_loss: 1.5583 - val_accuracy: 0.5837
# Epoch 99/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6083 - accuracy: 0.6941 - val_loss: 1.7097 - val_accuracy: 0.5845
# Epoch 100/100
# 212/212 [==============================] - 16s 77ms/step - loss: 0.6056 - accuracy: 0.6901 - val_loss: 1.8227 - val_accuracy: 0.5796
# Test loss: 0.9698639512062073
# Test accuracy: 0.6106122732162476
# 39/39 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.45      0.29      0.35       208
#            1       0.31      0.33      0.32       250
#            2       0.74      0.79      0.76       767
#
#     accuracy                           0.61      1225
#    macro avg       0.50      0.47      0.48      1225
# weighted avg       0.60      0.61      0.60      1225
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 212/212 [==============================] - 80s 331ms/step - loss: 167469432832.0000 - accuracy: 0.4458 - val_loss: 1.4911 - val_accuracy: 0.2180
# Epoch 2/30
# 212/212 [==============================] - 62s 291ms/step - loss: 1.0211 - accuracy: 0.4768 - val_loss: 1.4539 - val_accuracy: 0.2180
# Epoch 3/30
# 212/212 [==============================] - 62s 292ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.3914 - val_accuracy: 0.2180
# Epoch 4/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0206 - accuracy: 0.4768 - val_loss: 1.4417 - val_accuracy: 0.2180
# Epoch 5/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0209 - accuracy: 0.4768 - val_loss: 1.4640 - val_accuracy: 0.2180
# Epoch 6/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4307 - val_accuracy: 0.2180
# Epoch 7/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0206 - accuracy: 0.4768 - val_loss: 1.4525 - val_accuracy: 0.2180
# Epoch 8/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0209 - accuracy: 0.4768 - val_loss: 1.3910 - val_accuracy: 0.2180
# Epoch 9/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0206 - accuracy: 0.4768 - val_loss: 1.3743 - val_accuracy: 0.2180
# Epoch 10/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0210 - accuracy: 0.4768 - val_loss: 1.4696 - val_accuracy: 0.2180
# Epoch 11/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0208 - accuracy: 0.4768 - val_loss: 1.4298 - val_accuracy: 0.2180
# Epoch 12/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4495 - val_accuracy: 0.2180
# Epoch 13/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0206 - accuracy: 0.4768 - val_loss: 1.4344 - val_accuracy: 0.2180
# Epoch 14/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0209 - accuracy: 0.4768 - val_loss: 1.4043 - val_accuracy: 0.2180
# Epoch 15/30
# 212/212 [==============================] - 62s 293ms/step - loss: 1.0210 - accuracy: 0.4768 - val_loss: 1.4643 - val_accuracy: 0.2180
# Epoch 16/30
# 212/212 [==============================] - 62s 292ms/step - loss: 1.0208 - accuracy: 0.4768 - val_loss: 1.4887 - val_accuracy: 0.2180
# Epoch 17/30
# 212/212 [==============================] - 62s 292ms/step - loss: 1.0218 - accuracy: 0.4768 - val_loss: 1.3959 - val_accuracy: 0.2180
# Epoch 18/30
# 212/212 [==============================] - 62s 292ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4595 - val_accuracy: 0.2180
# Epoch 19/30
# 212/212 [==============================] - 62s 292ms/step - loss: 1.0216 - accuracy: 0.4768 - val_loss: 1.4731 - val_accuracy: 0.2180
# Epoch 20/30
# 212/212 [==============================] - 62s 292ms/step - loss: 1.0206 - accuracy: 0.4768 - val_loss: 1.4541 - val_accuracy: 0.2180
# Epoch 21/30
# 212/212 [==============================] - 62s 292ms/step - loss: 1.0209 - accuracy: 0.4768 - val_loss: 1.4547 - val_accuracy: 0.2180
# Epoch 22/30
# 212/212 [==============================] - 62s 292ms/step - loss: 1.0211 - accuracy: 0.4768 - val_loss: 1.4590 - val_accuracy: 0.2180
# Epoch 23/30
# 212/212 [==============================] - 62s 292ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4289 - val_accuracy: 0.2180
# Epoch 24/30
# 212/212 [==============================] - 62s 295ms/step - loss: 1.0209 - accuracy: 0.4768 - val_loss: 1.4810 - val_accuracy: 0.2180
# Epoch 25/30
# 212/212 [==============================] - 63s 296ms/step - loss: 1.0208 - accuracy: 0.4768 - val_loss: 1.5061 - val_accuracy: 0.2180
# Epoch 26/30
# 212/212 [==============================] - 63s 295ms/step - loss: 1.0208 - accuracy: 0.4768 - val_loss: 1.4568 - val_accuracy: 0.2180
# Epoch 27/30
# 212/212 [==============================] - 63s 297ms/step - loss: 1.0209 - accuracy: 0.4768 - val_loss: 1.4552 - val_accuracy: 0.2180
# Epoch 28/30
# 212/212 [==============================] - 63s 298ms/step - loss: 1.0206 - accuracy: 0.4768 - val_loss: 1.5234 - val_accuracy: 0.2180
# Epoch 29/30
# 212/212 [==============================] - 63s 298ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4185 - val_accuracy: 0.2180
# Epoch 30/30
# 212/212 [==============================] - 63s 298ms/step - loss: 1.0208 - accuracy: 0.4768 - val_loss: 1.4096 - val_accuracy: 0.2180
# Test loss: 1.4904805421829224
# Test accuracy: 0.20408163964748383
# 39/39 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       208
#            1       0.20      1.00      0.34       250
#            2       0.00      0.00      0.00       767
#
#     accuracy                           0.20      1225
#    macro avg       0.07      0.33      0.11      1225
# weighted avg       0.04      0.20      0.07      1225
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### lr 0.01 bs32 - done

# %%
####################################################################################################################
#          We define our hyperparameters. everything is in the same cell for convenience

learning_rate = [0.01]
batch_size = [32]

####################################################################################################################
#           We define our model specific parameters

model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)

####################################################################################################################
#           We print the number of models and state the hyperparameter search

print(f'Running learning rate:{learning_rate} and batch size: {batch_size} for epochs: {epochs}')

####################################################################################################################
#           We loop in our hyperparameters

for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')

            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 

            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 

            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False

            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            #       The top model dense layers are arbitrarily chosen.

            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            
            ####################################################################################################################
            #       We Compile our model

            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.

            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')

            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)


            ####################################################################################################################
            #       Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            ####################################################################################################################
            #       save model with acc for later investigaion

            model.save('model{} acc{}  lr{} batch size{}.h5'.format(model_name,score[1], i,j,))
            ####################################################################################################################
            #       print visualization of training metrics           
            acc = history.history['accuracy']
            val_acc = history.history['val_accuracy']

            loss = history.history['loss']
            val_loss = history.history['val_loss']

            plt.figure(figsize=(8, 8))
            plt.subplot(2, 1, 1)
            plt.plot(acc, label='Training Accuracy')
            plt.plot(val_acc, label='Validation Accuracy')
            plt.legend(loc='lower right')
            plt.ylabel('Accuracy')
            plt.ylim([min(plt.ylim()),1])
            plt.title(f'Training and Validation Accuracy {cp_filepath}')

            plt.subplot(2, 1, 2)
            plt.plot(loss, label='Training Loss')
            plt.plot(val_loss, label='Validation Loss')
            plt.legend(loc='upper right')
            plt.ylabel('Cross Entropy')
            plt.ylim([0,1.0])
            plt.title(f'Training and Validation Loss {cp_filepath}')
            plt.xlabel('epoch')
            plt.show()

            #################################################################################################################### 
            #       Generate predictions on the test set

            y_pred = model.predict(X_test)
            y_pred_classes = np.argmax(y_pred, axis=1)

            print(classification_report(y_test, y_pred_classes))

            ####################################################################################################################
            #       We Generate a confusion matrix
            cm = confusion_matrix(y_test, y_pred_classes)

            ####################################################################################################################
            #       Define the class labels
            class_names = ['Failed (0)', 'Partially (1)', 'Accepted (2)']

            ####################################################################################################################
            #       Plot the confusion matrix
            plt.figure(figsize=(8, 6))
            plt.imshow(cm, cmap=plt.cm.OrRd)
            plt.title(f'Confusion Matrix \n {cp_filepath}')
            plt.xlabel('Predicted Labels')
            plt.ylabel('True Labels')
            plt.xticks(np.arange(len(class_names)), class_names, rotation=45)
            plt.yticks(np.arange(len(class_names)), class_names)
            plt.colorbar()

            ####################################################################################################################
            #       Add labels to the plot

            for k in range(len(class_names)):
                for h in range(len(class_names)):
                    plt.text(h, k, cm[k, h], ha='center', va='center', color='black')

            plt.show()

            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model

            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])


            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')


            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            # Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            model.save(' fintunedmodel{} acc{} lr{} batch size{}.h5'.format(model_name,score[1], i,j,))

            acc = history.history['accuracy']
            val_acc = history.history['val_accuracy']

            loss = history.history['loss']
            val_loss = history.history['val_loss']

            plt.figure(figsize=(8, 8))
            plt.subplot(2, 1, 1)
            plt.plot(acc, label='Training Accuracy')
            plt.plot(val_acc, label='Validation Accuracy')
            plt.legend(loc='lower right')
            plt.ylabel('Accuracy')
            plt.ylim([min(plt.ylim()),1])
            plt.title(f'Training and Validation Accuracy {cp_filepath}')

            plt.subplot(2, 1, 2)
            plt.plot(loss, label='Training Loss')
            plt.plot(val_loss, label='Validation Loss')
            plt.legend(loc='upper right')
            plt.ylabel('Cross Entropy')
            plt.ylim([0,1.0])
            plt.title(f'Training and Validation Loss {cp_filepath}')
            plt.xlabel('epoch')
            plt.show()

            # Generate predictions on the test set
            y_pred = model.predict(X_test)
            y_pred_classes = np.argmax(y_pred, axis=1)

            print(classification_report(y_test, y_pred_classes))

            # Compute the confusion matrix
            cm = confusion_matrix(y_test, y_pred_classes)

            # Define the class labels
            class_names = ['Failed (0)', 'Partially (1)', 'Accepted (2)']

            # Plot the confusion matrix
            plt.figure(figsize=(8, 6))
            plt.imshow(cm, cmap=plt.cm.OrRd)
            plt.title(f'Confusion Matrix \n {cp_filepath}')
            plt.xlabel('Predicted Labels')
            plt.ylabel('True Labels')
            plt.xticks(np.arange(len(class_names)), class_names, rotation=45)
            plt.yticks(np.arange(len(class_names)), class_names)
            plt.colorbar()

            # Add labels to the plot
            for k in range(len(class_names)):
                for h in range(len(class_names)):
                    plt.text(h, k, cm[k, h], ha='center', va='center', color='black')

            plt.show()
# Out:
# Running learning rate:[0.01] and batch size: [32] for epochs: 100
# Running:
#  learning rate:0.01, batch size: 32 for epochs: 100
# Epoch 1/100
# 424/424 [==============================] - 29s 50ms/step - loss: 12.4127 - accuracy: 0.4931 - val_loss: 1.1985 - val_accuracy: 0.5347
# Epoch 2/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.8394 - accuracy: 0.5651 - val_loss: 1.1598 - val_accuracy: 0.4955
# Epoch 3/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.7936 - accuracy: 0.5965 - val_loss: 1.0294 - val_accuracy: 0.5094
# Epoch 4/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.7741 - accuracy: 0.6113 - val_loss: 1.0501 - val_accuracy: 0.5576
# Epoch 5/100
# 424/424 [==============================] - 19s 44ms/step - loss: 0.7886 - accuracy: 0.6034 - val_loss: 0.9727 - val_accuracy: 0.6057
# Epoch 6/100
# 424/424 [==============================] - 18s 43ms/step - loss: 0.8825 - accuracy: 0.5748 - val_loss: 1.5884 - val_accuracy: 0.2180
# Epoch 7/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0283 - accuracy: 0.4764 - val_loss: 1.4639 - val_accuracy: 0.2180
# Epoch 8/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0196 - accuracy: 0.4774 - val_loss: 1.4376 - val_accuracy: 0.2180
# Epoch 9/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4395 - val_accuracy: 0.2180
# Epoch 10/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4745 - val_accuracy: 0.2180
# Epoch 11/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4485 - val_accuracy: 0.2180
# Epoch 12/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4456 - val_accuracy: 0.2180
# Epoch 13/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4633 - val_accuracy: 0.2180
# Epoch 14/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.3991 - val_accuracy: 0.2180
# Epoch 15/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0186 - accuracy: 0.4772 - val_loss: 1.4417 - val_accuracy: 0.2180
# Epoch 16/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0210 - accuracy: 0.4776 - val_loss: 1.4659 - val_accuracy: 0.2180
# Epoch 17/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4743 - val_accuracy: 0.2180
# Epoch 18/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4885 - val_accuracy: 0.2180
# Epoch 19/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4363 - val_accuracy: 0.2180
# Epoch 20/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4252 - val_accuracy: 0.2180
# Epoch 21/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4720 - val_accuracy: 0.2180
# Epoch 22/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4633 - val_accuracy: 0.2180
# Epoch 23/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4649 - val_accuracy: 0.2180
# Epoch 24/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4433 - val_accuracy: 0.2180
# Epoch 25/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4429 - val_accuracy: 0.2180
# Epoch 26/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4238 - val_accuracy: 0.2180
# Epoch 27/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4245 - val_accuracy: 0.2180
# Epoch 28/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4636 - val_accuracy: 0.2180
# Epoch 29/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4649 - val_accuracy: 0.2180
# Epoch 30/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4343 - val_accuracy: 0.2180
# Epoch 31/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4731 - val_accuracy: 0.2180
# Epoch 32/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4444 - val_accuracy: 0.2180
# Epoch 33/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4408 - val_accuracy: 0.2180
# Epoch 34/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4523 - val_accuracy: 0.2180
# Epoch 35/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4420 - val_accuracy: 0.2180
# Epoch 36/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4697 - val_accuracy: 0.2180
# Epoch 37/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4390 - val_accuracy: 0.2180
# Epoch 38/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4719 - val_accuracy: 0.2180
# Epoch 39/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4858 - val_accuracy: 0.2180
# Epoch 40/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4229 - val_accuracy: 0.2180
# Epoch 41/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4591 - val_accuracy: 0.2180
# Epoch 42/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4877 - val_accuracy: 0.2180
# Epoch 43/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4603 - val_accuracy: 0.2180
# Epoch 44/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4749 - val_accuracy: 0.2180
# Epoch 45/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4377 - val_accuracy: 0.2180
# Epoch 46/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4497 - val_accuracy: 0.2180
# Epoch 47/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4413 - val_accuracy: 0.2180
# Epoch 48/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4407 - val_accuracy: 0.2180
# Epoch 49/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4576 - val_accuracy: 0.2180
# Epoch 50/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4490 - val_accuracy: 0.2180
# Epoch 51/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4039 - val_accuracy: 0.2180
# Epoch 52/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4300 - val_accuracy: 0.2180
# Epoch 53/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4253 - val_accuracy: 0.2180
# Epoch 54/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4268 - val_accuracy: 0.2180
# Epoch 55/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4240 - val_accuracy: 0.2180
# Epoch 56/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4515 - val_accuracy: 0.2180
# Epoch 57/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4518 - val_accuracy: 0.2180
# Epoch 58/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0199 - accuracy: 0.4768 - val_loss: 1.5055 - val_accuracy: 0.2180
# Epoch 59/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4531 - val_accuracy: 0.2180
# Epoch 60/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4540 - val_accuracy: 0.2180
# Epoch 61/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4299 - val_accuracy: 0.2180
# Epoch 62/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4384 - val_accuracy: 0.2180
# Epoch 63/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4547 - val_accuracy: 0.2180
# Epoch 64/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.3959 - val_accuracy: 0.2180
# Epoch 65/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4306 - val_accuracy: 0.2180
# Epoch 66/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4105 - val_accuracy: 0.2180
# Epoch 67/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4791 - val_accuracy: 0.2180
# Epoch 68/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4428 - val_accuracy: 0.2180
# Epoch 69/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0198 - accuracy: 0.4768 - val_loss: 1.4418 - val_accuracy: 0.2180
# Epoch 70/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0199 - accuracy: 0.4768 - val_loss: 1.4421 - val_accuracy: 0.2180
# Epoch 71/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4355 - val_accuracy: 0.2180
# Epoch 72/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4440 - val_accuracy: 0.2180
# Epoch 73/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4008 - val_accuracy: 0.2180
# Epoch 74/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4470 - val_accuracy: 0.2180
# Epoch 75/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4405 - val_accuracy: 0.2180
# Epoch 76/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4304 - val_accuracy: 0.2180
# Epoch 77/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4398 - val_accuracy: 0.2180
# Epoch 78/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4549 - val_accuracy: 0.2180
# Epoch 79/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4313 - val_accuracy: 0.2180
# Epoch 80/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4547 - val_accuracy: 0.2180
# Epoch 81/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4225 - val_accuracy: 0.2180
# Epoch 82/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4467 - val_accuracy: 0.2180
# Epoch 83/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4148 - val_accuracy: 0.2180
# Epoch 84/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4643 - val_accuracy: 0.2180
# Epoch 85/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4303 - val_accuracy: 0.2180
# Epoch 86/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4320 - val_accuracy: 0.2180
# Epoch 87/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4368 - val_accuracy: 0.2180
# Epoch 88/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4313 - val_accuracy: 0.2180
# Epoch 89/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4159 - val_accuracy: 0.2180
# Epoch 90/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4103 - val_accuracy: 0.2180
# Epoch 91/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4792 - val_accuracy: 0.2180
# Epoch 92/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4437 - val_accuracy: 0.2180
# Epoch 93/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4346 - val_accuracy: 0.2180
# Epoch 94/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4257 - val_accuracy: 0.2180
# Epoch 95/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4667 - val_accuracy: 0.2180
# Epoch 96/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4100 - val_accuracy: 0.2180
# Epoch 97/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4658 - val_accuracy: 0.2180
# Epoch 98/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0199 - accuracy: 0.4768 - val_loss: 1.4266 - val_accuracy: 0.2180
# Epoch 99/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4754 - val_accuracy: 0.2180
# Epoch 100/100
# 424/424 [==============================] - 18s 43ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4463 - val_accuracy: 0.2180
# Test loss: 0.9712860584259033
# Test accuracy: 0.5885714292526245
# 39/39 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.48      0.23      0.31       208
#            1       0.29      0.44      0.35       250
#            2       0.76      0.73      0.75       767
#
#     accuracy                           0.59      1225
#    macro avg       0.51      0.47      0.47      1225
# weighted avg       0.62      0.59      0.59      1225
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 424/424 [==============================] - 75s 163ms/step - loss: 19640950784.0000 - accuracy: 0.4604 - val_loss: 1.4084 - val_accuracy: 0.2180
# Epoch 2/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0212 - accuracy: 0.4768 - val_loss: 1.4702 - val_accuracy: 0.2180
# Epoch 3/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4514 - val_accuracy: 0.2180
# Epoch 4/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4094 - val_accuracy: 0.2180
# Epoch 5/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4692 - val_accuracy: 0.2180
# Epoch 6/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4402 - val_accuracy: 0.2180
# Epoch 7/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4789 - val_accuracy: 0.2180
# Epoch 8/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4493 - val_accuracy: 0.2180
# Epoch 9/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4091 - val_accuracy: 0.2180
# Epoch 10/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4923 - val_accuracy: 0.2180
# Epoch 11/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4329 - val_accuracy: 0.2180
# Epoch 12/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4311 - val_accuracy: 0.2180
# Epoch 13/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0200 - accuracy: 0.4768 - val_loss: 1.4070 - val_accuracy: 0.2180
# Epoch 14/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4326 - val_accuracy: 0.2180
# Epoch 15/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0199 - accuracy: 0.4768 - val_loss: 1.5017 - val_accuracy: 0.2180
# Epoch 16/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4771 - val_accuracy: 0.2180
# Epoch 17/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4547 - val_accuracy: 0.2180
# Epoch 18/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4982 - val_accuracy: 0.2180
# Epoch 19/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.5033 - val_accuracy: 0.2180
# Epoch 20/30
# 424/424 [==============================] - 65s 154ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4420 - val_accuracy: 0.2180
# Epoch 21/30
# 424/424 [==============================] - 66s 155ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4179 - val_accuracy: 0.2180
# Epoch 22/30
# 424/424 [==============================] - 67s 158ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4561 - val_accuracy: 0.2180
# Epoch 23/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4530 - val_accuracy: 0.2180
# Epoch 24/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4035 - val_accuracy: 0.2180
# Epoch 25/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4814 - val_accuracy: 0.2180
# Epoch 26/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.4733 - val_accuracy: 0.2180
# Epoch 27/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4144 - val_accuracy: 0.2180
# Epoch 28/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0203 - accuracy: 0.4768 - val_loss: 1.4200 - val_accuracy: 0.2180
# Epoch 29/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4023 - val_accuracy: 0.2180
# Epoch 30/30
# 424/424 [==============================] - 66s 156ms/step - loss: 1.0201 - accuracy: 0.4768 - val_loss: 1.4952 - val_accuracy: 0.2180
# Test loss: 1.408805251121521
# Test accuracy: 0.20408163964748383
# 39/39 [==============================] - 1s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       208
#            1       0.20      1.00      0.34       250
#            2       0.00      0.00      0.00       767
#
#     accuracy                           0.20      1225
#    macro avg       0.07      0.33      0.11      1225
# weighted avg       0.04      0.20      0.07      1225
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### lr0.01 bs16 - Done

# %%
####################################################################################################################
#          We define our hyperparameters. everything is in the same cell for convenience

learning_rate = [0.01]
batch_size = [16]

####################################################################################################################
#           We define our model specific parameters

model_name = "VGG19" # This is for our model saving names, you still have to change the keras.apllications.model name!
epochs = 100
finetune_epochs = 30
num_classes = 3
input_shape = (128, 128, 3)

####################################################################################################################
#           We print the number of models and state the hyperparameter search

print(f'Running learning rate:{learning_rate} and batch size: {batch_size} for epochs: {epochs}')

####################################################################################################################
#           We loop in our hyperparameters

for i in learning_rate:
    for j in batch_size:
            ####################################################################################################################
            #       We print the specific run
            print(f'Running: \n learning rate:{i}, batch size: {j} for epochs: {epochs}')

            ####################################################################################################################
            #       We import pre trained model from keras applications, weights are important for a pretrained model, 
            #       include top=False is to shave off the top dense layers, which we replace with our own. 

            base_model = keras.applications.VGG19(weights='imagenet',  # Load weights pre-trained on ImageNet.
                                                  input_shape=input_shape,
                                                  include_top=False,# Do not include the ImageNet classifier at the top.
            ) 

            ####################################################################################################################
            #       We "Freeze" the base model to restrict training of the Convolutional layers in the base
            base_model.trainable = False

            ####################################################################################################################
            #       We define the new model in the sequential API of keras. 
            #       We add our own layers on top of the base model to train a classifier for our own dataset on top of the 
            #       "hopefully" generative base model  
            #       The top model dense layers are arbitrarily chosen.

            model = tf.keras.Sequential([
                base_model,
                tf.keras.layers.GlobalMaxPool2D(),
                tf.keras.layers.Dense(4096, activation='relu'),
                tf.keras.layers.Dense(4096, activation='relu'),   
                tf.keras.layers.Dense(num_classes, activation='softmax')
            ])
            
            ####################################################################################################################
            #       We Compile our model

            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

            ####################################################################################################################
            #       We initiate a callback to save best performing model with the names of the gridsearch parameters.

            cp_filepath = '{} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')

            ####################################################################################################################
            #       We train the model by fitting and adding to history,
            history = model.fit(X_train, y_train, batch_size=j, epochs=epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            histories.append(history)
            name.append(cp_filepath)
            ####################################################################################################################
            #       Load best model
            model = tf.keras.models.load_model(cp_filepath)


            ####################################################################################################################
            #       Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            ####################################################################################################################
            #       save model with acc for later investigaion

            model.save('model{} acc{}  lr{} batch size{}.h5'.format(model_name,score[1], i,j,))
            ####################################################################################################################
            #       print visualization of training metrics           
            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)         

            ####################################################################################################################
            #       We are now unfreezing the base layer and fine tune the whole model

            model = tf.keras.models.load_model(cp_filepath)
            model.trainable = True
            model.summary()
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=i),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])


            cp_filepath = 'ft {} lr{} batch size{}.h5'.format(model_name, i,j,)

            checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=cp_filepath, 
                                                            monitor='val_accuracy', 
                                                            save_best_only=True, mode='max')
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(cp_filepath, monitor='val_accuracy', save_best_only=True, mode='max')


            history = model.fit(X_train, y_train, batch_size=j, epochs=finetune_epochs, validation_data=(X_val, y_val), callbacks=[checkpoint])
            ft_histories.append(history)
            ft_name.append(cp_filepath)

                       # Load best model
            model = tf.keras.models.load_model(cp_filepath)

            # Evaluate model
            score = model.evaluate(X_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])

            model.save(' fintunedmodel{} acc{} lr{} batch size{}.h5'.format(model_name,score[1], i,j,))

            His_metrics(history, cp_filepath)
            Viz_metrics(X_test, y_test, model, cp_filepath)
# Out:
# Running learning rate:[0.01] and batch size: [16] for epochs: 100
# Running:
#  learning rate:0.01, batch size: 16 for epochs: 100
# Epoch 1/100
# 848/848 [==============================] - 25s 27ms/step - loss: 10.5885 - accuracy: 0.5159 - val_loss: 1.0397 - val_accuracy: 0.6204
# Epoch 2/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8967 - accuracy: 0.5374 - val_loss: 1.0357 - val_accuracy: 0.4890
# Epoch 3/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8637 - accuracy: 0.5385 - val_loss: 1.0719 - val_accuracy: 0.4563
# Epoch 4/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8357 - accuracy: 0.5612 - val_loss: 1.1553 - val_accuracy: 0.5257
# Epoch 5/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8258 - accuracy: 0.5715 - val_loss: 1.0148 - val_accuracy: 0.5690
# Epoch 6/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8151 - accuracy: 0.5726 - val_loss: 0.9267 - val_accuracy: 0.5608
# Epoch 7/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8446 - accuracy: 0.5752 - val_loss: 0.9599 - val_accuracy: 0.5657
# Epoch 8/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8603 - accuracy: 0.5432 - val_loss: 1.1135 - val_accuracy: 0.5069
# Epoch 9/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8305 - accuracy: 0.5508 - val_loss: 1.0320 - val_accuracy: 0.5469
# Epoch 10/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8195 - accuracy: 0.5514 - val_loss: 1.0992 - val_accuracy: 0.5388
# Epoch 11/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8459 - accuracy: 0.5457 - val_loss: 1.0750 - val_accuracy: 0.5078
# Epoch 12/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8146 - accuracy: 0.5525 - val_loss: 1.2065 - val_accuracy: 0.5029
# Epoch 13/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8164 - accuracy: 0.5502 - val_loss: 1.1434 - val_accuracy: 0.4939
# Epoch 14/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8215 - accuracy: 0.5473 - val_loss: 1.1369 - val_accuracy: 0.5494
# Epoch 15/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8209 - accuracy: 0.5457 - val_loss: 1.1408 - val_accuracy: 0.4890
# Epoch 16/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8161 - accuracy: 0.5502 - val_loss: 1.1187 - val_accuracy: 0.4971
# Epoch 17/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8268 - accuracy: 0.5435 - val_loss: 1.0906 - val_accuracy: 0.4563
# Epoch 18/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8184 - accuracy: 0.5451 - val_loss: 1.1561 - val_accuracy: 0.5551
# Epoch 19/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8160 - accuracy: 0.5556 - val_loss: 1.0179 - val_accuracy: 0.5118
# Epoch 20/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8188 - accuracy: 0.5533 - val_loss: 1.1538 - val_accuracy: 0.4980
# Epoch 21/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8213 - accuracy: 0.5469 - val_loss: 1.0236 - val_accuracy: 0.5494
# Epoch 22/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8168 - accuracy: 0.5520 - val_loss: 1.2117 - val_accuracy: 0.4914
# Epoch 23/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8191 - accuracy: 0.5561 - val_loss: 1.1228 - val_accuracy: 0.5976
# Epoch 24/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8201 - accuracy: 0.5545 - val_loss: 0.9534 - val_accuracy: 0.5388
# Epoch 25/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8158 - accuracy: 0.5513 - val_loss: 1.1043 - val_accuracy: 0.5118
# Epoch 26/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8256 - accuracy: 0.5487 - val_loss: 1.0643 - val_accuracy: 0.5478
# Epoch 27/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8106 - accuracy: 0.5505 - val_loss: 1.2025 - val_accuracy: 0.5069
# Epoch 28/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8136 - accuracy: 0.5533 - val_loss: 1.1757 - val_accuracy: 0.5061
# Epoch 29/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8146 - accuracy: 0.5517 - val_loss: 1.1451 - val_accuracy: 0.5347
# Epoch 30/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8170 - accuracy: 0.5519 - val_loss: 1.0460 - val_accuracy: 0.5657
# Epoch 31/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8123 - accuracy: 0.5523 - val_loss: 1.0845 - val_accuracy: 0.5265
# Epoch 32/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8117 - accuracy: 0.5489 - val_loss: 1.0770 - val_accuracy: 0.5673
# Epoch 33/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8212 - accuracy: 0.5523 - val_loss: 1.2449 - val_accuracy: 0.4637
# Epoch 34/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8271 - accuracy: 0.5541 - val_loss: 1.2061 - val_accuracy: 0.4751
# Epoch 35/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8305 - accuracy: 0.5499 - val_loss: 1.1030 - val_accuracy: 0.5069
# Epoch 36/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8278 - accuracy: 0.5509 - val_loss: 1.1708 - val_accuracy: 0.4580
# Epoch 37/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8279 - accuracy: 0.5543 - val_loss: 1.4269 - val_accuracy: 0.2776
# Epoch 38/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8270 - accuracy: 0.5457 - val_loss: 1.1000 - val_accuracy: 0.5224
# Epoch 39/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8209 - accuracy: 0.5506 - val_loss: 1.0950 - val_accuracy: 0.5012
# Epoch 40/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8257 - accuracy: 0.5532 - val_loss: 1.1536 - val_accuracy: 0.4898
# Epoch 41/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8350 - accuracy: 0.5505 - val_loss: 1.1823 - val_accuracy: 0.4808
# Epoch 42/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8385 - accuracy: 0.5427 - val_loss: 1.1427 - val_accuracy: 0.5167
# Epoch 43/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8220 - accuracy: 0.5499 - val_loss: 1.0822 - val_accuracy: 0.5600
# Epoch 44/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8210 - accuracy: 0.5503 - val_loss: 1.0961 - val_accuracy: 0.5053
# Epoch 45/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8170 - accuracy: 0.5550 - val_loss: 1.1417 - val_accuracy: 0.5290
# Epoch 46/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8255 - accuracy: 0.5485 - val_loss: 1.0766 - val_accuracy: 0.5069
# Epoch 47/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8197 - accuracy: 0.5547 - val_loss: 1.0847 - val_accuracy: 0.5445
# Epoch 48/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8142 - accuracy: 0.5554 - val_loss: 1.1347 - val_accuracy: 0.5649
# Epoch 49/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8256 - accuracy: 0.5501 - val_loss: 1.0179 - val_accuracy: 0.5698
# Epoch 50/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8273 - accuracy: 0.5523 - val_loss: 1.0119 - val_accuracy: 0.5347
# Epoch 51/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8274 - accuracy: 0.5505 - val_loss: 1.2167 - val_accuracy: 0.5069
# Epoch 52/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8183 - accuracy: 0.5569 - val_loss: 1.1827 - val_accuracy: 0.5739
# Epoch 53/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8287 - accuracy: 0.5574 - val_loss: 1.0374 - val_accuracy: 0.5976
# Epoch 54/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8238 - accuracy: 0.5556 - val_loss: 1.0869 - val_accuracy: 0.5086
# Epoch 55/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8188 - accuracy: 0.5546 - val_loss: 1.0446 - val_accuracy: 0.5788
# Epoch 56/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8169 - accuracy: 0.5553 - val_loss: 1.1737 - val_accuracy: 0.5706
# Epoch 57/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8302 - accuracy: 0.5539 - val_loss: 1.0744 - val_accuracy: 0.5633
# Epoch 58/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8187 - accuracy: 0.5551 - val_loss: 1.1205 - val_accuracy: 0.5682
# Epoch 59/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8332 - accuracy: 0.5443 - val_loss: 1.2731 - val_accuracy: 0.3861
# Epoch 60/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8160 - accuracy: 0.5529 - val_loss: 1.1200 - val_accuracy: 0.5012
# Epoch 61/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8143 - accuracy: 0.5563 - val_loss: 1.2067 - val_accuracy: 0.5118
# Epoch 62/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8294 - accuracy: 0.5566 - val_loss: 1.1626 - val_accuracy: 0.4278
# Epoch 63/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8155 - accuracy: 0.5549 - val_loss: 1.1295 - val_accuracy: 0.4939
# Epoch 64/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8215 - accuracy: 0.5566 - val_loss: 1.1893 - val_accuracy: 0.5110
# Epoch 65/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8294 - accuracy: 0.5522 - val_loss: 1.1334 - val_accuracy: 0.5404
# Epoch 66/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8158 - accuracy: 0.5577 - val_loss: 1.1057 - val_accuracy: 0.5943
# Epoch 67/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8145 - accuracy: 0.5567 - val_loss: 1.1279 - val_accuracy: 0.5624
# Epoch 68/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8186 - accuracy: 0.5553 - val_loss: 1.1312 - val_accuracy: 0.5184
# Epoch 69/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8214 - accuracy: 0.5570 - val_loss: 1.0364 - val_accuracy: 0.5829
# Epoch 70/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8274 - accuracy: 0.5508 - val_loss: 1.4949 - val_accuracy: 0.2441
# Epoch 71/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8216 - accuracy: 0.5536 - val_loss: 1.1717 - val_accuracy: 0.5176
# Epoch 72/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8160 - accuracy: 0.5530 - val_loss: 1.0710 - val_accuracy: 0.5282
# Epoch 73/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8167 - accuracy: 0.5585 - val_loss: 1.1697 - val_accuracy: 0.5273
# Epoch 74/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8175 - accuracy: 0.5548 - val_loss: 1.1408 - val_accuracy: 0.5412
# Epoch 75/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8183 - accuracy: 0.5567 - val_loss: 1.0351 - val_accuracy: 0.5518
# Epoch 76/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8166 - accuracy: 0.5530 - val_loss: 1.0786 - val_accuracy: 0.5543
# Epoch 77/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8159 - accuracy: 0.5542 - val_loss: 1.1593 - val_accuracy: 0.5290
# Epoch 78/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8179 - accuracy: 0.5579 - val_loss: 1.1914 - val_accuracy: 0.4914
# Epoch 79/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8189 - accuracy: 0.5561 - val_loss: 1.1673 - val_accuracy: 0.5216
# Epoch 80/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8297 - accuracy: 0.5498 - val_loss: 1.0885 - val_accuracy: 0.5673
# Epoch 81/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8200 - accuracy: 0.5532 - val_loss: 1.1775 - val_accuracy: 0.4857
# Epoch 82/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8179 - accuracy: 0.5572 - val_loss: 1.1185 - val_accuracy: 0.5461
# Epoch 83/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8178 - accuracy: 0.5539 - val_loss: 1.0497 - val_accuracy: 0.5224
# Epoch 84/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8285 - accuracy: 0.5536 - val_loss: 1.1056 - val_accuracy: 0.5192
# Epoch 85/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8168 - accuracy: 0.5555 - val_loss: 1.1452 - val_accuracy: 0.4800
# Epoch 86/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8220 - accuracy: 0.5516 - val_loss: 1.1376 - val_accuracy: 0.5004
# Epoch 87/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8141 - accuracy: 0.5553 - val_loss: 1.1580 - val_accuracy: 0.5184
# Epoch 88/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8145 - accuracy: 0.5536 - val_loss: 1.0864 - val_accuracy: 0.5290
# Epoch 89/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8134 - accuracy: 0.5539 - val_loss: 1.1383 - val_accuracy: 0.5706
# Epoch 90/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8189 - accuracy: 0.5536 - val_loss: 1.1543 - val_accuracy: 0.5012
# Epoch 91/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8160 - accuracy: 0.5578 - val_loss: 1.0482 - val_accuracy: 0.4996
# Epoch 92/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8223 - accuracy: 0.5482 - val_loss: 1.0516 - val_accuracy: 0.5420
# Epoch 93/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8171 - accuracy: 0.5530 - val_loss: 1.1093 - val_accuracy: 0.5282
# Epoch 94/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8236 - accuracy: 0.5519 - val_loss: 1.1495 - val_accuracy: 0.5241
# Epoch 95/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8203 - accuracy: 0.5513 - val_loss: 1.0906 - val_accuracy: 0.5682
# Epoch 96/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8156 - accuracy: 0.5559 - val_loss: 1.0736 - val_accuracy: 0.5461
# Epoch 97/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8171 - accuracy: 0.5494 - val_loss: 0.9734 - val_accuracy: 0.5804
# Epoch 98/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8187 - accuracy: 0.5489 - val_loss: 1.3119 - val_accuracy: 0.4016
# Epoch 99/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8128 - accuracy: 0.5536 - val_loss: 1.1411 - val_accuracy: 0.5249
# Epoch 100/100
# 848/848 [==============================] - 22s 26ms/step - loss: 0.8222 - accuracy: 0.5544 - val_loss: 1.0180 - val_accuracy: 0.5755
# Test loss: 1.0039831399917603
# Test accuracy: 0.6097959280014038
# 39/39 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       208
#            1       0.32      0.48      0.38       250
#            2       0.74      0.82      0.78       767
#
#     accuracy                           0.61      1225
#    macro avg       0.35      0.43      0.39      1225
# weighted avg       0.53      0.61      0.56      1225
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_max_pooling2d_1 (Glo  (None, 512)              0
#  balMaxPooling2D)
#
#  dense_3 (Dense)             (None, 4096)              2101248
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  dense_5 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 38,919,235
# Trainable params: 38,919,235
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 848/848 [==============================] - 76s 86ms/step - loss: 26986008576.0000 - accuracy: 0.4626 - val_loss: 1.5121 - val_accuracy: 0.2180
# Epoch 2/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0211 - accuracy: 0.4743 - val_loss: 1.4469 - val_accuracy: 0.2180
# Epoch 3/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0215 - accuracy: 0.4768 - val_loss: 1.4472 - val_accuracy: 0.2180
# Epoch 4/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0215 - accuracy: 0.4768 - val_loss: 1.4304 - val_accuracy: 0.2180
# Epoch 5/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0211 - accuracy: 0.4768 - val_loss: 1.4117 - val_accuracy: 0.2180
# Epoch 6/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0211 - accuracy: 0.4768 - val_loss: 1.4630 - val_accuracy: 0.2180
# Epoch 7/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0211 - accuracy: 0.4768 - val_loss: 1.5161 - val_accuracy: 0.2180
# Epoch 8/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0215 - accuracy: 0.4768 - val_loss: 1.4524 - val_accuracy: 0.2180
# Epoch 9/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0210 - accuracy: 0.4768 - val_loss: 1.4318 - val_accuracy: 0.2180
# Epoch 10/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0210 - accuracy: 0.4768 - val_loss: 1.4206 - val_accuracy: 0.2180
# Epoch 11/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0213 - accuracy: 0.4768 - val_loss: 1.4135 - val_accuracy: 0.2180
# Epoch 12/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0212 - accuracy: 0.4768 - val_loss: 1.4767 - val_accuracy: 0.2180
# Epoch 13/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0209 - accuracy: 0.4768 - val_loss: 1.4671 - val_accuracy: 0.2180
# Epoch 14/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4779 - val_accuracy: 0.2180
# Epoch 15/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0208 - accuracy: 0.4768 - val_loss: 1.4587 - val_accuracy: 0.2180
# Epoch 16/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0207 - accuracy: 0.4768 - val_loss: 1.4774 - val_accuracy: 0.2180
# Epoch 17/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0204 - accuracy: 0.4768 - val_loss: 1.4067 - val_accuracy: 0.2180
# Epoch 18/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0210 - accuracy: 0.4768 - val_loss: 1.4536 - val_accuracy: 0.2180
# Epoch 19/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0210 - accuracy: 0.4768 - val_loss: 1.4454 - val_accuracy: 0.2180
# Epoch 20/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0209 - accuracy: 0.4768 - val_loss: 1.4737 - val_accuracy: 0.2180
# Epoch 21/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4831 - val_accuracy: 0.2180
# Epoch 22/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0208 - accuracy: 0.4768 - val_loss: 1.4474 - val_accuracy: 0.2180
# Epoch 23/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0202 - accuracy: 0.4768 - val_loss: 1.5044 - val_accuracy: 0.2180
# Epoch 24/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0205 - accuracy: 0.4768 - val_loss: 1.4536 - val_accuracy: 0.2180
# Epoch 25/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0206 - accuracy: 0.4768 - val_loss: 1.4168 - val_accuracy: 0.2180
# Epoch 26/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0211 - accuracy: 0.4768 - val_loss: 1.4454 - val_accuracy: 0.2180
# Epoch 27/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0204 - accuracy: 0.4760 - val_loss: 1.4456 - val_accuracy: 0.2180
# Epoch 28/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0208 - accuracy: 0.4768 - val_loss: 1.4626 - val_accuracy: 0.2180
# Epoch 29/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0209 - accuracy: 0.4768 - val_loss: 1.4510 - val_accuracy: 0.2180
# Epoch 30/30
# 848/848 [==============================] - 71s 84ms/step - loss: 1.0206 - accuracy: 0.4768 - val_loss: 1.4552 - val_accuracy: 0.2180
# Test loss: 1.5146851539611816
# Test accuracy: 0.20408163964748383
# 39/39 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       208
#            1       0.20      1.00      0.34       250
#            2       0.00      0.00      0.00       767
#
#     accuracy                           0.20      1225
#    macro avg       0.07      0.33      0.11      1225
# weighted avg       0.04      0.20      0.07      1225
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mkoli\anaconda3\envs\tfspeciale\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
